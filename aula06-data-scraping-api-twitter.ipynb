# %% [markdown]
# # Aula 06 &mdash; Data Scraping com API do Twitter
#
# Renato Vimieiro
# rv2 {em} cin.ufpe.br
#
# março 2017

# %%
import pandas as pd
import numpy as np

import tweepy

from functools import reduce
from collections import Counter
import json

# %% [markdown]
# ## Introdução
#
# Nas aulas anteriores vimos como obter dados diretamente de uma página web. Para isso, utilizamos a biblioteca BeautifulSoup. A biblioteca facilitava a busca de tags e, consequentemente, de informações úteis nas páginas. Embora tenhamos que lançar mão desse recurso em muitas ocasiões, alguns sites fornecem APIs para obtermos dados de forma semi-estruturada. Esses dados possuem formato livre, mas possuem indicadores do conteúdo. As representações mais usuais são [XML](https://en.wikipedia.org/wiki/XML) e [JSON](https://en.wikipedia.org/wiki/JSON).
#
# O formato JSON tem se tornado um dos mais usados para troca de dados na internet. Ele tem substituido inclusive XML. Muitos bancos de dados NoSQL, como MongoDB, fornecem suporte direto a dados nesse formato. Em outras palavras, JSON é, talvez, o formato franco de representação de dados para Data Science. Sendo assim, discutiremos rapidamente sua representação.

# %% [markdown]
# ## JSON
#
# O formato JSON (lê-se como *jay-son*) é essencialmente um dicionário. Ele descreve uma sequência de pares (chave,valor). Objetos no formato JSON são delimitados por { e }. Por sua vez, os pares são separados por vírgulas. As chaves e valores são separados por : (dois-pontos).
#
# As chaves devem ser sempre strings em unicode. Os valores podem ser:
#
# - string
# - número
# - objeto
# - vetor
# - true
# - false
# - null
#
# Os vetores referenciados acima são como vetores/listas em uma linguagem de programação. Eles podem conter uma sequência de um ou mais valores, incluindo outros vetores e objetos. A gramática do formato pode ser conferida em http://www.json.org/json-pt.html.
#
# ### Exemplo de um dado no formato JSON
#
# O exemplo a seguir foi retirado da Wikipedia. Ele ilustra como poderiam ser armazenados diversos dados sobre uma pessoa. A escolha das chaves é completamente arbitrária e definida pelo desenvolvedor.
#
# ```json
# {
#   "firstName": "John",
#   "lastName": "Smith",
#   "isAlive": true,
#   "age": 25,
#   "address": {
#     "streetAddress": "21 2nd Street",
#     "city": "New York",
#     "state": "NY",
#     "postalCode": "10021-3100"
#   },
#   "phoneNumbers": [
#     {
#       "type": "home",
#       "number": "212 555-1234"
#     },
#     {
#       "type": "office",
#       "number": "646 555-4567"
#     },
#     {
#       "type": "mobile",
#       "number": "123 456-7890"
#     }
#   ],
#   "children": [],
#   "spouse": null
# }
# ```

# %% [markdown]
# ## API do Twitter
#
# O Twitter oferece aos desenvolvedores uma API para permitir a interação entre o site e aplicativos de terceiros. A API é uma das ricas entre as redes sociais e, por isso, muitas pesquisas comerciais e científicas usam a plataforma.
#
# A API do Twitter se subdivide em outras duas APIs: REST e Streaming. A API de REST permite aos desenvolvedores acessar os perfis dos usuários (públicos) assim como seus seguidores, listas, timeline, além de efetuar buscas por termos ou usuários na plataforma. A API de Streaming, por outro lado, é dedicada ao monitoramento em tempo real dos tweets sendo postados na plataforma.
#
# Além dessas duas interfaces públicas, o Twitter ainda oferece uma terceira interface comercial, Gnip, para acesso a grandes volumes de dados. O Gnip, basicamente, fornece acesso à base de dados (pública) inteira do Twitter. Enquanto a API de Streaming faz amostragem dos tweets em tempo real (não é muito claro como isso é feito), o Gnip fornece acesso a efetivamente todos as mensagens sendo postadas. O mesmo acontece em relação ao REST, que limita, por exemplo, a busca por termos, não retornando todos os resultados. O Gnip, ao contrário, permite efetuar uma busca em toda a base.

# %% [markdown]
# ## Acesso à API do Twitter
#
# O acesso à API requer a criação de um perfil na plataforma e registro de um aplicativo. A autenticação é feita através do protocolo [OAuth](https://en.wikipedia.org/wiki/OAuth). A ideia básica do protocolo é que um usuário possa delegar acesso a recursos em um determinado site a terceiros sem revelar suas credenciais. Resumindo, o protocolo permite que chaves de acesso sejam geradas pelo usuário; essas chaves são passadas a um terceiro, a quem se deseja permitir acesso aos recursos do usuário; finalmente, a parte a quem o acesso foi delegado pode conectar-se ao sistema usando as chaves que lhe foram enviadas.
#
# #### Registrando um novo aplicativo
#
# Para registrar um aplicativo e gerar novas chaves de acesso, o usuário deve ir até o site https://apps.twitter.com.
#
# ![https://apps.twitter.com](images/tela_inicial_apps_twitter.png)
#
# Após logar, a tela inicial mostrará as aplicações autorizadas no momento.
#
# ![https://apps.twitter.com](images/apps_twitter_logado.png)
#
# Para criar/autorizar um novo aplicativo, clique no botão **Create New App**. Em seguida, você será redirecionado para uma página onde deverá preencher os dados do aplicativo
#
# ![https://apps.twitter.com](images/create_new_app.png)
#
# e aceitar os termos e condições de uso
#
# ![https://apps.twitter.com](images/create_new_app_accept_terms_confirm.png)
#
# Pronto! Agora você já resgistrou o aplicativo e poderá gerar as chaves de acesso como a seguir.
#
# #### Obtendo as chaves de acesso
#
# Após registrar o novo aplicativo, você será redirecionado à página de gerenciamento do aplicativo
#
# ![https://apps.twitter.com](images/new_app_twitter.png)
#
# Configure as permissões da maneira como for mais conveniente. Em geral, para apenas minerar os dados, basta permitir que o aplicativo possa somente ler os dados. Isso evita, ou diminui as chances, de postagens indevidas caso alguém obtenha suas chaves.
#
# Para gerar as chaves de acesso, vá até a aba **Keys and Access Tokens**.
#
# ![https://apps.twitter.com](images/consumer_key_twitter.png)
#
# Inicialmente o aplicativo não está autorizado a logar em nome do usuário. Você verá que foram assinalados um identificador e uma chave de acesso de usuário (*Consumer key and secret*), como mostrado na figura acima. Essas chaves servem para autenticar o usuário, contudo, elas não autenticam o aplicativo, como mostrado na figura abaixo.
#
# ![https://apps.twitter.com](images/authorize_app_twitter.png)
#
# Para autorizar o aplicativo, clique no botão **Create my access tokens**. O Twitter então gerará novos identificadores e chaves de acesso para o aplicativo (*Access token and secret*). Esses deverão ser usados em conjunto com as chaves de usuário para se ter acesso à API.
#
# ![https://apps.twitter.com](images/access_tokens_twitter.png)
#
# É importante lembrar que esses dois pares de identificadores e chaves nunca devem estar legíveis em seu programa. Eles são como senhas e, portanto, devem ser protegidos.
#
# Agora que já obtivemos as chaves de acesso, podemos iniciar a coleta de dados.

# %% [markdown]
# ## Acessando a API com Tweepy
#
# Existem diversas bibliotecas de Python para acessar a API do Twitter, como listado na página dos desenvolvedores (https://dev.twitter.com/resources/twitter-libraries). As duas bibliotecas mais usadas (pelo que vi na internet) são [Python-Twitter](https://github.com/bear/python-twitter) e [Tweepy](https://github.com/tweepy/tweepy). No entanto, Tweepy está melhor documentada e possui melhor suporte à API de Streaming. Assim, usaremos Tweepy em nossos exemplos.

# %% [markdown]
# #### Conectando-se a API com Tweepy
#
# A biblioteca Tweepy, na verdade, é um wrapper para os serviços listados na API do Twitter. Ela se encarrega dos detalhes de codificação e requisições ao servidor, abstraindo as consultas através de funções e métodos. A biblioteca abstrai inclusive os detalhes de autenticação.
#
# O primeiro passo para coletar os dados é autenticar o usuário e o aplicativo. Isso é feito da seguinte forma:

# %%
# As chaves estao armazenadas em um arquivo de configuracoes
# Python possui uma biblioteca para processar esses arquivos (ver configparser)
with open('../configs.txt') as f:
    chaves = json.load(f)
    
# Autentica o usuario na API
auth = tweepy.OAuthHandler(chaves["consumer_key"], chaves["consumer_secret"])

# Autentica o aplicativo
auth.set_access_token(chaves["access_token"], chaves["access_token_secret"])

# %% [markdown]
# O objeto `auth` contém a sessão autenticada e deverá ser usado nas conexões com a API.

# %% [markdown]
# #### Acesso à REST API
#
# O acesso à REST API é feito através de objetos da classe `tweepy.API`. Os objetos dessa classe possuem métodos que encapsulam os acessos às funcionalidades da API. Assim, devemos instaciar a classe usando a conexão criada anteriormente. É importante respeitar os limites impostos pela API, caso contrário, podemos ser bloqueados. As requisições que ultrapassarem os limites do Twitter resultaram em exceções do tipo `tweepy.RateLimitError`. Tweepy pode controlar automaticamente esses acessos. Podemos estabelecer que as chamadas a determinados métodos devem esperar até que o limite de requisições seja reestabelecido. O limite de requisições varia dependendo do tipo de requisição. O Twitter também faz constantes modificações nesses limites. Então, você sempre deve consultar a documentação da API para se certificar dos limites atuais. Eles podem ser conferidos em https://dev.twitter.com/rest/public/rate-limits.

# %%
api = tweepy.API(auth, wait_on_rate_limit=False)

# %% [markdown]
# O objeto `api` agora é nossa interface de acesso ao Twitter.
#
# Podemos usá-la para saber quais são os trending topics nos diversos lugares onde essa informação é monitorada.

# %%
api.trends_available()
# Out:
# [{'country': '',
#   'countryCode': None,
#   'name': 'Worldwide',
#   'parentid': 0,
#   'placeType': {'code': 19, 'name': 'Supername'},
#   'url': 'http://where.yahooapis.com/v1/place/1',
#   'woeid': 1},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Winnipeg',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'woeid': 2972},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Ottawa',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'woeid': 3369},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Quebec',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3444',
#   'woeid': 3444},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Montreal',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3534',
#   'woeid': 3534},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Toronto',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/4118',
#   'woeid': 4118},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Edmonton',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/8676',
#   'woeid': 8676},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Calgary',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/8775',
#   'woeid': 8775},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Vancouver',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/9807',
#   'woeid': 9807},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Birmingham',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/12723',
#   'woeid': 12723},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Blackpool',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/12903',
#   'woeid': 12903},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Bournemouth',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/13383',
#   'woeid': 13383},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Brighton',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/13911',
#   'woeid': 13911},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Bristol',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/13963',
#   'woeid': 13963},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Cardiff',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/15127',
#   'woeid': 15127},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Coventry',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/17044',
#   'woeid': 17044},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Derby',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/18114',
#   'woeid': 18114},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Edinburgh',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/19344',
#   'woeid': 19344},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Glasgow',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/21125',
#   'woeid': 21125},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Hull',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/25211',
#   'woeid': 25211},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Leeds',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/26042',
#   'woeid': 26042},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Leicester',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/26062',
#   'woeid': 26062},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Liverpool',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/26734',
#   'woeid': 26734},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Manchester',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/28218',
#   'woeid': 28218},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Middlesbrough',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/28869',
#   'woeid': 28869},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Newcastle',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/30079',
#   'woeid': 30079},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Nottingham',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/30720',
#   'woeid': 30720},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Plymouth',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/32185',
#   'woeid': 32185},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Portsmouth',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/32452',
#   'woeid': 32452},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Preston',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/32566',
#   'woeid': 32566},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Sheffield',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/34503',
#   'woeid': 34503},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Stoke-on-Trent',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/36240',
#   'woeid': 36240},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Swansea',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/36758',
#   'woeid': 36758},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'London',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/44418',
#   'woeid': 44418},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Belfast',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/44544',
#   'woeid': 44544},
#  {'country': 'Dominican Republic',
#   'countryCode': 'DO',
#   'name': 'Santo Domingo',
#   'parentid': 23424800,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/76456',
#   'woeid': 76456},
#  {'country': 'Guatemala',
#   'countryCode': 'GT',
#   'name': 'Guatemala City',
#   'parentid': 23424834,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/83123',
#   'woeid': 83123},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Acapulco',
#   'parentid': 23424900,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/110978',
#   'woeid': 110978},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Aguascalientes',
#   'parentid': 23424900,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/111579',
#   'woeid': 111579},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Chihuahua',
#   'parentid': 23424900,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/115958',
#   'woeid': 115958},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Mexico City',
#   'parentid': 23424900,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/116545',
#   

#  {'country': 'Malaysia',
#   'countryCode': 'MY',
#   'name': 'Kuala Lumpur',
#   'parentid': 23424901,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/1154781',
#   'woeid': 1154781},
# ...
#   'parentid': 23424977,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2490383',
#   'woeid': 2490383},
#  {'country': 'United States',
#   'countryCode': 'US',
#   'name': 'Tallahassee',
#   'parentid': 23424977,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2503713',
#   'woeid': 2503713},
#  {'country': 'United States',
#   'countryCode': 'US',
#   'name': 'Tampa',
#   'parentid': 23424977,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2503863',
#   'woeid': 2503863},
#  {'country': 'United States',
#   'countryCode': 'US',
#   'name': 'Tucson',
#   'parentid': 23424977,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2508428',
#   'woeid': 2508428},
#  {'country': 'United States',
#   'countryCode': 'US',
#   'name': 'Virginia Beach',
#   'parentid': 23424977,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2512636',
#   'woeid': 2512636},
#  {'country': 'United States',
#   'countryCode': 'US',
#   'name': 'Washington',
#   'parentid': 23424977,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2514815',
#   'woeid': 2514815},
#  {'country': 'Japan',
#   'countryCode': 'JP',
#   'name': 'Osaka',
#   'parentid': 23424856,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/15015370',
#   'woeid': 15015370},
#  {'country': 'Japan',
#   'countryCode': 'JP',
#   'name': 'Kyoto',
#   'parentid': 23424856,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/15015372',
#   'woeid': 15015372},
#  {'country': 'India',
#   'countryCode': 'IN',
#   'name': 'Delhi',
#   'parentid': 23424848,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/20070458',
#   'woeid': 20070458},
#  {'country': 'United Arab Emirates',
#   'countryCode': 'AE',
#   'name': 'United Arab Emirates',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424738',
#   'woeid': 23424738},
#  {'country': 'Algeria',
#   'countryCode': 'DZ',
#   'name': 'Algeria',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424740',
#   'woeid': 23424740},
#  {'country': 'Argentina',
#   'countryCode': 'AR',
#   'name': 'Argentina',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424747',
#   'woeid': 23424747},
#  {'country': 'Australia',
#   'countryCode': 'AU',
#   'name': 'Australia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424748',
#   'woeid': 23424748},
#  {'country': 'Austria',
#   'countryCode': 'AT',
#   'name': 'Austria',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424750',
#   'woeid': 23424750},
#  {'country': 'Bahrain',
#   'countryCode': 'BH',
#   'name': 'Bahrain',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424753',
#   'woeid': 23424753},
#  {'country': 'Belgium',
#   'countryCode': 'BE',
#   'name': 'Belgium',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424757',
#   'woeid': 23424757},
#  {'country': 'Belarus',
#   'countryCode': 'BY',
#   'name': 'Belarus',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424765',
#   'woeid': 23424765},
#  {'country': 'Brazil',
#   'countryCode': 'BR',
#   'name': 'Brazil',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424768',
#   'woeid': 23424768},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Canada',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424775',
#   'woeid': 23424775},
#  {'country': 'Chile',
#   'countryCode': 'CL',
#   'name': 'Chile',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424782',
#   'woeid': 23424782},
#  {'country': 'Colombia',
#   'countryCode': 'CO',
#   'name': 'Colombia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424787',
#   'woeid': 23424787},
#  {'country': 'Denmark',
#   'countryCode': 'DK',
#   'name': 'Denmark',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424796',
#   'woeid': 23424796},
#  {'country': 'Dominican Republic',
#   'countryCode': 'DO',
#   'name': 'Dominican Republic',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424800',
#   'woeid': 23424800},
#  {'country': 'Ecuador',
#   'countryCode': 'EC',
#   'name': 'Ecuador',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424801',
#   'woeid': 23424801},
#  {'country': 'Egypt',
#   'countryCode': 'EG',
#   'name': 'Egypt',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424802',
#   'woeid': 23424802},
#  {'country': 'Ireland',
#   'countryCode': 'IE',
#   'name': 'Ireland',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424803',
#   'woeid': 23424803},
#  {'country': 'France',
#   'countryCode': 'FR',
#   'name': 'France',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424819',
#   'woeid': 23424819},
#  {'country': 'Ghana',
#   'countryCode': 'GH',
#   'name': 'Ghana',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424824',
#   'woeid': 23424824},
#  {'country': 'Germany',
#   'countryCode': 'DE',
#   'name': 'Germany',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424829',
#   'woeid': 23424829},
#  {'country': 'Greece',
#   'countryCode': 'GR',
#   'name': 'Greece',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424833',
#   'woeid': 23424833},
#  {'country': 'Guatemala',
#   'countryCode': 'GT',
#   'name': 'Guatemala',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424834',
#   'woeid': 23424834},
#  {'country': 'Indonesia',
#   'countryCode': 'ID',
#   'name': 'Indonesia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424846',
#   'woeid': 23424846},
#  {'country': 'India',
#   'countryCode': 'IN',
#   'name': 'India',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424848',
#   'woeid': 23424848},
#  {'country': 'Israel',
#   'countryCode': 'IL',
#   'name': 'Israel',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424852',
#   'woeid': 23424852},
#  {'country': 'Italy',
#   'countryCode': 'IT',
#   'name': 'Italy',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424853',
#   'woeid': 23424853},
#  {'country': 'Japan',
#   'countryCode': 'JP',
#   'name': 'Japan',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424856',
#   'woeid': 23424856},
#  {'country': 'Jordan',
#   'countryCode': 'JO',
#   'name': 'Jordan',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424860',
#   'woeid': 23424860},
#  {'country': 'Kenya',
#   'countryCode': 'KE',
#   'name': 'Kenya',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424863',
#   'woeid': 23424863},
#  {'country': 'Korea',
#   'countryCode': 'KR',
#   'name': 'Korea',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424868',
#   'woeid': 23424868},
#  {'country': 'Kuwait',
#   'countryCode': 'KW',
#   'name': 'Kuwait',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424870',
#   'woeid': 23424870},
#  {'country': 'Lebanon',
#   'countryCode': 'LB',
#   'name': 'Lebanon',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424873',
#   'woeid': 23424873},
#  {'country': 'Latvia',
#   'countryCode': 'LV',
#   'name': 'Latvia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424874',
#   'woeid': 23424874},
#  {'country': 'Oman',
#   'countryCode': 'OM',
#   'name': 'Oman',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424898',
#   'woeid': 23424898},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Mexico',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424900',
#   'woeid': 23424900},
#  {'country': 'Malaysia',
#   'countryCode': 'MY',
#   'name': 'Malaysia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424901',
#   'woeid': 23424901},
#  {'country': 'Nigeria',
#   'countryCode': 'NG',
#   'name': 'Nigeria',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424908',
#   'woeid': 23424908},
#  {'country': 'Netherlands',
#   'countryCode': 'NL',
#   'name': 'Netherlands',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424909',
#   'woeid': 23424909},
#  {'country': 'Norway',
#   'countryCode': 'NO',
#   'name': 'Norway',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424910',
#   'woeid': 23424910},
#  {'country': 'New Zealand',
#   'countryCode': 'NZ',
#   'name': 'New Zealand',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424916',
#   'woeid': 23424916},
#  {'country': 'Peru',
#   'countryCode': 'PE',
#   'name': 'Peru',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424919',
#   'woeid': 23424919},
#  {'country': 'Pakistan',
#   'countryCode': 'PK',
#   'name': 'Pakistan',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424922',
#   'woeid': 23424922},
#  {'country': 'Poland',
#   'countryCode': 'PL',
#   'name': 'Poland',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424923',
#   'woeid': 23424923},
#  {'country': 'Panama',
#   'countryCode': 'PA',
#   'name': 'Panama',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424924',
#   'woeid': 23424924},
#  {'country': 'Portugal',
#   'countryCode': 'PT',
#   'name': 'Portugal',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424925',
#   'woeid': 23424925},
#  {'country': 'Qatar',
#   'countryCode': 'QA',
#   'name': 'Qatar',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424930',
#   'woeid': 23424930},
#  {'country': 'Philippines',
#   'countryCode': 'PH',
#   'name': 'Philippines',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424934',
#   'woeid': 23424934},
#  {'country': 'Puerto Rico',
#   'countryCode': 'PR',
#   'name': 'Puerto Rico',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424935',
#   'woeid': 23424935},
#  {'country': 'Russia',
#   'countryCode': 'RU',
#   'name': 'Russia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424936',
#   'woeid': 23424936},
#  {'country': 'Saudi Arabia',
#   'countryCode': 'SA',
#   'name': 'Saudi Arabia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424938',
#   'woeid': 23424938},
#  {'country': 'South Africa',
#   'countryCode': 'ZA',
#   'name': 'South Africa',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424942',
#   'woeid': 23424942},
#  {'country': 'Singapore',
#   'countryCode': 'SG',
#   'name': 'Singapore',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424948',
#   'woeid': 23424948},
#  {'country': 'Spain',
#   'countryCode': 'ES',
#   'name': 'Spain',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424950',
#   'woeid': 23424950},
#  {'country': 'Sweden',
#   'countryCode': 'SE',
#   'name': 'Sweden',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424954',
#   'woeid': 23424954},
#  {'country': 'Switzerland',
#   'countryCode': 'CH',
#   'name': 'Switzerland',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424957',
#   'woeid': 23424957},
#  {'country': 'Thailand',
#   'countryCode': 'TH',
#   'name': 'Thailand',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424960',
#   'woeid': 23424960},
#  {'country': 'Turkey',
#   'countryCode': 'TR',
#   'name': 'Turkey',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424969',
#   'woeid': 23424969},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'United Kingdom',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424975',
#   'woeid': 23424975},
#  {'country': 'Ukraine',
#   'countryCode': 'UA',
#   'name': 'Ukraine',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424976',
#   'woeid': 23424976},
#  {'country': 'United States',
#   'countryCode': 'US',
#   'name': 'United States',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424977',
#   'woeid': 23424977},
#  {'country': 'Venezuela',
#   'countryCode': 'VE',
#   'name': 'Venezuela',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424982',
#   'woeid': 23424982},
#  {'country': 'Vietnam',
#   'countryCode': 'VN',
#   'name': 'Vietnam',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424984',
#   'woeid': 23424984},
#  {'country': 'Malaysia',
#   'countryCode': 'MY',
#   'name': 'Petaling',
#   'parentid': 23424901,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/56013632',
#   'woeid': 56013632},
#  {'country': 'Malaysia',
#   'countryCode': 'MY',
#   'name': 'Hulu Langat',
#   'parentid': 23424901,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/56013645',
#   'woeid': 56013645},
#  {'country': 'Saudi Arabia',
#   'countryCode': 'SA',
#   'name': 'Ahsa',
#   'parentid': 23424938,
#   'placeType': {'code': 9, 'name': 'Unknown'},
#   'url': 'http://where.yahooapis.com/v1/place/56120136',
#   'woeid': 56120136},
#  {'country': 'Japan',
#   'countryCode': 'JP',
#   'name': 'Okayama',
#   'parentid': 23424856,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/90036018',
#   'woeid': 90036018}]

# %%
trendtopics = api.trends_place(455824)
trendtopics
# Out:
# [{'as_of': '2017-03-30T12:15:39Z',
#   'created_at': '2017-03-30T12:09:50Z',
#   'locations': [{'name': 'Recife', 'woeid': 455824}],
#   'trends': [{'name': '#PurposeTourRioDeJaneiro',
#     'promoted_content': None,
#     'query': '%23PurposeTourRioDeJaneiro',
#     'tweet_volume': 911577,
#     'url': 'http://twitter.com/search?q=%23PurposeTourRioDeJaneiro'},
#    {'name': '#RedeBBB',
#     'promoted_content': None,
#     'query': '%23RedeBBB',
#     'tweet_volume': 20926,
#     'url': 'http://twitter.com/search?q=%23RedeBBB'},
#    {'name': '#QuintaDetremuraSDV',
#     'promoted_content': None,
#     'query': '%23QuintaDetremuraSDV',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23QuintaDetremuraSDV'},
#    {'name': '#New1DAlbum',
#     'promoted_content': None,
#     'query': '%23New1DAlbum',
#     'tweet_volume': 30867,
#     'url': 'http://twitter.com/search?q=%23New1DAlbum'},
#    {'name': '#ParabensAnitta',
#     'promoted_content': None,
#     'query': '%23ParabensAnitta',
#     'tweet_volume': 12907,
#     'url': 'http://twitter.com/search?q=%23ParabensAnitta'},
#    {'name': 'Lasier Martins',
#     'promoted_content': None,
#     'query': '%22Lasier+Martins%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Lasier+Martins%22'},
#    {'name': 'Salmo 150',
#     'promoted_content': None,
#     'query': '%22Salmo+150%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Salmo+150%22'},
#    {'name': 'Radial Leste',
#     'promoted_content': None,
#     'query': '%22Radial+Leste%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Radial+Leste%22'},
#    {'name': 'Glastonbury',
#     'promoted_content': None,
#     'query': 'Glastonbury',
#     'tweet_volume': 13606,
#     'url': 'http://twitter.com/search?q=Glastonbury'},
#    {'name': 'Gustavo Rocha',
#     'promoted_content': None,
#     'query': '%22Gustavo+Rocha%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Gustavo+Rocha%22'},
#    {'name': 'Fetranspor',
#     'promoted_content': None,
#     'query': 'Fetranspor',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Fetranspor'},
#    {'name': 'Lanterna Verde',
#     'promoted_content': None,
#     'query': '%22Lanterna+Verde%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Lanterna+Verde%22'},
#    {'name': 'Justin Bieber',
#     'promoted_content': None,
#     'query': '%22Justin+Bieber%22',
#     'tweet_volume': 312288,
#     'url': 'http://twitter.com/search?q=%22Justin+Bieber%22'},
#    {'name': 'Whindersson',
#     'promoted_content': None,
#     'query': 'Whindersson',
#     'tweet_volume': 118941,
#     'url': 'http://twitter.com/search?q=Whindersson'},
#    {'name': 'Neymar',
#     'promoted_content': None,
#     'query': 'Neymar',
#     'tweet_volume': 98756,
#     'url': 'http://twitter.com/search?q=Neymar'},
#    {'name': 'Galaxy S8',
#     'promoted_content': None,
#     'query': '%22Galaxy+S8%22',
#     'tweet_volume': 363114,
#     'url': 'http://twitter.com/search?q=%22Galaxy+S8%22'},
#    {'name': 'Luccas Carlos',
#     'promoted_content': None,
#     'query': '%22Luccas+Carlos%22',
#     'tweet_volume': 13556,
#     'url': 'http://twitter.com/search?q=%22Luccas+Carlos%22'},
#    {'name': 'Volta Redonda',
#     'promoted_content': None,
#     'query': '%22Volta+Redonda%22',
#     'tweet_volume': 11566,
#     'url': 'http://twitter.com/search?q=%22Volta+Redonda%22'},
#    {'name': 'EMILLY GO SOLO',
#     'promoted_content': None,
#     'query': '%22EMILLY+GO+SOLO%22',
#     'tweet_volume': 25788,
#     'url': 'http://twitter.com/search?q=%22EMILLY+GO+SOLO%22'},
#    {'name': 'Bruno Grassi',
#     'promoted_content': None,
#     'query': '%22Bruno+Grassi%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Bruno+Grassi%22'},
#    {'name': 'Mark Zuckerberg',
#     'promoted_content': None,
#     'query': '%22Mark+Zuckerberg%22',
#     'tweet_volume': 14520,
#     'url': 'http://twitter.com/search?q=%22Mark+Zuckerberg%22'},
#    {'name': 'Paraguai',
#     'promoted_content': None,
#     'query': 'Paraguai',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Paraguai'},
#    {'name': 'Felipe Dylon',
#     'promoted_content': None,
#     'query': '%22Felipe+Dylon%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Felipe+Dylon%22'},
#    {'name': 'Amazon',
#     'promoted_content': None,
#     'query': 'Amazon',
#     'tweet_volume': 623836,
#     'url': 'http://twitter.com/search?q=Amazon'},
#    {'name': 'Stories',
#     'promoted_content': None,
#     'query': 'Stories',
#     'tweet_volume': 259826,
#     'url': 'http://twitter.com/search?q=Stories'},
#    {'name': 'Vitor Hugo',
#     'promoted_content': None,
#     'query': '%22Vitor+Hugo%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Vitor+Hugo%22'},
#    {'name': '#GabaritandoÉtica',
#     'promoted_content': None,
#     'query': '%23Gabaritando%C3%89tica',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Gabaritando%C3%89tica'},
#    {'name': '#BomDiaBrasil',
#     'promoted_content': None,
#     'query': '%23BomDiaBrasil',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23BomDiaBrasil'},
#    {'name': '#MaisVocê',
#     'promoted_content': None,
#     'query': '%23MaisVoc%C3%AA',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MaisVoc%C3%AA'},
#    {'name': '#Boechat',
#     'promoted_content': None,
#     'query': '%23Boechat',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Boechat'},
#    {'name': '#NoMoreSadSongsVideo',
#     'promoted_content': None,
#     'query': '%23NoMoreSadSongsVideo',
#     'tweet_volume': 143841,
#     'url': 'http://twitter.com/search?q=%23NoMoreSadSongsVideo'},
#    {'name': '#maejorinbrazil',
#     'promoted_content': None,
#     'query': '%23maejorinbrazil',
#     'tweet_volume': 20477,
#     'url': 'http://twitter.com/search?q=%23maejorinbrazil'},
#    {'name': '#Armys23Version',
#     'promoted_content': None,
#     'query': '%23Armys23Version',
#     'tweet_volume': 78788,
#     'url': 'http://twitter.com/search?q=%23Armys23Version'},
#    {'name': '#NaMafiaMeSegueQSdv',
#     'promoted_content': None,
#     'query': '%23NaMafiaMeSegueQSdv',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23NaMafiaMeSegueQSdv'},
#    {'name': '#SaiaJusta',
#     'promoted_content': None,
#     'query': '%23SaiaJusta',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SaiaJusta'},
#    {'name': '#BiTwitter',
#     'promoted_content': None,
#     'query': '%23BiTwitter',
#     'tweet_volume': 172114,
#     'url': 'http://twitter.com/search?q=%23BiTwitter'},
#    {'name': '#ProgramaDoRatinho',
#     'promoted_content': None,
#     'query': '%23ProgramaDoRatinho',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ProgramaDoRatinho'},
#    {'name': '#Curitiba324Anos',
#     'promoted_content': None,
#     'query': '%23Curitiba324Anos',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Curitiba324Anos'},
#    {'name': '#rudymusic',
#     'promoted_content': None,
#     'query': '%23rudymusic',
#     'tweet_volume': 47201,
#     'url': 'http://twitter.com/search?q=%23rudymusic'}]}]

# %% [markdown]
# Como pode ser visto, o resultado é uma lista de objetos no formato JSON (um dicionário). Podemos usar Pandas para criar um data frame com os dados obtidos. Repare que a requisição retorna um único objeto com quatro chaves: data da apuração, data da requisição, local, e os tópicos. Nossa intenção é criar um data frame com os dados dos tópicos. As outras informações são complementares e podem ser replicadas no data frame se necessário após a criação.

# %%
dfTrendTopics = pd.DataFrame(trendtopics[0]['trends'])

# %%
dfTrendTopics.head()
# Out:
#                        name promoted_content                       query  \
# 0  #PurposeTourRioDeJaneiro             None  %23PurposeTourRioDeJaneiro
# 1                  #RedeBBB             None                  %23RedeBBB
# 2       #QuintaDetremuraSDV             None       %23QuintaDetremuraSDV
# 3               #New1DAlbum             None               %23New1DAlbum
# 4           #ParabensAnitta             None           %23ParabensAnitta
#
#    tweet_volume                                                url
# 0      911577.0  http://twitter.com/search?q=%23PurposeTourRioD...
# 1       20926.0             http://twitter.com/search?q=%23RedeBBB
# 2           NaN  http://twitter.com/search?q=%23QuintaDetremuraSDV
# 3       30867.0          http://twitter.com/search?q=%23New1DAlbum
# 4       12907.0      http://twitter.com/search?q=%23ParabensAnitta

# %%
dfTrendTopics.sort_values(by='tweet_volume',ascending=False).\
                head(10)[['name','tweet_volume']]
# Out:
#                         name  tweet_volume
# 0   #PurposeTourRioDeJaneiro      911577.0
# 23                    Amazon      623836.0
# 15                 Galaxy S8      363114.0
# 12             Justin Bieber      312288.0
# 24                   Stories      259826.0
# 35                #BiTwitter      172114.0
# 30      #NoMoreSadSongsVideo      143841.0
# 13               Whindersson      118941.0
# 14                    Neymar       98756.0
# 32           #Armys23Version       78788.0

# %% [markdown]
# Podemos também obter a lista de tweets de um usuário

# %%
trumpsTweets = api.user_timeline(screen_name='realdonaldtrump')
trumpsTweets[0]
# Out:
# Status(_json={'favorited': False, 'geo': None, 'is_quote_status': False, 'coordinates': None, 'id_str': '847061031293779969', 'retweet_count': 7674, 'in_reply_to_user_id_str': None, 'in_reply_to_status_id_str': None, 'entities': {'urls': [], 'hashtags': [], 'symbols': [], 'user_mentions': []}, 'retweeted': False, 'contributors': None, 'text': 'If the people of our great country could only see how viciously and inaccurately my administration is covered by certain media!', 'created_at': 'Wed Mar 29 12:21:02 +0000 2017', 'in_reply_to_status_id': None, 'place': None, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_screen_name': None, 'in_reply_to_user_id': None, 'favorite_count': 35385, 'user': {'has_extended_profile': False, 'notifications': False, 'location': 'Washington, DC', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg', 'profile_sidebar_fill_color': 'C5CEC0', 'id_str': '25073877', 'profile_sidebar_border_color': 'BDDCAD', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg', 'utc_offset': -14400, 'default_profile': False, 'time_zone': 'Eastern Time (US & Canada)', 'following': False, 'entities': {'description': {'urls': []}}, 'profile_text_color': '333333', 'translator_type': 'regular', 'profile_use_background_image': True, 'created_at': 'Wed Mar 18 13:46:38 +0000 2009', 'geo_enabled': True, 'contributors_enabled': False, 'verified': True, 'url': None, 'favourites_count': 47, 'lang': 'en', 'description': '45th President of the United States of America', 'follow_request_sent': False, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg', 'listed_count': 67128, 'profile_link_color': '0D5B73', 'profile_background_tile': True, 'followers_count': 27160698, 'name': 'Donald J. Trump', 'profile_background_color': '6D5C18', 'friends_count': 43, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1489657715', 'is_translation_enabled': True, 'protected': False, 'id': 25073877, 'default_profile_image': False, 'screen_name': 'realDonaldTrump', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg', 'is_translator': False, 'statuses_count': 34665}, 'lang': 'en', 'id': 847061031293779969, 'truncated': False}, favorited=False, geo=None, is_quote_status=False, coordinates=None, id_str='847061031293779969', retweet_count=7674, in_reply_to_user_id_str=None, in_reply_to_status_id_str=None, entities={'urls': [], 'hashtags': [], 'symbols': [], 'user_mentions': []}, retweeted=False, contributors=None, text='If the people of our great country could only see how viciously and inaccurately my administration is covered by certain media!', created_at=datetime.datetime(2017, 3, 29, 12, 21, 2), in_reply_to_status_id=None, author=User(_json={'has_extended_profile': False, 'notifications': False, 'location': 'Washington, DC', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg', 'profile_sidebar_fill_color': 'C5CEC0', 'id_str': '25073877', 'profile_sidebar_border_color': 'BDDCAD', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg', 'utc_offset': -14400, 'default_profile': False, 'time_zone': 'Eastern Time (US & Canada)', 'following': False, 'entities': {'description': {'urls': []}}, 'profile_text_color': '333333', 'translator_type': 'regular', 'profile_use_background_image': True, 'created_at': 'Wed Mar 18 13:46:38 +0000 2009', 'geo_enabled': True, 'contributors_enabled': False, 'verified': True, 'url': None, 'favourites_count': 47, 'lang': 'en', 'description': '45th President of the United States of America', 'follow_request_sent': False, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background ...

# %% [markdown]
# O resultado da chamada é uma lista de objetos da classe `Status`. Inspecionando esse objeto, vemos que ele possui um atributo `_json` que armazena o tweet como um dicionário (JSON).

# %%
print(type(trumpsTweets[0]._json))
trumpsTweets[0]._json
# Out:
# <class 'dict'>
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Mar 29 12:21:02 +0000 2017',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 35385,
#  'favorited': False,
#  'geo': None,
#  'id': 847061031293779969,
#  'id_str': '847061031293779969',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 7674,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': 'If the people of our great country could only see how viciously and inaccurately my administration is covered by certain media!',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': '45th President of the United States of America',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 47,
#   'follow_request_sent': False,
#   'followers_count': 27160698,
#   'following': False,
#   'friends_count': 43,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 25073877,
#   'id_str': '25073877',
#   'is_translation_enabled': True,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 67128,
#   'location': 'Washington, DC',
#   'name': 'Donald J. Trump',
#   'notifications': False,
#   'profile_background_color': '6D5C18',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1489657715',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg',
#   'profile_link_color': '0D5B73',
#   'profile_sidebar_border_color': 'BDDCAD',
#   'profile_sidebar_fill_color': 'C5CEC0',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'realDonaldTrump',
#   'statuses_count': 34665,
#   'time_zone': 'Eastern Time (US & Canada)',
#   'translator_type': 'regular',
#   'url': None,
#   'utc_offset': -14400,
#   'verified': True}}

# %% [markdown]
# Essa representação reflete o modelo de objetos estabelecido pela API do Twitter. Um tweet possui vários campos, como descrito em https://dev.twitter.com/overview/api/tweets. Nem todos os campos são interessantes para a análise de dados. Por exemplo, o tweet contém informações detalhadas sobre o usuário, como o link para a imagem de seu perfil, o link para a imagem que ele usa de fundo, entre outras coisas. Geralmente, esses dados não são úteis para análise. Assim, devemos ser cuidadosos para criar um data frame somente com os dados que julgarmos importantes.
#
# Por exemplo, podemos selecionar os seguintes campos:
#
# - id
# - created_at
# - entities (hashtags, urls, user_mentions)
# - favorite_count
# - in_reply_to_screen_name
# - in_reply_to_status_id
# - in_reply_to_user_id
# - lang
# - place (country, name)
# - retweet_count
# - source
# - text
# - truncated
# - user (screen_name, id)

# %%
def filtra_campos(tweet):    
    dic = {a[0] : a[1] for a in tweet.items() if a[0] in ['id',
                                    'created_at',
                                    'favorite_count',
                                    'in_reply_to_screen_name',
                                    'in_reply_to_status_id',
                                    'in_reply_to_user_id',
                                    'lang',
                                    'retweet_count',
                                    'source',
                                    'text',
                                    'truncated']}
    dic.update(tweet['entities'])
    if tweet['place']:
        dic.update({'place_'+a[0] : a[1] for a in tweet['place'].items() \
                    if a[0] in ['country', 'name']})
    dic.update({'user_'+a[0] : a[1] for a in tweet['user'].items() \
                if a[0] in ['screen_name', 'id']})
    return dic

# %%
filtra_campos(trumpsTweets[0]._json)
# Out:
# {'created_at': 'Wed Mar 29 12:21:02 +0000 2017',
#  'favorite_count': 35385,
#  'hashtags': [],
#  'id': 847061031293779969,
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_user_id': None,
#  'lang': 'en',
#  'retweet_count': 7674,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'symbols': [],
#  'text': 'If the people of our great country could only see how viciously and inaccurately my administration is covered by certain media!',
#  'truncated': False,
#  'urls': [],
#  'user_id': 25073877,
#  'user_mentions': [],
#  'user_screen_name': 'realDonaldTrump'}

# %% [markdown]
# Podemos aplicar a função `filtra_campos` aos tweets recuperados para extrair os campos desejados.

# %%
dfTrumpsTweets = pd.DataFrame(list(map(lambda x: filtra_campos(x._json),trumpsTweets)))
dfTrumpsTweets.head()
# Out:
#                        created_at  favorite_count  \
# 0  Wed Mar 29 12:21:02 +0000 2017           35385
# 1  Wed Mar 29 12:01:52 +0000 2017           30505
# 2  Tue Mar 28 22:41:09 +0000 2017           64865
# 3  Tue Mar 28 21:48:40 +0000 2017           34999
# 4  Tue Mar 28 20:57:17 +0000 2017           30731
#
#                                           hashtags                  id  \
# 0                                               []  847061031293779969
# 1                                               []  847056211006631936
# 2                                               []  846854703183020032
# 3  [{'indices': [31, 44], 'text': 'MadeInTheUSA'}]  846841493952319489
# 4                                               []  846828561491202048
#
#   in_reply_to_screen_name in_reply_to_status_id in_reply_to_user_id lang  \
# 0                    None                  None                None   en
# 1                    None                  None                None   en
# 2                    None                  None                None   en
# 3                    None                  None                None   en
# 4                    None                  None                None   en
#
#                                                media  retweet_count  \
# 0                                                NaN           7674
# 1                                                NaN           6779
# 2                                                NaN          19235
# 3  [{'indices': [83, 106], 'media_url_https': 'ht...           7521
# 4                                                NaN           5840
#
#                                               source symbols  \
# 0  <a href="http://twitter.com/download/iphone" r...      []
# 1  <a href="http://twitter.com/download/iphone" r...      []
# 2  <a href="http://twitter.com/download/iphone" r...      []
# 3  <a href="http://twitter.com/download/iphone" r...      []
# 4  <a href="http://twitter.com/download/iphone" r...      []
#
#                                                 text truncated  \
# 0  If the people of our great country could only ...     False
# 1  Remember when the failing @nytimes apologized ...     False
# 2  Why doesn't Fake News talk about Podesta ties ...     False
# 3  A NEW ERA IN AMERICAN ENERGY! \n#MadeInTheUSA🇺...     False
# 4  It was an honor to welcome @GLFOP to the @Whit...      True
#
#                                                 urls   user_id  \
# 0                                                 []  25073877
# 1                                                 []  25073877
# 2                                                 []  25073877
# 3  [{'indices': [59, 82], 'url': 'https://t.co/EG...  25073877
# 4  [{'indices': [121, 144], 'url': 'https://t.co/...  25073877
#
#                                        user_mentions user_screen_name
# 0                                                 []  realDonaldTrump
# 1  [{'id_str': '807095', 'id': 807095, 'indices':...  realDonaldTrump
# 2  [{'id_str': '1367531', 'id': 1367531, 'indices...  realDonaldTrump
# 3                                                 []  realDonaldTrump
# 4  [{'id_str': '222196210', 'id': 222196210, 'ind...  realDonaldTrump

# %% [markdown]
# #### Pesquisando tweets
#
# A API do Twitter fornece ainda acesso à pesquisa de tweets usando termos ou *hashtags*.
# A descrição completa de como elaborar termos de busca pode ser encontrada em https://dev.twitter.com/rest/public/search. O acesso é fornecido em Tweepy pelo método [`search`](http://docs.tweepy.org/en/v3.5.0/api.html#API.search) da classe API.
#
# A documentação de Tweepy traz a seguinte descrição
#
# ```python
# API.search(q[, lang][, locale][, rpp][, page][, since_id][, geocode][, show_user])
# ```
#
# Contudo, os parâmetros descritos estão desatualizados. A documentação do código traz a lista atual de parâmetros, conforme descrição da API do Twitter. São eles:
#
# ```python
# 'q', 'lang', 'locale', 'since_id', 'geocode',
#              'max_id', 'since', 'until', 'result_type', 'count',
#               'include_entities', 'from', 'to', 'source'
# ```
#
# Verifique https://dev.twitter.com/rest/reference/get/search/tweets para ver a descrição de cada um dos parâmetros.

# %%
tweetsDataScience = api.search('#datascience',count=100,result_type="recent")
len(tweetsDataScience)
# Out:
# 100

# %%
tweetsDataScience
# Out:
# [Status(entities={'user_mentions': [{'screen_name': 'AusDATAcentre', 'name': 'DataCentreTech', 'id_str': '830060806666670081', 'id': 830060806666670081, 'indices': [3, 17]}], 'hashtags': [{'indices': [41, 64], 'text': 'ArtificialIntelligence'}, {'indices': [66, 69], 'text': 'ai'}, {'indices': [71, 87], 'text': 'machinelearning'}, {'indices': [89, 97], 'text': 'bigdata'}, {'indices': [99, 103], 'text': 'iot'}, {'indices': [105, 118], 'text': 'deeplearning'}, {'indices': [120, 132], 'text': 'datascience'}], 'symbols': [], 'urls': []}, text='RT @AusDATAcentre: CONPUTER OR COMPUTER?\n#ArtificialIntelligence \n#ai \n#machinelearning \n#bigdata \n#iot \n#deeplearning \n#datascience \n#robo…', retweeted_status=Status(entities={'user_mentions': [], 'hashtags': [{'indices': [22, 45], 'text': 'ArtificialIntelligence'}, {'indices': [47, 50], 'text': 'ai'}, {'indices': [52, 68], 'text': 'machinelearning'}, {'indices': [70, 78], 'text': 'bigdata'}, {'indices': [80, 84], 'text': 'iot'}, {'indices': [86, 99], 'text': 'deeplearning'}, {'indices': [101, 113], 'text': 'datascience'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/8…', 'indices': [115, 138], 'url': 'https://t.co/zYAOuMZhAW', 'expanded_url': 'https://twitter.com/i/web/status/849029491523555328'}]}, text='CONPUTER OR COMPUTER?\n#ArtificialIntelligence \n#ai \n#machinelearning \n#bigdata \n#iot \n#deeplearning \n#datascience… https://t.co/zYAOuMZhAW', favorite_count=0, in_reply_to_status_id=None, retweet_count=5, id_str='849029491523555328', in_reply_to_user_id=None, author=User(profile_image_url_https='https://pbs.twimg.com/profile_images/830066290517737474/UFcbjD47_normal.jpg', screen_name='AusDATAcentre', profile_text_color='333333', profile_background_image_url_https=None, id_str='830060806666670081', profile_link_color='1DA1F2', profile_sidebar_fill_color='DDEEF6', notifications=False, profile_sidebar_border_color='C0DEED', translator_type='none', name='DataCentreTech', profile_banner_url='https://pbs.twimg.com/profile_banners/830060806666670081/1491030244', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=830060806666670081, followers_count=1076, follow_request_sent=False, location='Brisbane, Queensland', entities={'description': {'urls': []}}, verified=False, geo_enabled=False, profile_background_image_url=None, friends_count=4467, favourites_count=386, _json={'entities': {'description': {'urls': []}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830066290517737474/UFcbjD47_normal.jpg', 'verified': False, 'geo_enabled': False, 'profile_background_image_url': None, 'profile_text_color': '333333', 'friends_count': 4467, 'favourites_count': 386, 'id_str': '830060806666670081', 'profile_link_color': '1DA1F2', 'following': False, 'has_extended_profile': True, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/830066290517737474/UFcbjD47_normal.jpg', 'profile_sidebar_border_color': 'C0DEED', 'is_translator': False, 'name': 'DataCentreTech', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/830060806666670081/1491030244', 'profile_background_image_url_https': None, 'is_translation_enabled': False, 'time_zone': None, 'lang': 'en', 'default_profile': True, 'url': None, 'follow_request_sent': False, 'created_at': 'Fri Feb 10 14:28:12 +0000 2017', 'statuses_count': 504, 'id': 830060806666670081, 'followers_count': 1076, 'screen_name': 'AusDATAcentre', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_background_tile': False, 'utc_offset': None, 'location': 'Brisbane, Queensland', 'profile_use_background_image': True, 'profile_background_color': 'F5F8FA', 'listed_count': 14, 'default_profile_image': False, 'translator_type': 'none', 'description': "Australia's premier Data Centre Experts. We'll sort your Data Centre out and help you make better business decisions. oh, and #iot. #internet of things"}, following=False,  ...
#  Status(entities={'user_mentions': [], 'hashtags': [{'indices': [37, 49], 'text': 'DataScience'}, {'indices': [50, 58], 'text': 'bigdata'}, {'indices': [59, 67], 'text': 'Fintech'}, {'indices': [69, 82], 'text': 'DeepLearning'}, {'indices': [83, 86], 'text': 'AI'}, {'indices': [87, 98], 'text': 'Algorithms'}, {'indices': [99, 105], 'text': 'FinAI'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/8…', 'indices': [107, 130], 'url': 'https://t.co/ct8iarzLjm', 'expanded_url': 'https://twitter.com/i/web/status/849031208969412609'}]}, text='tp://RagingFX.com   Report for Apr 2 #DataScience #bigdata #Fintech  #DeepLearning #AI #Algorithms #FinAI… https://t.co/ct8iarzLjm', favorite_count=0, in_reply_to_status_id=None, retweet_count=0, id_str='849031208969412609', in_reply_to_user_id=None, author=User(profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', screen_name='AlertsRagingFX', profile_text_color='333333', profile_background_image_url_https=None, id_str='717581949280382977', profile_link_color='1DA1F2', profile_sidebar_fill_color='DDEEF6', notifications=False, profile_sidebar_border_color='C0DEED', translator_type='none', name='Tom Kadala', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=717581949280382977, followers_count=12, follow_request_sent=False, location='', entities={'url': {'urls': [{'display_url': 'RagingFX.com', 'indices': [0, 23], 'url': 'https://t.co/U7r3ri75MB', 'expanded_url': 'http://www.RagingFX.com'}]}, 'description': {'urls': []}}, verified=False, geo_enabled=False, profile_background_image_url=None, friends_count=2, favourites_count=0, _json={'entities': {'url': {'urls': [{'display_url': 'RagingFX.com', 'indices': [0, 23], 'url': 'https://t.co/U7r3ri75MB', 'expanded_url': 'http://www.RagingFX.com'}]}, 'description': {'urls': []}}, 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'verified': False, 'geo_enabled': False, 'profile_background_image_url': None, 'profile_text_color': '333333', 'friends_count': 2, 'favourites_count': 0, 'id_str': '717581949280382977', 'profile_link_color': '1DA1F2', 'following': False, 'has_extended_profile': False, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_sidebar_border_color': 'C0DEED', 'is_translator': False, 'name': 'Tom Kadala', 'default_profile_image': True, 'profile_background_image_url_https': None, 'is_translation_enabled': False, 'time_zone': 'Pacific Time (US & Canada)', 'lang': 'en', 'default_profile': True, 'url': 'https://t.co/U7r3ri75MB', 'follow_request_sent': False, 'created_at': 'Wed Apr 06 05:17:23 +0000 2016', 'statuses_count': 93, 'id': 717581949280382977, 'followers_count': 12, 'screen_name': 'AlertsRagingFX', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_background_tile': False, 'utc_offset': -25200, 'location': '', 'profile_use_background_image': True, 'profile_background_color': 'F5F8FA', 'listed_count': 35, 'translator_type': 'none', 'description': ''}, following=False, has_extended_profile=False, contributors_enabled=False, protected=False, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', is_translator=False, time_zone='Pacific Time (US & Canada)', default_profile=True, url='https://t.co/U7r3ri75MB', created_at=datetime.datetime(2016, 4, 6, 5, 17, 23), statuses_count=93, profile_background_tile=False, utc_offset=-25200, profile_use_background_image=True, profile_background_color='F5F8FA', listed_count=35, default_profile_image=True, description=''), in_reply_to_status_id_str=None, retweeted=False, favorited=False, _json={'entities': {'user_mentions': [], 'hashtags': [{'indices': [37, 49], 'text': 'DataScience'}, {'indices': [50, 58], 'text': 'bigdata'}, {'indices': [59, 67], 'text': 'Fintech' ...
#  Status(entities={'user_mentions': [{'screen_name': 'Storagepedia', 'name': 'Paul Joyce', 'id_str': '2192915707', 'id': 2192915707, 'indices': [0, 13]}], 'hashtags': [{'indices': [75, 83], 'text': 'BigData'}, {'indices': [88, 100], 'text': 'DataScience'}, {'indices': [110, 133], 'text': 'BusinessTransformation'}], 'symbols': [], 'urls': []}, text='@Storagepedia Thanks for sharing Paul! Great discussion about how leverage #BigData and #DataScience to power #BusinessTransformation', favorite_count=0, in_reply_to_status_id=848947686980042753, retweet_count=0, id_str='849031181307830273', in_reply_to_user_id=2192915707, author=User(profile_image_url_https='https://pbs.twimg.com/profile_images/417527060760764417/1sx3EDer_normal.jpeg', screen_name='schmarzo', profile_text_color='333333', profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/378800000116141153/f3bd6d681495459474bd5c7a14c180ac.jpeg', id_str='14083628', profile_link_color='0084B4', profile_sidebar_fill_color='DDEEF6', notifications=False, profile_sidebar_border_color='FFFFFF', translator_type='none', name='Dean of Big Data', profile_banner_url='https://pbs.twimg.com/profile_banners/14083628/1460685000', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=14083628, followers_count=8741, follow_request_sent=False, location='Northern California', entities={'url': {'urls': [{'display_url': 'infocus.emc.com/author/william…', 'indices': [0, 22], 'url': 'http://t.co/qB7a4mzBsy', 'expanded_url': 'http://infocus.emc.com/author/william_schmarzo/'}]}, 'description': {'urls': [{'display_url': 'infocus.emc.com/author/william…', 'indices': [92, 115], 'url': 'https://t.co/SKryBf15YZ', 'expanded_url': 'https://infocus.emc.com/author/william_schmarzo/'}]}}, verified=False, geo_enabled=True, profile_background_image_url='http://pbs.twimg.com/profile_background_images/378800000116141153/f3bd6d681495459474bd5c7a14c180ac.jpeg', friends_count=7411, favourites_count=3917, _json={'entities': {'url': {'urls': [{'display_url': 'infocus.emc.com/author/william…', 'indices': [0, 22], 'url': 'http://t.co/qB7a4mzBsy', 'expanded_url': 'http://infocus.emc.com/author/william_schmarzo/'}]}, 'description': {'urls': [{'display_url': 'infocus.emc.com/author/william…', 'indices': [92, 115], 'url': 'https://t.co/SKryBf15YZ', 'expanded_url': 'https://infocus.emc.com/author/william_schmarzo/'}]}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/417527060760764417/1sx3EDer_normal.jpeg', 'verified': False, 'geo_enabled': True, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000116141153/f3bd6d681495459474bd5c7a14c180ac.jpeg', 'profile_text_color': '333333', 'friends_count': 7411, 'favourites_count': 3917, 'id_str': '14083628', 'profile_link_color': '0084B4', 'following': False, 'has_extended_profile': False, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/417527060760764417/1sx3EDer_normal.jpeg', 'profile_sidebar_border_color': 'FFFFFF', 'is_translator': False, 'name': 'Dean of Big Data', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14083628/1460685000', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000116141153/f3bd6d681495459474bd5c7a14c180ac.jpeg', 'is_translation_enabled': False, 'time_zone': 'Pacific Time (US & Canada)', 'lang': 'en', 'default_profile': False, 'url': 'http://t.co/qB7a4mzBsy', 'follow_request_sent': False, 'created_at': 'Wed Mar 05 15:53:35 +0000 2008', 'statuses_count': 8928, 'id': 14083628, 'followers_count': 8741, 'screen_name': 'schmarzo', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_background_tile': False, 'utc_offset': -25200, 'location': 'Northern California', 'profile_use_background_image': True, 'profile_background_color': 'C0DEED', 'listed_count': 790, 'default_profile_image': False, 'translator_type': 'none', ' ...
#  Status(entities={'user_mentions': [{'screen_name': 'ShaunVosper', 'name': 'ShaunVosper', 'id_str': '830005193551015936', 'id': 830005193551015936, 'indices': [3, 15]}], 'hashtags': [{'indices': [50, 53], 'text': 'ai'}, {'indices': [55, 71], 'text': 'machinelearning'}, {'indices': [73, 81], 'text': 'bigdata'}, {'indices': [83, 87], 'text': 'iot'}, {'indices': [89, 102], 'text': 'deeplearning'}, {'indices': [104, 116], 'text': 'datascience'}, {'indices': [118, 125], 'text': 'robots'}, {'indices': [126, 132], 'text': 'robot'}], 'symbols': [], 'urls': []}, text='RT @ShaunVosper: I, ROBOT\nArtificialIntelligence \n#ai \n#machinelearning \n#bigdata \n#iot \n#deeplearning \n#datascience \n#robots\n#robot https:…', retweeted_status=Status(entities={'media': [{'display_url': 'pic.twitter.com/J236uitn5k', 'url': 'https://t.co/J236uitn5k', 'media_url': 'http://pbs.twimg.com/media/C8hbWjAWAAApZXm.jpg', 'type': 'photo', 'sizes': {'large': {'w': 1705, 'resize': 'fit', 'h': 1147}, 'medium': {'w': 1200, 'resize': 'fit', 'h': 807}, 'small': {'w': 680, 'resize': 'fit', 'h': 457}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'id': 849028972671270912, 'media_url_https': 'https://pbs.twimg.com/media/C8hbWjAWAAApZXm.jpg', 'id_str': '849028972671270912', 'indices': [116, 139], 'expanded_url': 'https://twitter.com/ShaunVosper/status/849028983140343809/photo/1'}], 'user_mentions': [], 'hashtags': [{'indices': [33, 36], 'text': 'ai'}, {'indices': [38, 54], 'text': 'machinelearning'}, {'indices': [56, 64], 'text': 'bigdata'}, {'indices': [66, 70], 'text': 'iot'}, {'indices': [72, 85], 'text': 'deeplearning'}, {'indices': [87, 99], 'text': 'datascience'}, {'indices': [101, 108], 'text': 'robots'}, {'indices': [109, 115], 'text': 'robot'}], 'symbols': [], 'urls': []}, text='I, ROBOT\nArtificialIntelligence \n#ai \n#machinelearning \n#bigdata \n#iot \n#deeplearning \n#datascience \n#robots\n#robot https://t.co/J236uitn5k', favorite_count=4, in_reply_to_status_id=None, retweet_count=4, id_str='849028983140343809', in_reply_to_user_id=None, author=User(profile_image_url_https='https://pbs.twimg.com/profile_images/830037728041562112/v9KSLYO-_normal.jpg', screen_name='ShaunVosper', profile_text_color='333333', profile_background_image_url_https=None, id_str='830005193551015936', profile_link_color='1DA1F2', profile_sidebar_fill_color='DDEEF6', notifications=False, profile_sidebar_border_color='C0DEED', translator_type='none', name='ShaunVosper', profile_banner_url='https://pbs.twimg.com/profile_banners/830005193551015936/1491030293', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=830005193551015936, followers_count=286, follow_request_sent=False, location='Brisbane, Queensland', entities={'url': {'urls': [{'display_url': 'dctechnologies.com.au', 'indices': [0, 23], 'url': 'https://t.co/FzVKRGKJZF', 'expanded_url': 'http://www.dctechnologies.com.au'}]}, 'description': {'urls': []}}, verified=False, geo_enabled=False, profile_background_image_url=None, friends_count=941, favourites_count=362, _json={'entities': {'url': {'urls': [{'display_url': 'dctechnologies.com.au', 'indices': [0, 23], 'url': 'https://t.co/FzVKRGKJZF', 'expanded_url': 'http://www.dctechnologies.com.au'}]}, 'description': {'urls': []}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830037728041562112/v9KSLYO-_normal.jpg', 'verified': False, 'geo_enabled': False, 'profile_background_image_url': None, 'profile_text_color': '333333', 'friends_count': 941, 'favourites_count': 362, 'id_str': '830005193551015936', 'profile_link_color': '1DA1F2', 'following': False, 'has_extended_profile': True, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/830037728041562112/v9KSLYO-_normal.jpg', 'profile_sidebar_border_color': 'C0DEED', 'is_translator': False, 'name': 'ShaunVosper', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/830005193551015936/14 ...
#  Status(entities={'user_mentions': [{'screen_name': 'ygaudry', 'name': 'yoann', 'id_str': '74780115', 'id': 74780115, 'indices': [3, 11]}], 'hashtags': [{'indices': [89, 97], 'text': 'BigData'}, {'indices': [98, 114], 'text': 'MachineLearning'}, {'indices': [115, 127], 'text': 'DataScience'}], 'symbols': [], 'urls': []}, text='RT @ygaudry: RT gp_pulipaka: Blockchain Market Research Report: Global Forecast to 2021. #BigData #MachineLearning #DataScience… https://t.…', retweeted_status=Status(entities={'user_mentions': [], 'hashtags': [{'indices': [76, 84], 'text': 'BigData'}, {'indices': [85, 101], 'text': 'MachineLearning'}, {'indices': [102, 114], 'text': 'DataScience'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/8…', 'indices': [116, 139], 'url': 'https://t.co/OWJs1rfebw', 'expanded_url': 'https://twitter.com/i/web/status/816470712353488897'}]}, text='RT gp_pulipaka: Blockchain Market Research Report: Global Forecast to 2021. #BigData #MachineLearning #DataScience… https://t.co/OWJs1rfebw', favorite_count=0, in_reply_to_status_id=None, retweet_count=1, id_str='849030901052977153', in_reply_to_user_id=None, author=User(profile_image_url_https='https://pbs.twimg.com/profile_images/822091614554386434/tSNcwCf3_normal.jpg', screen_name='ygaudry', profile_text_color='000000', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', id_str='74780115', profile_link_color='E3B87D', profile_sidebar_fill_color='000000', notifications=False, profile_sidebar_border_color='000000', translator_type='none', name='yoann', profile_banner_url='https://pbs.twimg.com/profile_banners/74780115/1483305348', is_translation_enabled=False, lang='fr', _api=<tweepy.api.API object at 0x11117dcc0>, id=74780115, followers_count=5036, follow_request_sent=False, location='Paris, France', entities={'url': {'urls': [{'display_url': 'fablife.com', 'indices': [0, 23], 'url': 'https://t.co/B7fTyuQYm0', 'expanded_url': 'http://www.fablife.com'}]}, 'description': {'urls': []}}, verified=False, geo_enabled=True, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', friends_count=3097, favourites_count=1221, _json={'entities': {'url': {'urls': [{'display_url': 'fablife.com', 'indices': [0, 23], 'url': 'https://t.co/B7fTyuQYm0', 'expanded_url': 'http://www.fablife.com'}]}, 'description': {'urls': []}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822091614554386434/tSNcwCf3_normal.jpg', 'verified': False, 'geo_enabled': True, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_text_color': '000000', 'friends_count': 3097, 'favourites_count': 1221, 'id_str': '74780115', 'profile_link_color': 'E3B87D', 'following': False, 'has_extended_profile': False, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/822091614554386434/tSNcwCf3_normal.jpg', 'profile_sidebar_border_color': '000000', 'is_translator': False, 'name': 'yoann', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/74780115/1483305348', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'is_translation_enabled': False, 'time_zone': 'Paris', 'lang': 'fr', 'default_profile': False, 'url': 'https://t.co/B7fTyuQYm0', 'follow_request_sent': False, 'created_at': 'Wed Sep 16 17:07:17 +0000 2009', 'statuses_count': 58778, 'id': 74780115, 'followers_count': 5036, 'screen_name': 'ygaudry', 'profile_sidebar_fill_color': '000000', 'profile_background_tile': False, 'utc_offset': 7200, 'location': 'Paris, France', 'profile_use_background_image': False, 'profile_background_color': '000000', 'listed_count': 2690, 'default_profile_image': False, 'translator_type': 'none', 'description': 'COO @weareFabLifers, passionate about innovation & digital marketing. Dad, runner, traveler | #marketing | #SMM | #growthhacking | #UX | #strategy | #innovation'}, following ...
#  Status(entities={'user_mentions': [], 'hashtags': [{'indices': [76, 84], 'text': 'BigData'}, {'indices': [85, 101], 'text': 'MachineLearning'}, {'indices': [102, 114], 'text': 'DataScience'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/8…', 'indices': [116, 139], 'url': 'https://t.co/OWJs1rfebw', 'expanded_url': 'https://twitter.com/i/web/status/816470712353488897'}]}, text='RT gp_pulipaka: Blockchain Market Research Report: Global Forecast to 2021. #BigData #MachineLearning #DataScience… https://t.co/OWJs1rfebw', favorite_count=0, in_reply_to_status_id=None, retweet_count=1, id_str='849030901052977153', in_reply_to_user_id=None, author=User(profile_image_url_https='https://pbs.twimg.com/profile_images/822091614554386434/tSNcwCf3_normal.jpg', screen_name='ygaudry', profile_text_color='000000', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', id_str='74780115', profile_link_color='E3B87D', profile_sidebar_fill_color='000000', notifications=False, profile_sidebar_border_color='000000', translator_type='none', name='yoann', profile_banner_url='https://pbs.twimg.com/profile_banners/74780115/1483305348', is_translation_enabled=False, lang='fr', _api=<tweepy.api.API object at 0x11117dcc0>, id=74780115, followers_count=5036, follow_request_sent=False, location='Paris, France', entities={'url': {'urls': [{'display_url': 'fablife.com', 'indices': [0, 23], 'url': 'https://t.co/B7fTyuQYm0', 'expanded_url': 'http://www.fablife.com'}]}, 'description': {'urls': []}}, verified=False, geo_enabled=True, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', friends_count=3097, favourites_count=1221, _json={'entities': {'url': {'urls': [{'display_url': 'fablife.com', 'indices': [0, 23], 'url': 'https://t.co/B7fTyuQYm0', 'expanded_url': 'http://www.fablife.com'}]}, 'description': {'urls': []}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822091614554386434/tSNcwCf3_normal.jpg', 'verified': False, 'geo_enabled': True, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_text_color': '000000', 'friends_count': 3097, 'favourites_count': 1221, 'id_str': '74780115', 'profile_link_color': 'E3B87D', 'following': False, 'has_extended_profile': False, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/822091614554386434/tSNcwCf3_normal.jpg', 'profile_sidebar_border_color': '000000', 'is_translator': False, 'name': 'yoann', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/74780115/1483305348', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'is_translation_enabled': False, 'time_zone': 'Paris', 'lang': 'fr', 'default_profile': False, 'url': 'https://t.co/B7fTyuQYm0', 'follow_request_sent': False, 'created_at': 'Wed Sep 16 17:07:17 +0000 2009', 'statuses_count': 58778, 'id': 74780115, 'followers_count': 5036, 'screen_name': 'ygaudry', 'profile_sidebar_fill_color': '000000', 'profile_background_tile': False, 'utc_offset': 7200, 'location': 'Paris, France', 'profile_use_background_image': False, 'profile_background_color': '000000', 'listed_count': 2690, 'default_profile_image': False, 'translator_type': 'none', 'description': 'COO @weareFabLifers, passionate about innovation & digital marketing. Dad, runner, traveler | #marketing | #SMM | #growthhacking | #UX | #strategy | #innovation'}, following=False, has_extended_profile=False, contributors_enabled=False, protected=False, profile_image_url='http://pbs.twimg.com/profile_images/822091614554386434/tSNcwCf3_normal.jpg', is_translator=False, time_zone='Paris', default_profile=False, url='https://t.co/B7fTyuQYm0', created_at=datetime.datetime(2009, 9, 16, 17, 7, 17), statuses_count=58778, profile_background_tile=False, utc_offset=7200, profile_use_background_image=False, profile_background_color='000000', listed_count=2690, def ...
#  Status(entities={'user_mentions': [{'screen_name': 'ShaunVosper', 'name': 'ShaunVosper', 'id_str': '830005193551015936', 'id': 830005193551015936, 'indices': [3, 15]}], 'hashtags': [{'indices': [50, 53], 'text': 'ai'}, {'indices': [55, 71], 'text': 'machinelearning'}, {'indices': [73, 81], 'text': 'bigdata'}, {'indices': [83, 87], 'text': 'iot'}, {'indices': [89, 102], 'text': 'deeplearning'}, {'indices': [104, 116], 'text': 'datascience'}, {'indices': [118, 125], 'text': 'robots'}, {'indices': [126, 132], 'text': 'robot'}], 'symbols': [], 'urls': []}, text='RT @ShaunVosper: I, ROBOT\nArtificialIntelligence \n#ai \n#machinelearning \n#bigdata \n#iot \n#deeplearning \n#datascience \n#robots\n#robot https:…', retweeted_status=Status(entities={'media': [{'display_url': 'pic.twitter.com/J236uitn5k', 'url': 'https://t.co/J236uitn5k', 'media_url': 'http://pbs.twimg.com/media/C8hbWjAWAAApZXm.jpg', 'type': 'photo', 'sizes': {'large': {'w': 1705, 'resize': 'fit', 'h': 1147}, 'medium': {'w': 1200, 'resize': 'fit', 'h': 807}, 'small': {'w': 680, 'resize': 'fit', 'h': 457}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'id': 849028972671270912, 'media_url_https': 'https://pbs.twimg.com/media/C8hbWjAWAAApZXm.jpg', 'id_str': '849028972671270912', 'indices': [116, 139], 'expanded_url': 'https://twitter.com/ShaunVosper/status/849028983140343809/photo/1'}], 'user_mentions': [], 'hashtags': [{'indices': [33, 36], 'text': 'ai'}, {'indices': [38, 54], 'text': 'machinelearning'}, {'indices': [56, 64], 'text': 'bigdata'}, {'indices': [66, 70], 'text': 'iot'}, {'indices': [72, 85], 'text': 'deeplearning'}, {'indices': [87, 99], 'text': 'datascience'}, {'indices': [101, 108], 'text': 'robots'}, {'indices': [109, 115], 'text': 'robot'}], 'symbols': [], 'urls': []}, text='I, ROBOT\nArtificialIntelligence \n#ai \n#machinelearning \n#bigdata \n#iot \n#deeplearning \n#datascience \n#robots\n#robot https://t.co/J236uitn5k', favorite_count=4, in_reply_to_status_id=None, retweet_count=4, id_str='849028983140343809', in_reply_to_user_id=None, author=User(profile_image_url_https='https://pbs.twimg.com/profile_images/830037728041562112/v9KSLYO-_normal.jpg', screen_name='ShaunVosper', profile_text_color='333333', profile_background_image_url_https=None, id_str='830005193551015936', profile_link_color='1DA1F2', profile_sidebar_fill_color='DDEEF6', notifications=False, profile_sidebar_border_color='C0DEED', translator_type='none', name='ShaunVosper', profile_banner_url='https://pbs.twimg.com/profile_banners/830005193551015936/1491030293', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=830005193551015936, followers_count=286, follow_request_sent=False, location='Brisbane, Queensland', entities={'url': {'urls': [{'display_url': 'dctechnologies.com.au', 'indices': [0, 23], 'url': 'https://t.co/FzVKRGKJZF', 'expanded_url': 'http://www.dctechnologies.com.au'}]}, 'description': {'urls': []}}, verified=False, geo_enabled=False, profile_background_image_url=None, friends_count=941, favourites_count=362, _json={'entities': {'url': {'urls': [{'display_url': 'dctechnologies.com.au', 'indices': [0, 23], 'url': 'https://t.co/FzVKRGKJZF', 'expanded_url': 'http://www.dctechnologies.com.au'}]}, 'description': {'urls': []}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830037728041562112/v9KSLYO-_normal.jpg', 'verified': False, 'geo_enabled': False, 'profile_background_image_url': None, 'profile_text_color': '333333', 'friends_count':
is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=14083628, followers_count=8741, follow_request_sent=False, location='Northern California', entities={'url': {'urls': [{'display_url': 'infocus.emc.com/author/william…', 'indices': [0, 22], 'url': 'http://t.co/qB7a4mzBsy', 'expanded_url': 'http://infocus.emc.com/author/william_schmarzo/'}]}, 'description': {'urls': [{'display_url': 'infocus.emc.com/author/william…', 'indices': [92, 115], 'url': 'https://t.co/SKryBf15YZ', 'expanded_url': 'https://infocus.emc.com/author/william_schmarzo/'}]}}, verified=False, geo_enabled=True, profile_background_image_url='http://pbs.twimg.com/profile_background_images/378800000116141153/f3bd6d681495459474bd5c7a14c180ac.jpeg', friends_count=7411, favourites_count=3917, _json={'entities': {'url': {'urls': [{'display_url': 'infocus.emc.com/author/william…', 'indices': [0, 22], 'url': 'http://t.co/qB7a4mzBsy', 'expanded_url': 'http://infocus.emc.com/author/william_schmarzo/'}]}, 'description': {'urls': [{'display_url': 'infocus.emc.com/author/william…', 'indices': [92, 115], 'url': 'https://t.co/SKryBf15YZ', 'expanded_url': 'https://infocus.emc.com/author/william_schmarzo/'}]}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/417527060760764417/1sx3EDer_normal.jpeg', 'verified': False, 'geo_enabled': True, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000116141153/f3bd6d681495459474bd5c7a14c180ac.jpeg', 'profile_text_color': '333333', 'friends_count': 7411, 'favourites_count': 3917, 'id_str': '14083628', 'profile_link_color': '0084B4', 'following': False, 'has_extended_profile': False, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/417527060760764417/1sx3EDer_normal.jpeg', 'profile_sidebar_border_color': 'FFFFFF', 'is_translator': False, 'name': 'Dean of Big Data', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14083628/1460685000', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000116141153/f3bd6d681495459474bd5c7a14c180ac.jpeg', 'is_translation_enabled': False, 'time_zone': 'Pacific Time (US & Canada)', 'lang': 'en', 'default_profile': False, 'url': 'http://t.co/qB7a4mzBsy', 'follow_request_sent': False, 'created_at': 'Wed Mar 05 15:53:35 +0000 2008', 'statuses_count': 8928, 'id': 14083628, 'followers_count': 8741, 'screen_name': 'schmarzo', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_background_tile': False, 'utc_offset': -25200, 'location': 'Northern California', 'profile_use_background_image': True, 'profile_background_color': 'C0DEED', 'listed_count': 790, 'default_profile_image': False, 'translator_type': 'none', 'description': '#BigData author, Dell EMC CTO, former VP Yahoo Analytics, USF Executive Fellow #DataScience https: ...
#  Status(entities={'user_mentions': [{'screen_name': 'ShaunVosper', 'name': 'ShaunVosper', 'id_str': '830005193551015936', 'id': 830005193551015936, 'indices': [3, 15]}], 'hashtags': [{'indices': [50, 53], 'text': 'ai'}, {'indices': [55, 71], 'text': 'machinelearning'}, {'indices': [73, 81], 'text': 'bigdata'}, {'indices': [83, 87], 'text': 'iot'}, {'indices': [89, 102], 'text': 'deeplearning'}, {'indices': [104, 116], 'text': 'datascience'}, {'indices': [118, 125], 'text': 'robots'}, {'indices': [126, 132], 'text': 'robot'}], 'symbols': [], 'urls': []}, text='RT @ShaunVosper: I, ROBOT\nArtificialIntelligence \n#ai \n#machinelearning \n#bigdata \n#iot \n#deeplearning \n#datascience \n#robots\n#robot https:…', retweeted_status=Status(entities={'media': [{'display_url': 'pic.twitter.com/J236uitn5k', 'url': 'https://t.co/J236uitn5k', 'media_url': 'http://pbs.twimg.com/media/C8hbWjAWAAApZXm.jpg', 'type': 'photo', 'sizes': {'large': {'w': 1705, 'resize': 'fit', 'h': 1147}, 'medium': {'w': 1200, 'resize': 'fit', 'h': 807}, 'small': {'w': 680, 'resize': 'fit', 'h': 457}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'id': 849028972671270912, 'media_url_https': 'https://pbs.twimg.com/media/C8hbWjAWAAApZXm.jpg', 'id_str': '849028972671270912', 'indices': [116, 139], 'expanded_url': 'https://twitter.com/ShaunVosper/status/849028983140343809/photo/1'}], 'user_mentions': [], 'hashtags': [{'indices': [33, 36], 'text': 'ai'}, {'indices': [38, 54], 'text': 'machinelearning'}, {'indices': [56, 64], 'text': 'bigdata'}, {'indices': [66, 70], 'text': 'iot'}, {'indices': [72, 85], 'text': 'deeplearning'}, {'indices': [87, 99], 'text': 'datascience'}, {'indices': [101, 108], 'text': 'robots'}, {'indices': [109, 115], 'text': 'robot'}], 'symbols': [], 'urls': []}, text='I, ROBOT\nArtificialIntelligence \n#ai \n#machinelearning \n#bigdata \n#iot \n#deeplearning \n#datascience \n#robots\n#robot https://t.co/J236uitn5k', favorite_count=4, in_reply_to_status_id=None, retweet_count=4, id_str='849028983140343809', in_reply_to_user_id=None, author=User(profile_image_url_https='https://pbs.twimg.com/profile_images/830037728041562112/v9KSLYO-_normal.jpg', screen_name='ShaunVosper', profile_text_color='333333', profile_background_image_url_https=None, id_str='830005193551015936', profile_link_color='1DA1F2', profile_sidebar_fill_color='DDEEF6', notifications=False, profile_sidebar_border_color='C0DEED', translator_type='none', name='ShaunVosper', profile_banner_url='https://pbs.twimg.com/profile_banners/830005193551015936/1491030293', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=830005193551015936, followers_count=286, follow_request_sent=False, location='Brisbane, Queensland', entities={'url': {'urls': [{'display_url': 'dctechnologies.com.au', 'indices': [0, 23], 'url': 'https://t.co/FzVKRGKJZF', 'expanded_url': 'http://www.dctechnologies.com.au'}]}, 'description': {'urls': []}}, verified=False, geo_enabled=False, profile_background_image_url=None, friends_count=941, favourites_count=362, _json={'entities': {'url': {'urls': [{'display_url': 'dctechnologies.com.au', 'indices': [0, 23], 'url': 'https://t.co/FzVKRGKJZF', 'expanded_url': 'http://www.dctechnologies.com.au'}]}, 'description': {'urls': []}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830037728041562112/v9KSLYO-_normal.jpg', 'verified': False, 'geo_enabled': False, 'profile_background_image_url': None, 'profile_text_color': '333333', 'friends_count': 941, 'favourites_count': 362, 'id_str': '830005193551015936', 'profile_link_color': '1DA1F2', 'following': False, 'has_extended_profile': True, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/830037728041562112/v9KSLYO-_normal.jpg', 'profile_sidebar_border_color': 'C0DEED', 'is_translator': False, 'name': 'ShaunVosper', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/830005193551015936/14 ...
#  Status(entities={'user_mentions': [{'screen_name': 'AusDATAcentre', 'name': 'DataCentreTech', 'id_str': '830060806666670081', 'id': 830060806666670081, 'indices': [3, 17]}], 'hashtags': [{'indices': [41, 64], 'text': 'ArtificialIntelligence'}, {'indices': [66, 69], 'text': 'ai'}, {'indices': [71, 87], 'text': 'machinelearning'}, {'indices': [89, 97], 'text': 'bigdata'}, {'indices': [99, 103], 'text': 'iot'}, {'indices': [105, 118], 'text': 'deeplearning'}, {'indices': [120, 132], 'text': 'datascience'}], 'symbols': [], 'urls': []}, text='RT @AusDATAcentre: CONPUTER OR COMPUTER?\n#ArtificialIntelligence \n#ai \n#machinelearning \n#bigdata \n#iot \n#deeplearning \n#datascience \n#robo…', retweeted_status=Status(entities={'user_mentions': [], 'hashtags': [{'indices': [22, 45], 'text': 'ArtificialIntelligence'}, {'indices': [47, 50], 'text': 'ai'}, {'indices': [52, 68], 'text': 'machinelearning'}, {'indices': [70, 78], 'text': 'bigdata'}, {'indices': [80, 84], 'text': 'iot'}, {'indices': [86, 99], 'text': 'deeplearning'}, {'indices': [101, 113], 'text': 'datascience'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/8…', 'indices': [115, 138], 'url': 'https://t.co/zYAOuMZhAW', 'expanded_url': 'https://twitter.com/i/web/status/849029491523555328'}]}, text='CONPUTER OR COMPUTER?\n#ArtificialIntelligence \n#ai \n#machinelearning \n#bigdata \n#iot \n#deeplearning \n#datascience… https://t.co/zYAOuMZhAW', favorite_count=0, in_reply_to_status_id=None, retweet_count=5, id_str='849029491523555328', in_reply_to_user_id=None, author=User(profile_image_url_https='https://pbs.twimg.com/profile_images/830066290517737474/UFcbjD47_normal.jpg', screen_name='AusDATAcentre', profile_text_color='333333', profile_background_image_url_https=None, id_str='830060806666670081', profile_link_color='1DA1F2', profile_sidebar_fill_color='DDEEF6', notifications=False, profile_sidebar_border_color='C0DEED', translator_type='none', name='DataCentreTech', profile_banner_url='https://pbs.twimg.com/profile_banners/830060806666670081/1491030244', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=830060806666670081, followers_count=1076, follow_request_sent=False, location='Brisbane, Queensland', entities={'description': {'urls': []}}, verified=False, geo_enabled=False, profile_background_image_url=None, friends_count=4467, favourites_count=386, _json={'entities': {'description': {'urls': []}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830066290517737474/UFcbjD47_normal.jpg', 'verified': False, 'geo_enabled': False, 'profile_background_image_url': None, 'profile_text_color': '333333', 'friends_count': 4467, 'favourites_count': 386, 'id_str': '830060806666670081', 'profile_link_color': '1DA1F2', 'following': False, 'has_extended_profile': True, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/830066290517737474/UFcbjD47_normal.jpg', 'profile_sidebar_border_color': 'C0DEED', 'is_translator': False, 'name': 'DataCentreTech', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/830060806666670081/1491030244', 'profile_background_image_url_https': None, 'is_translation_enabled': False, 'time_zone': None, 'lang': 'en', 'default_profile': True, 'url': None, 'follow_request_sent': False, 'created_at': 'Fri Feb 10 14:28:12 +0000 2017', 'statuses_count': 504, 'id': 830060806666670081, 'followers_count': 1076, 'screen_name': 'AusDATAcentre', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_background_tile': False, 'utc_offset': None, 'location': 'Brisbane, Queensland', 'profile_use_background_image': True, 'profile_background_color': 'F5F8FA', 'listed_count': 14, 'default_profile_image': False, 'translator_type': 'none', 'description': "Australia's premier Data Centre Experts. We'll sort your Data Centre out and help you make better business decisions. oh, and #iot. #internet of things"}, following=False,  ...
# ...
 'text': 'datascience'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/gavin_kickstar…', 'indices': [67, 90], 'url': 'https://t.co/H95Pt7cDlj', 'expanded_url': 'https://twitter.com/gavin_kickstart/status/849015240683540480'}]}, text='If you like skiing and #datascience you really should live in Utah https://t.co/H95Pt7cDlj', quoted_status_id=849015240683540480, favorite_count=1, in_reply_to_status_id=None, retweet_count=1, id_str='849023071889440770', quoted_status_id_str='849015240683540480', in_reply_to_user_id=None, author=User(profile_image_url_https='https://pbs.twimg.com/profile_images/605110708162854912/QJc4xsRr_normal.jpg', screen_name='datagonzo', profile_text_color='000000', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme5/bg.gif', id_str='21104170', profile_link_color='4DB80E', profile_sidebar_fill_color='000000', notifications=False, profile_sidebar_border_color='000000', translator_type='none', name='Gonzo', profile_banner_url='https://pbs.twimg.com/profile_banners/21104170/1358968333', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=21104170, followers_count=415, follow_request_sent=False, location='Provo, UT, USA', entities={'description': {'urls': []}}, verified=False, geo_enabled=True, profile_background_image_url='http://abs.twimg.com/images/themes/theme5/bg.gif', friends_count=142, favourites_count=1563, _json={'entities': {'description': {'urls': []}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/605110708162854912/QJc4xsRr_normal.jpg', 'verified': False, 'geo_enabled': True, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_text_color': '000000', 'friends_count': 142, 'favourites_count': 1563, 'id_str': '21104170', 'profile_link_color': '4DB80E', 'following': False, 'has_extended_profile': False, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/605110708162854912/QJc4xsRr_normal.jpg', 'profile_sidebar_border_color': '000000', 'is_translator': False, 'name': 'Gonzo', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21104170/1358968333', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif', 'is_translation_enabled': False, 'time_zone': 'Mountain Time (US & Canada)', 'lang': 'en', 'default_profile': False, 'url': None, 'follow_request_sent': False, 'created_at': 'Tue Feb 17 16:42:58 +0000 2009', 'statuses_count': 2096, 'id': 21104170, 'followers_count': 415, 'screen_name': 'datagonzo', 'profile_sidebar_fill_color': '000000', 'profile_background_tile': False, 'utc_offset': -21600, 'location': 'Provo, UT, USA', 'profile_use_background_image': False, 'profile_background_color': '000000', 'listed_count': 49, 'default_profile_image': False, 'translator_type': 'none', 'description': 'David Gonzo Gonzalez. Disciple of #datajesus. #datascience #storyteller #lego coach'}, following=False, has_extended_profile=False, contributors_enabled=False, protected=False, profile_image_url='http://pbs.twimg.com/profile_images/605110708162854912/QJc4xsRr_normal.jpg', is_translator=False, time_zone='Mountain Time (US & Canada)', default_profile=False, url=None, created_at=datetime.datetime(2009, 2, 17, 16, 42, 58), statuses_count=2096, profile_background_tile=False, utc_offset=-21600, profile_use_background_image=False, profile_background_color='000000', listed_count=49, default_profile_image=False, description='David Gonzo Gonzalez. Disciple of #datajesus. #datascience #storyteller #lego coach'), in_reply_to_status_id_str=None, retweeted=False, favorited=False, _json={'entities': {'user_mentions': [], 'hashtags': [{'indices': [23, 35], 'text': 'datascience'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/gavin_kickstar…', 'indices': [67, 90], 'url': 'https://t.co/H95Pt7cDlj', 'expa ...
#  Status(entities={'media': [{'display_url': 'pic.twitter.com/mQUPoyxYh9', 'url': 'https://t.co/mQUPoyxYh9', 'media_url': 'http://pbs.twimg.com/media/C8hVu2-U0AATLTj.jpg', 'type': 'photo', 'sizes': {'small': {'w': 625, 'resize': 'fit', 'h': 448}, 'large': {'w': 625, 'resize': 'fit', 'h': 448}, 'medium': {'w': 625, 'resize': 'fit', 'h': 448}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'id': 849022793278607360, 'media_url_https': 'https://pbs.twimg.com/media/C8hVu2-U0AATLTj.jpg', 'id_str': '849022793278607360', 'indices': [56, 79], 'expanded_url': 'https://twitter.com/nportillo/status/849022960853700608/photo/1'}], 'user_mentions': [], 'hashtags': [{'indices': [34, 42], 'text': 'bigdata'}, {'indices': [43, 55], 'text': 'datascience'}], 'symbols': [], 'urls': []}, text='The risk of become data driven :) #bigdata #datascience https://t.co/mQUPoyxYh9', favorite_count=2, in_reply_to_status_id=None, retweet_count=0, id_str='849022960853700608', in_reply_to_user_id=None, author=User(profile_image_url_https='https://pbs.twimg.com/profile_images/1313312906/portait_002small_normal.jpg', screen_name='nportillo', profile_text_color='000000', profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/527269817812676608/ScTTzKkI.jpeg', id_str='1474661', profile_link_color='0000FF', profile_sidebar_fill_color='E0FF92', notifications=False, profile_sidebar_border_color='87BC44', translator_type='none', name='Nestor J. Portillo', profile_banner_url='https://pbs.twimg.com/profile_banners/1474661/1398218152', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=1474661, followers_count=1532, follow_request_sent=False, location='Pacific Northwest - USA', entities={'url': {'urls': [{'display_url': 'about.me/nportillo', 'indices': [0, 23], 'url': 'https://t.co/HfEF5jTTCE', 'expanded_url': 'http://about.me/nportillo'}]}, 'description': {'urls': []}}, verified=False, geo_enabled=False, profile_background_image_url='http://pbs.twimg.com/profile_background_images/527269817812676608/ScTTzKkI.jpeg', friends_count=219, favourites_count=138, _json={'entities': {'url': {'urls': [{'display_url': 'about.me/nportillo', 'indices': [0, 23], 'url': 'https://t.co/HfEF5jTTCE', 'expanded_url': 'http://about.me/nportillo'}]}, 'description': {'urls': []}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1313312906/portait_002small_normal.jpg', 'verified': False, 'geo_enabled': False, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/527269817812676608/ScTTzKkI.jpeg', 'profile_text_color': '000000', 'friends_count': 219, 'favourites_count': 138, 'id_str': '1474661', 'profile_link_color': '0000FF', 'following': False, 'has_extended_profile': True, 'contributors_enabled': False, 'protected': False, 'notifications': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1313312906/portait_002small_normal.jpg', 'profile_sidebar_border_color': '87BC44', 'is_translator': False, 'name': 'Nestor J. Portillo', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1474661/1398218152', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/527269817812676608/ScTTzKkI.jpeg', 'is_translation_enabled': False, 'time_zone': 'America/Los_Angeles', 'lang': 'en', 'default_profile': False, 'url': 'https://t.co/HfEF5jTTCE', 'follow_request_sent': False, 'created_at': 'Mon Mar 19 05:43:48 +0000 2007', 'statuses_count': 2320, 'id': 1474661, 'followers_count': 1532, 'screen_name': 'nportillo', 'profile_sidebar_fill_color': 'E0FF92', 'profile_background_tile': False, 'utc_offset': -25200, 'location': 'Pacific Northwest - USA', 'profile_use_background_image': False, 'profile_background_color': '9AE4E8', 'listed_count': 151, 'default_profile_image': False, 'translator_type': 'none', 'description': 'Work for Cisco (tweets are my own). Communities expert, Influencer Strategist, Customer & employee Advocacy, Social Media Practitioner. Blog ...

# %% [markdown]
# O resultado novamente é uma lista de objetos do tipo `Status`, a qual podemos processar da mesma forma como fizemos com os tweets do Trump.

# %%
dfTweetsDataScience = pd.DataFrame(list(map(lambda x: filtra_campos(x._json),
                                            tweetsDataScience)))
dfTweetsDataScience.head()
# Out:
#                        created_at  favorite_count  \
# 0  Mon Apr 03 22:50:06 +0000 2017               0
# 1  Mon Apr 03 22:49:49 +0000 2017               0
# 2  Mon Apr 03 22:49:42 +0000 2017               0
# 3  Mon Apr 03 22:49:19 +0000 2017               0
# 4  Mon Apr 03 22:49:13 +0000 2017               0
#
#                                             hashtags                  id  \
# 0  [{'indices': [41, 64], 'text': 'ArtificialInte...  849031280889020416
# 1  [{'indices': [37, 49], 'text': 'DataScience'},...  849031208969412609
# 2  [{'indices': [75, 83], 'text': 'BigData'}, {'i...  849031181307830273
# 3  [{'indices': [50, 53], 'text': 'ai'}, {'indice...  849031084260048898
# 4  [{'indices': [89, 97], 'text': 'BigData'}, {'i...  849031061397012480
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_user_id lang  \
# 0                    None                    NaN                  NaN   en
# 1                    None                    NaN                  NaN   in
# 2            Storagepedia           8.489477e+17         2.192916e+09   en
# 3                    None                    NaN                  NaN   en
# 4                    None                    NaN                  NaN   en
#
#   media place_country place_name  retweet_count  \
# 0   NaN           NaN        NaN              5
# 1   NaN           NaN        NaN              0
# 2   NaN           NaN        NaN              0
# 3   NaN           NaN        NaN              4
# 4   NaN           NaN        NaN              1
#
#                                               source symbols  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...      []
# 1  <a href="http://twitter.com" rel="nofollow">Tw...      []
# 2  <a href="http://twitter.com" rel="nofollow">Tw...      []
# 3  <a href="http://twitter.com" rel="nofollow">Tw...      []
# 4  <a href="https://twitter.com/alevergara78" rel...      []
#
#                                                 text truncated  \
# 0  RT @AusDATAcentre: CONPUTER OR COMPUTER?\n#Art...     False
# 1  tp://RagingFX.com   Report for Apr 2 #DataScie...      True
# 2  @Storagepedia Thanks for sharing Paul! Great d...     False
# 3  RT @ShaunVosper: I, ROBOT\nArtificialIntellige...     False
# 4  RT @ygaudry: RT gp_pulipaka: Blockchain Market...     False
#
#                                                 urls             user_id  \
# 0                                                 []            68494106
# 1  [{'display_url': 'twitter.com/i/web/status/8…'...  717581949280382977
# 2                                                 []            14083628
# 3                                                 []            68494106
# 4                                                 []           104520454
#
#                                        user_mentions user_screen_name
# 0  [{'screen_name': 'AusDATAcentre', 'name': 'Dat...         Pedra999
# 1                                                 []   AlertsRagingFX
# 2  [{'screen_name': 'Storagepedia', 'name': 'Paul...         schmarzo
# 3  [{'screen_name': 'ShaunVosper', 'name': 'Shaun...         Pedra999
# 4  [{'screen_name': 'ygaudry', 'name': 'yoann', '...     alevergara78

# %% [markdown]
# Agora podemos iniciar nosso processamento. Podemos, por exemplo, identificar as mensagens mais interessantes, considerando o número de retweets.

# %%
dfTweetsDataScience.retweet_count.describe()
# Out:
# count    100.000000
# mean      14.860000
# std       28.489594
# min        0.000000
# 25%        1.000000
# 50%        3.500000
# 75%       16.000000
# max      179.000000
# Name: retweet_count, dtype: float64

# %%
[a for a in dfTweetsDataScience[\
    dfTweetsDataScience.retweet_count >= 16].sort_values(by='retweet_count')['text']]
# Out:
# ['RT @HopwoodMedia: 6 key requirements for #IoT success via @JimMarous @evankirstel #analytics #bigdata #dataviz #DataScience https://t.co/bi…',
#  'RT @HopwoodMedia: 6 key requirements for #IoT success via @JimMarous @evankirstel #analytics #bigdata #dataviz #DataScience https://t.co/bi…',
#  'RT @gp_pulipaka: Correcting Intel’s Deep Learning Benchmark Mistakes. #BigData #DeepLearning #MachineLearning #DataScience #AI\nhttps://t.co…',
#  'RT @MrDataScience: Apollo 17 was the last time humans travelled beyond low Earth orbit (45 years ago?!?!) #SpaceX #DataScience https://t.co…',
#  'RT @KirkDBorne: Predicting Customer Behavior with Predictive #BehavioralAnalytics [#infographic]\n\n#BigData #DataScience #MachineLearning #C…',
#  'RT @gp_pulipaka: Application of K-Means in #DataMining to Cluster Hemodialysis Patients. #BigData #MachineLearning #DataScience #AI \nhttps:…',
#  'RT @gp_pulipaka: Stanford researchers create #DeepLearning algorithm for drug development. #BigData #MachineLearning #DataScience #AI\nhttps…',
#  'RT @essec: #Infographic The Evolution of #IoT @ipfconline1 v/@CouthonConseil\n#BigData #DataScience #Fintech #AI #Startup #Chatbots https://…',
#  'RT @essec: #Infographic The Evolution of #IoT @ipfconline1 v/@CouthonConseil\n#BigData #DataScience #Fintech #AI #Startup #Chatbots https://…',
#  'RT @essec: #Infographic The Evolution of #IoT @ipfconline1 v/@CouthonConseil\n#BigData #DataScience #Fintech #AI #Startup #Chatbots https://…',
#  'RT @essec: #Infographic The Evolution of #IoT @ipfconline1 v/@CouthonConseil\n#BigData #DataScience #Fintech #AI #Startup #Chatbots https://…',
#  'RT @dataiku: Evolution of the Internet of Things #iot #infographic #datascience #bigdata #businessintelligence | RT @McKibbinUSA by @casale…',
#  'RT @gp_pulipaka: Deploy Deep Learning Models on #Amazon.#BigData #DeepLearning #MachineLearning #DataScience #AI #AWS #DataScientists\nhttps…',
#  'RT @gp_pulipaka: Deploy Deep Learning Models on #Amazon.#BigData #DeepLearning #MachineLearning #DataScience #AI #AWS #DataScientists\nhttps…',
#  'RT @gp_pulipaka: Deploy Deep Learning Models on #Amazon.#BigData #DeepLearning #MachineLearning #DataScience #AI #AWS #DataScientists\nhttps…',
#  'RT @Ronald_vanLoon: The Mathematics of Machine Learning | #DataScience #MachineLearning #RT https://t.co/cqVYdBRjgK https://t.co/EU0k6Dtkst',
#  "RT @KirkDBorne: Last week's top posts in #BigData #MachineLearning #DataScience #Statistics #DeepLearning at @DataScienceCtrl https://t.co/…",
#  'RT @ipfconline1: Driving the Success of #DataScience Solutions : Skills, Roles and Responsabilities [Infographic] \n#BigData #Analytics #Bus…',
#  "RT @KirkDBorne: Don't Be Fooled by Statistical Randomness &gt;&gt; 7 Traps to Avoid: https://t.co/AENMIpH7lc #abdsc #BigData #DataScience #Statis…",
#  'RT @Ronald_vanLoon: Machine Learning &amp; Data Science Skills You Need To Get Hired In Fortune 500 Companies | #DataScience #BigData #RT https…',
#  'RT @KirkDBorne: 27 free #DataMining books: https://t.co/GNJ8aKBwXd #abdsc #BigData #DataScience #MachineLearning via @DataScienceCtrl https…',
#  'RT @KirkDBorne: 27 free #DataMining books: https://t.co/GNJ8aKBwXd #abdsc #BigData #DataScience #MachineLearning via @DataScienceCtrl https…',
#  'RT @ipfconline1: #BigData #DataScience Future is Graph #Analytics &amp; much more fun stuff!\nSee @BoozAllen Field Guide: https://t.co/yV0imjwMY…',
#  'RT @MktgSciences: 27 Free #DataMining books – #DataScience Central - https://t.co/4ItVOppG8T\n#machinelearning #analytics https://t.co/HlYnw…',
#  'RT @wiomax: How to succeed with #bigdata on a tight budget https://t.co/siz7NTYlKV #DataScience #businessintelligence #LeanStartup #datadri…',
#  'RT @KirkDBorne: Top Prediction #Algorithms in One Picture: https://t.co/DHqZa7qmAI #abdsc #BigData #DataScience #MachineLearning #Predictiv…']

# %% [markdown]
# Observamos que muitas mensagens se tratam de retweets extra-oficiais (não executadas pelo botão de retweet). Essas mensagens citam diversas usuários. Dessa forma, podemos os tweets para encontrar quais são os usuários mais influentes em data science.
#
# Se verificarmos a descrição do objeto Tweet, veremos que ele possui um atributo user_mentions no campo ***entities***. Esse atributo é preenchido pelo Twitter que entrega uma lista de todos os usuários (objetos do tipo User) contidos no texto. Para o nosso exemplo, podemos nos restringir somente ao login do usuário no perfil (screen_name). Depois, podemos usar o screen_name dos usuários mais influentes para recuperar as informações de seus perfis diretamente da API.

# %%
usuariosInfluentes = dfTweetsDataScience.user_mentions.apply(lambda x: 
                                        [y['screen_name'] for y in x])
usuariosInfluentes
# Out:
# 0                                       [AusDATAcentre]
# 1                                                    []
# 2                                        [Storagepedia]
# 3                                         [ShaunVosper]
# 4                                             [ygaudry]
# 5                                                    []
# 6                                         [ShaunVosper]
# 7                                         [gp_pulipaka]
# 8                                                    []
# 9                                         [ShaunVosper]
# 10                                      [AusDATAcentre]
# 11                                        [gp_pulipaka]
# 12                                            [msarsar]
# 13                                        [ShaunVosper]
# 14                                        [gp_pulipaka]
# 15                                        [gp_pulipaka]
# 16                                      [AusDATAcentre]
# 17                                            [pyguide]
# 18                                            [msarsar]
# 19                                       [MktgSciences]
# 20                                            [DellEMC]
# 21                                            [msarsar]
# 22                                            [pyguide]
# 23                                                   []
# 24          [joe_caserta, bill_walrond, DBTADataSummit]
# 25                                        [ShaunVosper]
# 26                                      [AusDATAcentre]
# 27                                                   []
# 28                                                   []
# 29                                          [MikeTamir]
#                             ...
# 70                             [ipfconline1, BoozAllen]
# 71                                        [ipfconline1]
# 72                                             [PNNLab]
# 73                                     [Ronald_vanLoon]
# 74                                             [wiomax]
# 75                 [essec, ipfconline1, CouthonConseil]
# 76                 [essec, ipfconline1, CouthonConseil]
# 77                 [essec, ipfconline1, CouthonConseil]
# 78                                            [DellEMC]
# 79                                            [DellEMC]
# 80                                          [datagonzo]
# 81                                          [dreyco676]
# 82                                                   []
# 83                                                   []
# 84                       [DBTADataSummit, bill_walrond]
# 85                                          [mich8elwu]
# 86                                            [pyguide]
# 87                                                   []
# 88                                      [MrDataScience]
# 89                                    [AcheronAnalytic]
# 90                         [KirkDBorne, analyticbridge]
# 91                                    [AcheronAnalytic]
# 92                                                   []
# 93                                      [Cloudnews2013]
# 94    [MissB0107, teachingofsci, Vicbean76, MissL_Amos]
# 95                                                   []
# 96               [teachingofsci, Vicbean76, MissL_Amos]
# 97                                         [KirkDBorne]
# 98                                                   []
# 99                                                   []
# Name: user_mentions, dtype: object

# %%
top10Influentes = Counter(reduce(lambda x, y: x+y,
                                 usuariosInfluentes.values)).most_common(10)
top10Influentes
# Out:
# [('KirkDBorne', 7),
#  ('ShaunVosper', 6),
#  ('gp_pulipaka', 6),
#  ('ipfconline1', 6),
#  ('AusDATAcentre', 5),
#  ('CouthonConseil', 4),
#  ('essec', 4),
#  ('bigdataconf', 4),
#  ('MikeTamir', 4),
#  ('msarsar', 3)]

# %% [markdown]
# Agora que encontramos os dez usuários mais citados nas mensagens, podemos usar a API para recuperar seus dados de perfil. Essa consulta é feita pela interface `lookup_users`.

# %%
descTop10Influentes = api.lookup_users(screen_names=[a[0] for a in top10Influentes])
descTop10Influentes
# Out:
# [User(profile_image_url_https='https://pbs.twimg.com/profile_images/834247069057613825/spqkv7Ko_normal.jpg', screen_name='KirkDBorne', profile_text_color='333333', profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/378800000110442114/094a0b4d38b70e3871a1bda7d7fe2341.jpeg', id_str='534563976', profile_link_color='0084B4', profile_sidebar_fill_color='DDEEF6', notifications=False, profile_sidebar_border_color='FFFFFF', translator_type='none', name='Kirk Borne', profile_banner_url='https://pbs.twimg.com/profile_banners/534563976/1450104430', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=534563976, followers_count=141937, follow_request_sent=False, location='Booz Allen Hamilton', status=Status(entities={'user_mentions': [{'screen_name': 'benhamner', 'name': 'Ben Hamner', 'id_str': '22674817', 'id': 22674817, 'indices': [15, 25]}, {'screen_name': 'Quora', 'name': 'Quora', 'id_str': '33696409', 'id': 33696409, 'indices': [40, 46]}, {'screen_name': 'kaggle', 'name': 'Kaggle', 'id_str': '80422885', 'id': 80422885, 'indices': [53, 60]}], 'hashtags': [{'indices': [62, 78], 'text': 'MachineLearning'}, {'indices': [80, 93], 'text': 'DeepLearning'}, {'indices': [95, 98], 'text': 'AI'}, {'indices': [100, 115], 'text': 'DataScientists'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/8…', 'indices': [117, 140], 'url': 'https://t.co/b8Qf3o9qf5', 'expanded_url': 'https://twitter.com/i/web/status/849022142591139840'}]}, text='Check out what @benhamner has to say on @Quora about @Kaggle, #MachineLearning, #DeepLearning, #AI, #DataScientists… https://t.co/b8Qf3o9qf5', favorite_count=2, in_reply_to_status_id=None, retweet_count=1, id_str='849022142591139840', in_reply_to_user_id=None, in_reply_to_status_id_str=None, retweeted=False, favorited=False, _json={'entities': {'user_mentions': [{'screen_name': 'benhamner', 'name': 'Ben Hamner', 'id_str': '22674817', 'id': 22674817, 'indices': [15, 25]}, {'screen_name': 'Quora', 'name': 'Quora', 'id_str': '33696409', 'id': 33696409, 'indices': [40, 46]}, {'screen_name': 'kaggle', 'name': 'Kaggle', 'id_str': '80422885', 'id': 80422885, 'indices': [53, 60]}], 'hashtags': [{'indices': [62, 78], 'text': 'MachineLearning'}, {'indices': [80, 93], 'text': 'DeepLearning'}, {'indices': [95, 98], 'text': 'AI'}, {'indices': [100, 115], 'text': 'DataScientists'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/8…', 'indices': [117, 140], 'url': 'https://t.co/b8Qf3o9qf5', 'expanded_url': 'https://twitter.com/i/web/status/849022142591139840'}]}, 'text': 'Check out what @benhamner has to say on @Quora about @Kaggle, #MachineLearning, #DeepLearning, #AI, #DataScientists… https://t.co/b8Qf3o9qf5', 'favorite_count': 2, 'in_reply_to_status_id': None, 'retweet_count': 1, 'id_str': '849022142591139840', 'in_reply_to_user_id': None, 'in_reply_to_status_id_str': None, 'retweeted': False, 'favorited': False, 'geo': None, 'truncated': True, 'in_reply_to_user_id_str': None, 'contributors': None, 'lang': 'en', 'is_quote_status': False, 'created_at': 'Mon Apr 03 22:13:47 +0000 2017', 'in_reply_to_screen_name': None, 'id': 849022142591139840, 'possibly_sensitive': False, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'place': None, 'coordinates': None}, geo=None, truncated=True, in_reply_to_user_id_str=None, contributors=None, lang='en', is_quote_status=False, _api=<tweepy.api.API object at 0x11117dcc0>, created_at=datetime.datetime(2017, 4, 3, 22, 13, 47), in_reply_to_screen_name=None, id=849022142591139840, source_url='http://twitter.com', possibly_sensitive=False, source='Twitter Web Client', place=None, coordinates=None), entities={'url': {'urls': [{'display_url': 'linkedin.com/in/kirkdborne', 'indices': [0, 23], 'url': 'https://t.co/tWlmeuTlR7', 'expanded_url': 'http://www.linkedin.com/in/kirkdborne'}]}, 'description': {'urls': [{'display_url': 'rocketdatascience.org', 'indices': [117, ...
#  User(profile_image_url_https='https://pbs.twimg.com/profile_images/830037728041562112/v9KSLYO-_normal.jpg', screen_name='ShaunVosper', profile_text_color='333333', profile_background_image_url_https=None, id_str='830005193551015936', profile_link_color='1DA1F2', profile_sidebar_fill_color='DDEEF6', notifications=False, profile_sidebar_border_color='C0DEED', translator_type='none', name='ShaunVosper', profile_banner_url='https://pbs.twimg.com/profile_banners/830005193551015936/1491030293', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=830005193551015936, followers_count=286, follow_request_sent=False, location='Brisbane, Queensland', status=Status(entities={'media': [{'display_url': 'pic.twitter.com/J236uitn5k', 'url': 'https://t.co/J236uitn5k', 'media_url': 'http://pbs.twimg.com/media/C8hbWjAWAAApZXm.jpg', 'type': 'photo', 'sizes': {'large': {'w': 1705, 'resize': 'fit', 'h': 1147}, 'medium': {'w': 1200, 'resize': 'fit', 'h': 807}, 'small': {'w': 680, 'resize': 'fit', 'h': 457}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'id': 
...
#  User(profile_image_url_https='https://pbs.twimg.com/profile_images/674658758472024064/1BWd5LDj_normal.jpg', screen_name='MikeTamir', profile_text_color='000000', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme4/bg.gif', id_str='331659804', profile_link_color='1B95E0', profile_sidebar_fill_color='000000', notifications=False, profile_sidebar_border_color='000000', translator_type='none', name='Mike Tamir, PhD', profile_banner_url='https://pbs.twimg.com/profile_banners/331659804/1479956250', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=331659804, followers_count=12290, follow_request_sent=False, location='San Francisco, USA', status=Status(entities={'user_mentions': [{'screen_name': 'takt', 'name': 'takt', 'id_str': '5852142', 'id': 5852142, 'indices': [46, 51]}, {'screen_name': 'Starbucks', 'name': 'Starbucks Coffee', 'id_str': '30973', 'id': 30973, 'indices': [100, 110]}], 'hashtags': [{'indices': [8, 20], 'text': 'DataScience'}, {'indices': [27, 35], 'text': 'Haskell'}, {'indices': [52, 68], 'text': 'MachineLearning'}, {'indices': [69, 72], 'text': 'AI'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/8…', 'indices': [119, 142], 'url': 'https://t.co/Us9JZn6RCs', 'expanded_url': 'https://twitter.com/i/web/status/849021447209197568'}]}, text='HIRING: #DataScience &amp; #Haskell Engineers @Takt #MachineLearning #AI for large enterprises like @Starbucks DM me:… https://t.co/Us9JZn6RCs', favorite_count=3, in_reply_to_status_id=None, retweet_count=3, id_str='849021447209197568', in_reply_to_user_id=None, in_reply_to_status_id_str=None, retweeted=False, favorited=False, _json={'entities': {'user_mentions': [{'screen_name': 'takt', 'name': 'takt', 'id_str': '5852142', 'id': 5852142, 'indices': [46, 51]}, {'screen_name': 'Starbucks', 'name': 'Starbucks Coffee', 'id_str': '30973', 'id': 30973, 'indices': [100, 110]}], 'hashtags': [{'indices': [8, 20], 'text': 'DataScience'}, {'indices': [27, 35], 'text': 'Haskell'}, {'indices': [52, 68], 'text': 'MachineLearning'}, {'indices': [69, 72], 'text': 'AI'}], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/8…', 'indices': [119, 142], 'url': 'https://t.co/Us9JZn6RCs', 'expanded_url': 'https://twitter.com/i/web/status/849021447209197568'}]}, 'text': 'HIRING: #DataScience &amp; #Haskell Engineers @Takt #MachineLearning #AI for large enterprises like @Starbucks DM me:… https://t.co/Us9JZn6RCs', 'favorite_count': 3, 'in_reply_to_status_id': None, 'retweet_count': 3, 'id_str': '849021447209197568', 'in_reply_to_user_id': None, 'in_reply_to_status_id_str': None, 'retweeted': False, 'favorited': False, 'geo': None, 'truncated': True, 'in_reply_to_user_id_str': None, 'contributors': None, 'lang': 'en', 'is_quote_status': False, 'created_at': 'Mon Apr 03 22:11:01 +0000 2017', 'in_reply_to_screen_name': None, 'id': 849021447209197568, 'possibly_sensitive': False, 'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>', 'place': None, 'coordinates': None}, geo=None, truncated=True, in_reply_to_user_id_str=None, contributors=None, lang='en', is_quote_status=False, _api=<tweepy.api.API object at 0x11117dcc0>, created_at=datetime.datetime(2017, 4, 3, 22, 11, 1), in_reply_to_screen_name=None, id=849021447209197568, source_url='http://bufferapp.com', possibly_sensitive=False, source='Buffer', place=None, coordinates=None), entities={'url': {'urls': [{'display_url': 'linkedin.com/in/miketamir', 'indices': [0, 23], 'url': 'https://t.co/N3pFtaBSdq', 'expanded_url': 'http://linkedin.com/in/miketamir'}]}, 'description': {'urls': []}}, verified=False, geo_enabled=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme4/bg.gif', friends_count=4751, favourites_count=255, _json={'status': {'entities': {'user_mentions': [{'screen_name': 'takt', 'name': 'takt', 'id_str': '5852142', 'id': 5852142, 'indices': [46, 51]}, {'screen_name': 'Starbucks', 'name': 'Starbucks Coffee',  ...
#  User(profile_image_url_https='https://pbs.twimg.com/profile_images/826896126062260225/ptNJNP6a_normal.jpg', screen_name='msarsar', profile_text_color='000000', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme18/bg.gif', id_str='79699596', profile_link_color='1B95E0', profile_sidebar_fill_color='000000', notifications=False, profile_sidebar_border_color='000000', translator_type='none', name='Dr. Mehdi Sarsar', profile_banner_url='https://pbs.twimg.com/profile_banners/79699596/1486980353', is_translation_enabled=False, lang='en', _api=<tweepy.api.API object at 0x11117dcc0>, id=79699596, followers_count=7685, follow_request_sent=False, location='Paris - London', status=Status(entities={'user_mentions': [{'screen_name': 'ACSCentSci', 'name': 'ACS Central Science', 'id_str': '2180867466', 'id': 2180867466, 'indices': [87, 98]}, {'screen_name': 'vijaypande', 'name': 'Vijay Pande', 'id_str': '15275361', 'id': 15275361, 'indices': [99, 110]}], 'hashtags': [{'indices': [111, 114], 'text': 'AI'}], 'symbols': [], 'urls': [{'display_url': 'ln.is/JdMvy', 'indices': [63, 86], 'url': 'https://t.co/tzFdiKQzP3', 'expanded_url': 'http://ln.is/JdMvy'}, {'display_url': 'twitter.com/i/web/status/8…', 'indices': [116, 139], 'url': 'https://t.co/t3vUblKkmn', 'expanded_url': 'https://twitter.com/i/web/status/849033441282805760'}]}, text='Deep learning, using small amounts of data, for drug discovery https://t.co/tzFdiKQzP3 @ACSCentSci @Vijaypande #AI… https://t.co/t3vUblKkmn', favorite_count=0, in_reply_to_status_id=None, retweet_count=0, id_str='849033441282805760', in_reply_to_user_id=None, in_reply_to_status_id_str=None, retweeted=False, favorited=False, _json={'entities': {'user_mentions': [{'screen_name': 'ACSCentSci', 'name': 'ACS Central Science', 'id_str': '2180867466', 'id': 2180867466, 'indices': [87, 98]}, {'screen_name': 'vijaypande', 'name': 'Vijay Pande', 'id_str': '15275361', 'id': 15275361, 'indices': [99, 110]}], 'hashtags': [{'indices': [111, 114], 'text': 'AI'}], 'symbols': [], 'urls': [{'display_url': 'ln.is/JdMvy', 'indices': [63, 86], 'url': 'https://t.co/tzFdiKQzP3', 'expanded_url': 'http://ln.is/JdMvy'}, {'display_url': 'twitter.com/i/web/status/8…', 'indices': [116, 139], 'url': 'https://t.co/t3vUblKkmn', 'expanded_url': 'https://twitter.com/i/web/status/849033441282805760'}]}, 'text': 'Deep learning, using small amounts of data, for drug discovery https://t.co/tzFdiKQzP3 @ACSCentSci @Vijaypande #AI… https://t.co/t3vUblKkmn', 'favorite_count': 0, 'in_reply_to_status_id': None, 'retweet_count': 0, 'id_str': '849033441282805760', 'in_reply_to_user_id': None, 'in_reply_to_status_id_str': None, 'retweeted': False, 'favorited': False, 'geo': None, 'truncated': True, 'in_reply_to_user_id_str': None, 'contributors': None, 'lang': 'en', 'is_quote_status': False, 'created_at': 'Mon Apr 03 22:58:41 +0000 2017', 'in_reply_to_screen_name': None, 'id': 849033441282805760, 'possibly_sensitive': False, 'source': '<a href="http://linkis.com" rel="nofollow">Linkis: turn sharing into growth</a>', 'place': None, 'coordinates': None}, geo=None, truncated=True, in_reply_to_user_id_str=None, contributors=None, lang='en', is_quote_status=False, _api=<tweepy.api.API object at 0x11117dcc0>, created_at=datetime.datetime(2017, 4, 3, 22, 58, 41), in_reply_to_screen_name=None, id=849033441282805760, source_url='http://linkis.com', possibly_sensitive=False, source='Linkis: turn sharing into growth', place=None, coordinates=None), entities={'url': {'urls': [{'display_url': 'amazon.com/BDMOT-Theory-D…', 'indices': [0, 23], 'url': 'https://t.co/MOhjHoAfQJ', 'expanded_url': 'https://www.amazon.com/BDMOT-Theory-Data-Moment-Truth/dp/3659840998'}]}, 'description': {'urls': []}}, verified=False, geo_enabled=True, profile_background_image_url='http://abs.twimg.com/images/themes/theme18/bg.gif', friends_count=2959, favourites_count=327, _json={'status': {'entities': {'user_mentions': [{'screen_name': 'ACSCentSci', 'name': 'ACS Central ...

# %% [markdown]
# Os objetos do tipo User possuem diversos campos que não são úteis para nossa análise nesse momento. Assim, antes de criar um data frame com os dados dos usuários, devemos filtrá-los, escolhendo somente aquilo que pode ser interessante. Nesse primeiro momento restringiremos nossa análise ao login, nome, descrição, localização, número de seguidores, o número de pessoas que o usuário segue, e o número de tweets que ele já tuitou.

# %%
dfTop10Influentes = pd.DataFrame([{'screen_name':a.screen_name,
                                  'name':a.name,
                                   'description':a.description,
                                   'location':a.location,
                                   'followers_count':a.followers_count,
                                   'friends_count':a.friends_count,
                                   'no_tweets':a.statuses_count
                                  } for a in descTop10Influentes],
                                columns = ['screen_name', 'name', 'description',
                                          'location', 'followers_count', 'friends_count', 
                                           'no_tweets'])
dfTop10Influentes
# Out:
#       screen_name                  name  \
# 0      KirkDBorne            Kirk Borne
# 1     ShaunVosper           ShaunVosper
# 2     gp_pulipaka       Dr. GP Pulipaka
# 3     ipfconline1            ipfconline
# 4   AusDATAcentre        DataCentreTech
# 5  CouthonConseil   ✦ Couthon Conseil ✦
# 6           essec  ESSEC BusinessSchool
# 7     bigdataconf   Big Data Conference
# 8       MikeTamir       Mike Tamir, PhD
# 9         msarsar      Dr. Mehdi Sarsar
#
#                                          description  \
# 0  The Principal Data Scientist at @BoozAllen, Ph...
# 1  Data technology specialist & father of beautif...
# 2  Ganapathi Pulipaka | Founder and CEO @deepsing...
# 3  Création de Sites Internet Formation et Consei...
# 4  Australia's premier Data Centre Experts. We'll...
# 5  #Recrutement de #cadres & #freelances en {#Big...
# 6  Leading International Business School. Excelle...
# 7  Hurry!! Register fast #BigData Bootcamp #Dalla...
# 8  #CSO Chief #DataScientist tweeting on #DataSci...
# 9  ICT Senior Consultant 🇬🇧🇫🇷 #BigData #Economics...
#
#                     location  followers_count  friends_count  no_tweets
# 0        Booz Allen Hamilton           141937          81196      69321
# 1       Brisbane, Queensland              286            945        450
# 2            Los Angeles, CA            21148          12649      27043
# 3          Marseille, France            38594          38138      53125
# 4       Brisbane, Queensland             1077           4468        504
# 5         France & Worldwide             6239           5220       7430
# 6  Paris - Singapore - Rabat            28322           2756      26349
# 7                                        4853           2439      14692
# 8         San Francisco, USA            12290           4751       2976
# 9             Paris - London             7685           2959       3212

# %% [markdown]
# #### Trabalhando com cursores
#
# A API do Twitter fornece mecanismos para que o usuário itere sobre o conjunto de resultados de uma requisição. Ao invés de retornar todos os resultados de uma única vez, a API utiliza o conceito de paginação através de cursores.
#
# Os resultados são divididos em páginas. Na primeira requisição, assume que a página solicitada é a primeira, usando para isso o parâmetro cursor com valor -1. Junto com os resultados, a API retorna o cursor (índice de página) anterior e o próximo. Na requisição subsequente, o usuário informa o próximo cursor e a API retorna a página seguinte com os outros resultados. O usuário pode, então, iterar sobre mais resultados que o limite imposto em cada requisição.
#
# A biblioteca Tweepy possui uma interface direta para a paginação usada pelo Twitter. O tutorial http://docs.tweepy.org/en/v3.5.0/cursor_tutorial.html detalha como utilizar os cursores. Veremos um exemplo a seguir onde recuperaremos os 1000 tweets mais recentes contendo #datascience.

# %%
tweetsDataScience = [tweet for tweet in tweepy.Cursor(api.search, q='#datascience',\
                                  count=100,result_type="recent").items(1000)]
len(tweetsDataScience)
# Out:
# 1000

# %% [markdown]
# O resultado da pesquisa continua sendo uma lista de objetos do tipo `Status`, os quais podemos processar da mesma forma que fizemos com a consulta direta.

# %%
dfTweetsDataScience = pd.DataFrame(list(map(lambda x: filtra_campos(x._json),
                                            tweetsDataScience)))
dfTweetsDataScience.head()
# Out:
#                        created_at  favorite_count  \
# 0  Mon Apr 03 16:37:52 +0000 2017               0
# 1  Mon Apr 03 16:37:44 +0000 2017               0
# 2  Mon Apr 03 16:37:33 +0000 2017               0
# 3  Mon Apr 03 16:37:27 +0000 2017               0
# 4  Mon Apr 03 16:37:16 +0000 2017               0
#
#                                             hashtags                  id  \
# 0  [{'indices': [76, 84], 'text': 'BigData'}, {'i...  848937606800957443
# 1  [{'indices': [70, 78], 'text': 'BigData'}, {'i...  848937574160904193
# 2  [{'indices': [60, 68], 'text': 'BigData'}, {'i...  848937527759314945
# 3  [{'indices': [70, 78], 'text': 'BigData'}, {'i...  848937500064264192
# 4  [{'indices': [45, 58], 'text': 'DeepLearning'}...  848937454254116864
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_user_id lang  \
# 0                    None                    NaN                  NaN   en
# 1                    None                    NaN                  NaN   en
# 2                    None                    NaN                  NaN   en
# 3                    None                    NaN                  NaN   en
# 4                    None                    NaN                  NaN   en
#
#   media place_country place_name  retweet_count  \
# 0   NaN           NaN        NaN              4
# 1   NaN           NaN        NaN              6
# 2   NaN           NaN        NaN              4
# 3   NaN           NaN        NaN              6
# 4   NaN           NaN        NaN              7
#
#                                               source symbols  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...      []
# 1  <a href="http://twitter.com" rel="nofollow">Tw...      []
# 2  <a href="http://twitter.com" rel="nofollow">Tw...      []
# 3  <a href="http://twitter.com" rel="nofollow">Tw...      []
# 4  <a href="http://twitter.com" rel="nofollow">Tw...      []
#
#                                                 text truncated  \
# 0  RT @gp_pulipaka: Understanding Neural-Networks...     False
# 1  RT @gp_pulipaka: Neural-Networks: Part III – D...     False
# 2  RT @gp_pulipaka: A.I. used to create worldwide...     False
# 3  RT @gp_pulipaka: Correcting Intel’s Deep Learn...     False
# 4  RT @gp_pulipaka: Stanford researchers create #...     False
#
#                                                 urls    user_id  \
# 0                                                 []  480875170
# 1                                                 []  480875170
# 2  [{'display_url': 'buff.ly/2otsdDu', 'indices':...  480875170
# 3                                                 []  480875170
# 4                                                 []  480875170
#
#                                        user_mentions user_screen_name
# 0  [{'name': 'Dr. GP Pulipaka', 'indices': [3, 15...       Rosenchild
# 1  [{'name': 'Dr. GP Pulipaka', 'indices': [3, 15...       Rosenchild
# 2  [{'name': 'Dr. GP Pulipaka', 'indices': [3, 15...       Rosenchild
# 3  [{'name': 'Dr. GP Pulipaka', 'indices': [3, 15...       Rosenchild
# 4  [{'name': 'Dr. GP Pulipaka', 'indices': [3, 15...       Rosenchild

# %%
dfTweetsDataScience[['favorite_count','retweet_count']].describe()
# Out:
#        favorite_count  retweet_count
# count     1000.000000    1000.000000
# mean         0.446000      11.303000
# std          1.632712      22.274904
# min          0.000000       0.000000
# 25%          0.000000       1.000000
# 50%          0.000000       4.000000
# 75%          0.000000      12.000000
# max         21.000000     178.000000

# %%
top10Influentes = Counter(reduce(lambda x, y: x+y,
                                 dfTweetsDataScience.user_mentions.apply(lambda x: 
                                        [y['screen_name'] for y in x]).values)).most_common(10)
top10Influentes
# Out:
# [('gp_pulipaka', 97),
#  ('KirkDBorne', 70),
#  ('ipfconline1', 44),
#  ('DataScienceCtrl', 38),
#  ('evankirstel', 33),
#  ('miguelselas', 30),
#  ('Ronald_vanLoon', 25),
#  ('kdnuggets', 24),
#  ('DBaker007', 20),
#  ('MikeQuindazzi', 18)]

# %%
dfTop10Influentes = pd.DataFrame([{'screen_name':a.screen_name,
                                  'name':a.name,
                                   'description':a.description,
                                   'location':a.location,
                                   'followers_count':a.followers_count,
                                   'friends_count':a.friends_count,
                                   'no_tweets':a.statuses_count
                                  } \
                                  for a in api.lookup_users(screen_names=[a[0] \
                                                                          for a in top10Influentes])],
                                columns = ['screen_name', 'name', 'description',
                                          'location', 'followers_count', 'friends_count', 
                                           'no_tweets'])
dfTop10Influentes
# Out:
#        screen_name                  name  \
# 0      gp_pulipaka       Dr. GP Pulipaka
# 1       KirkDBorne            Kirk Borne
# 2      ipfconline1            ipfconline
# 3  DataScienceCtrl  Data Science Central
# 4      evankirstel          Evan Kirstel
# 5      miguelselas          Miguel Selas
# 6   Ronald_vanLoon       Ronald van Loon
# 7        kdnuggets             KDnuggets
# 8        DBaker007           Duane Baker
# 9    MikeQuindazzi      Mike Quindazzi ✨
#
#                                          description  \
# 0  Ganapathi Pulipaka | Founder and CEO @deepsing...
# 1  The Principal Data Scientist at @BoozAllen, Ph...
# 2  Création de Sites Internet Formation et Consei...
# 3  Co-founded by Vincent Granville and part the D...
# 4  #B2B #Solopreneur #Influencer #ThoughtLeader H...
# 5  Managing Partner & CEO at Bufete de Marketing ...
# 6  Helping data driven companies generating value...
# 7  Covering #Analytics, #BigData, #DataMining, #D...
# 8  IT Consultant #IT #bigdata #analytics #cloud #...
# 9  Managing Director • @StrategyAnd @PwC • Execut...
#
#                          location  followers_count  friends_count  no_tweets
# 0                 Los Angeles, CA            21126          12522      27043
# 1             Booz Allen Hamilton           141908          81199      69311
# 2               Marseille, France            38551          38054      53057
# 3                 Los Angeles, CA            87166           1126      18838
# 4                      Boston, MA           111743          96540     475684
# 5  Madrid | México DF | São Paulo             6435           5405       5056
# 6   #NL. Also connect on LinkedIn            78336          77253      24948
# 7              Brookline, MA, USA            79581            419      36923
# 8                    Columbus, OH            23073          22013      55907
# 9                 California, USA            29193           4668      18090

# %% [markdown]
# ## Usando a API de Streaming
#
# Como foi dito anteriormente, a API REST não foi desenvolvida para a coleta de dados em tempo real. De acordo com a documentação da API (https://dev.twitter.com/rest/reference/get/search/tweets), o mecanismo de busca não foi desenvolvido para servir como base para coleta exaustiva de tweets. Veja o que diz a documentação
#
#     Please note that Twitter’s search service and, by extension, the Search API is not meant to be an exhaustive source of Tweets. Not all Tweets will be indexed or made available via the search interface.
#
# Caso seja importante coletar um grande volume de dados para processá-los depois, deve-se usar a [interface/API de streaming](https://dev.twitter.com/streaming/overview). Nesse caso, uma conexão é mantida com o servidor do Twitter por um tempo mais longo. Novos tweets serão enviados ao usuário à medida em que são postados.
#
# Mais uma vez, Tweepy fornece os mecanismos necessários para coletas da API de streaming. Em suma, o usuário deve criar um *listener* que executará as ações correspondentes quando um evento ocorrer. Esse listerner é passado para Tweepy que se encarrega de conectar com a API do Twitter.

# %%
from tweepy.streaming import StreamListener
from tweepy import Stream

# %% [markdown]
# A classe abaixo define um exemplo de um listener que exibe as mensagens na saída padrão sempre que um novo dado é enviado.

# %%
class StdOutListener(StreamListener):

    def on_data(self, data):
        print(data)
        return True

    def on_error(self, status):
        print(status)

# %% [markdown]
# O segundo passo para se coletar dados da API de streaming é instanciar um objeto `Stream` que será responsável pela conexão. Devemos passar para o construtor a sessão autenticada da mesma forma que na API REST, e um listener.

# %%
stream = Stream(auth, StdOutListener())

# %% [markdown]
# Na maior parte dos casos, nossa intenção é em coletar apenas tweets específicos de um assunto. Assim como na interface de busca, podemos informar os termos que estamos interessados no parâmetro **track**. Uma descrição mais completa dos parâmetros está disponível em https://dev.twitter.com/streaming/overview/request-parameters

# %%
stream.filter(track=['vamosport' ,'vamosanta', 
                     'classicodasmultidoes', 
                     'sportxsantacruz', 'sport recife'])
