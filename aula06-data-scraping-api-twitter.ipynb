# %% [markdown]
# # Aula 06 &mdash; Data Scraping com API do Twitter
#
# Renato Vimieiro
# rv2 {em} cin.ufpe.br
#
# março 2017

# %%
import pandas as pd
import numpy as np

import tweepy

from functools import reduce
from collections import Counter
import json

# %% [markdown]
# ## Introdução
#
# Nas aulas anteriores vimos como obter dados diretamente de uma página web. Para isso, utilizamos a biblioteca BeautifulSoup. A biblioteca facilitava a busca de tags e, consequentemente, de informações úteis nas páginas. Embora tenhamos que lançar mão desse recurso em muitas ocasiões, alguns sites fornecem APIs para obtermos dados de forma semi-estruturada. Esses dados possuem formato livre, mas possuem indicadores do conteúdo. As representações mais usuais são [XML](https://en.wikipedia.org/wiki/XML) e [JSON](https://en.wikipedia.org/wiki/JSON).
#
# O formato JSON tem se tornado um dos mais usados para troca de dados na internet. Ele tem substituido inclusive XML. Muitos bancos de dados NoSQL, como MongoDB, fornecem suporte direto a dados nesse formato. Em outras palavras, JSON é, talvez, o formato franco de representação de dados para Data Science. Sendo assim, discutiremos rapidamente sua representação.

# %% [markdown]
# ## JSON
#
# O formato JSON (lê-se como *jay-son*) é essencialmente um dicionário. Ele descreve uma sequência de pares (chave,valor). Objetos no formato JSON são delimitados por { e }. Por sua vez, os pares são separados por vírgulas. As chaves e valores são separados por : (dois-pontos).
#
# As chaves devem ser sempre strings em unicode. Os valores podem ser:
#
# - string
# - número
# - objeto
# - vetor
# - true
# - false
# - null
#
# Os vetores referenciados acima são como vetores/listas em uma linguagem de programação. Eles podem conter uma sequência de um ou mais valores, incluindo outros vetores e objetos. A gramática do formato pode ser conferida em http://www.json.org/json-pt.html.
#
# ### Exemplo de um dado no formato JSON
#
# O exemplo a seguir foi retirado da Wikipedia. Ele ilustra como poderiam ser armazenados diversos dados sobre uma pessoa. A escolha das chaves é completamente arbitrária e definida pelo desenvolvedor.
#
# ```json
# {
#   "firstName": "John",
#   "lastName": "Smith",
#   "isAlive": true,
#   "age": 25,
#   "address": {
#     "streetAddress": "21 2nd Street",
#     "city": "New York",
#     "state": "NY",
#     "postalCode": "10021-3100"
#   },
#   "phoneNumbers": [
#     {
#       "type": "home",
#       "number": "212 555-1234"
#     },
#     {
#       "type": "office",
#       "number": "646 555-4567"
#     },
#     {
#       "type": "mobile",
#       "number": "123 456-7890"
#     }
#   ],
#   "children": [],
#   "spouse": null
# }
# ```

# %% [markdown]
# ## API do Twitter
#
# O Twitter oferece aos desenvolvedores uma API para permitir a interação entre o site e aplicativos de terceiros. A API é uma das ricas entre as redes sociais e, por isso, muitas pesquisas comerciais e científicas usam a plataforma.
#
# A API do Twitter se subdivide em outras duas APIs: REST e Streaming. A API de REST permite aos desenvolvedores acessar os perfis dos usuários (públicos) assim como seus seguidores, listas, timeline, além de efetuar buscas por termos ou usuários na plataforma. A API de Streaming, por outro lado, é dedicada ao monitoramento em tempo real dos tweets sendo postados na plataforma.
#
# Além dessas duas interfaces públicas, o Twitter ainda oferece uma terceira interface comercial, Gnip, para acesso a grandes volumes de dados. O Gnip, basicamente, fornece acesso à base de dados (pública) inteira do Twitter. Enquanto a API de Streaming faz amostragem dos tweets em tempo real (não é muito claro como isso é feito), o Gnip fornece acesso a efetivamente todos as mensagens sendo postadas. O mesmo acontece em relação ao REST, que limita, por exemplo, a busca por termos, não retornando todos os resultados. O Gnip, ao contrário, permite efetuar uma busca em toda a base.

# %% [markdown]
# ## Acesso à API do Twitter
#
# O acesso à API requer a criação de um perfil na plataforma e registro de um aplicativo. A autenticação é feita através do protocolo [OAuth](https://en.wikipedia.org/wiki/OAuth). A ideia básica do protocolo é que um usuário possa delegar acesso a recursos em um determinado site a terceiros sem revelar suas credenciais. Resumindo, o protocolo permite que chaves de acesso sejam geradas pelo usuário; essas chaves são passadas a um terceiro, a quem se deseja permitir acesso aos recursos do usuário; finalmente, a parte a quem o acesso foi delegado pode conectar-se ao sistema usando as chaves que lhe foram enviadas.
#
# #### Registrando um novo aplicativo
#
# Para registrar um aplicativo e gerar novas chaves de acesso, o usuário deve ir até o site https://apps.twitter.com.
#
# ![https://apps.twitter.com](images/tela_inicial_apps_twitter.png)
#
# Após logar, a tela inicial mostrará as aplicações autorizadas no momento.
#
# ![https://apps.twitter.com](images/apps_twitter_logado.png)
#
# Para criar/autorizar um novo aplicativo, clique no botão **Create New App**. Em seguida, você será redirecionado para uma página onde deverá preencher os dados do aplicativo
#
# ![https://apps.twitter.com](images/create_new_app.png)
#
# e aceitar os termos e condições de uso
#
# ![https://apps.twitter.com](images/create_new_app_accept_terms_confirm.png)
#
# Pronto! Agora você já resgistrou o aplicativo e poderá gerar as chaves de acesso como a seguir.
#
# #### Obtendo as chaves de acesso
#
# Após registrar o novo aplicativo, você será redirecionado à página de gerenciamento do aplicativo
#
# ![https://apps.twitter.com](images/new_app_twitter.png)
#
# Configure as permissões da maneira como for mais conveniente. Em geral, para apenas minerar os dados, basta permitir que o aplicativo possa somente ler os dados. Isso evita, ou diminui as chances, de postagens indevidas caso alguém obtenha suas chaves.
#
# Para gerar as chaves de acesso, vá até a aba **Keys and Access Tokens**.
#
# ![https://apps.twitter.com](images/consumer_key_twitter.png)
#
# Inicialmente o aplicativo não está autorizado a logar em nome do usuário. Você verá que foram assinalados um identificador e uma chave de acesso de usuário (*Consumer key and secret*), como mostrado na figura acima. Essas chaves servem para autenticar o usuário, contudo, elas não autenticam o aplicativo, como mostrado na figura abaixo.
#
# ![https://apps.twitter.com](images/authorize_app_twitter.png)
#
# Para autorizar o aplicativo, clique no botão **Create my access tokens**. O Twitter então gerará novos identificadores e chaves de acesso para o aplicativo (*Access token and secret*). Esses deverão ser usados em conjunto com as chaves de usuário para se ter acesso à API.
#
# ![https://apps.twitter.com](images/access_tokens_twitter.png)
#
# É importante lembrar que esses dois pares de identificadores e chaves nunca devem estar legíveis em seu programa. Eles são como senhas e, portanto, devem ser protegidos.
#
# Agora que já obtivemos as chaves de acesso, podemos iniciar a coleta de dados.

# %% [markdown]
# ## Acessando a API com Tweepy
#
# Existem diversas bibliotecas de Python para acessar a API do Twitter, como listado na página dos desenvolvedores (https://dev.twitter.com/resources/twitter-libraries). As duas bibliotecas mais usadas (pelo que vi na internet) são [Python-Twitter](https://github.com/bear/python-twitter) e [Tweepy](https://github.com/tweepy/tweepy). No entanto, Tweepy está melhor documentada e possui melhor suporte à API de Streaming. Assim, usaremos Tweepy em nossos exemplos.

# %% [markdown]
# #### Conectando-se a API com Tweepy
#
# A biblioteca Tweepy, na verdade, é um wrapper para os serviços listados na API do Twitter. Ela se encarrega dos detalhes de codificação e requisições ao servidor, abstraindo as consultas através de funções e métodos. A biblioteca abstrai inclusive os detalhes de autenticação.
#
# O primeiro passo para coletar os dados é autenticar o usuário e o aplicativo. Isso é feito da seguinte forma:

# %%
# As chaves estao armazenadas em um arquivo de configuracoes
# Python possui uma biblioteca para processar esses arquivos (ver configparser)
with open('../configs.txt') as f:
    chaves = json.load(f)
    
# Autentica o usuario na API
auth = tweepy.OAuthHandler(chaves["consumer_key"], chaves["consumer_secret"])

# Autentica o aplicativo
auth.set_access_token(chaves["access_token"], chaves["access_token_secret"])

# %% [markdown]
# O objeto `auth` contém a sessão autenticada e deverá ser usado nas conexões com a API.

# %% [markdown]
# #### Acesso à REST API
#
# O acesso à REST API é feito através de objetos da classe `tweepy.API`. Os objetos dessa classe possuem métodos que encapsulam os acessos às funcionalidades da API. Assim, devemos instaciar a classe usando a conexão criada anteriormente. É importante respeitar os limites impostos pela API, caso contrário, podemos ser bloqueados. As requisições que ultrapassarem os limites do Twitter resultaram em exceções do tipo `tweepy.RateLimitError`. Tweepy pode controlar automaticamente esses acessos. Podemos estabelecer que as chamadas a determinados métodos devem esperar até que o limite de requisições seja reestabelecido. O limite de requisições varia dependendo do tipo de requisição. O Twitter também faz constantes modificações nesses limites. Então, você sempre deve consultar a documentação da API para se certificar dos limites atuais. Eles podem ser conferidos em https://dev.twitter.com/rest/public/rate-limits.

# %%
api = tweepy.API(auth, wait_on_rate_limit=False)

# %% [markdown]
# O objeto `api` agora é nossa interface de acesso ao Twitter.
#
# Podemos usá-la para saber quais são os trending topics nos diversos lugares onde essa informação é monitorada.

# %%
api.trends_available()
# Out:
# [{'country': '',
#   'countryCode': None,
#   'name': 'Worldwide',
#   'parentid': 0,
#   'placeType': {'code': 19, 'name': 'Supername'},
#   'url': 'http://where.yahooapis.com/v1/place/1',
#   'woeid': 1},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Winnipeg',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'woeid': 2972},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Ottawa',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'woeid': 3369},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Quebec',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3444',
#   'woeid': 3444},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Montreal',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3534',
#   'woeid': 3534},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Toronto',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/4118',
#   'woeid': 4118},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Edmonton',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/8676',
#   'woeid': 8676},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Calgary',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/8775',
#   'woeid': 8775},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Vancouver',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/9807',
#   'woeid': 9807},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Birmingham',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/12723',
#   'woeid': 12723},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Blackpool',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/12903',
#   'woeid': 12903},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Bournemouth',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/13383',
#   'woeid': 13383},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Brighton',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/13911',
#   'woeid': 13911},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Bristol',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/13963',
#   'woeid': 13963},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Cardiff',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/15127',
#   'woeid': 15127},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Coventry',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/17044',
#   'woeid': 17044},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Derby',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/18114',
#   'woeid': 18114},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Edinburgh',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/19344',
#   'woeid': 19344},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Glasgow',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/21125',
#   'woeid': 21125},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Hull',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/25211',
#   'woeid': 25211},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Leeds',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/26042',
#   'woeid': 26042},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Leicester',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/26062',
#   'woeid': 26062},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Liverpool',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/26734',
#   'woeid': 26734},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Manchester',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/28218',
#   'woeid': 28218},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Middlesbrough',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/28869',
#   'woeid': 28869},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Newcastle',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/30079',
#   'woeid': 30079},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Nottingham',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/30720',
#   'woeid': 30720},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Plymouth',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/32185',
#   'woeid': 32185},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Portsmouth',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/32452',
#   'woeid': 32452},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Preston',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/32566',
#   'woeid': 32566},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Sheffield',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/34503',
#   'woeid': 34503},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Stoke-on-Trent',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/36240',
#   'woeid': 36240},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Swansea',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/36758',
#   'woeid': 36758},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'London',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/44418',
#   'woeid': 44418},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'Belfast',
#   'parentid': 23424975,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/44544',
#   'woeid': 44544},
#  {'country': 'Dominican Republic',
#   'countryCode': 'DO',
#   'name': 'Santo Domingo',
#   'parentid': 23424800,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/76456',
#   'woeid': 76456},
#  {'country': 'Guatemala',
#   'countryCode': 'GT',
#   'name': 'Guatemala City',
#   'parentid': 23424834,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/83123',
#   'woeid': 83123},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Acapulco',
#   'parentid': 23424900,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/110978',
#   'woeid': 110978},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Aguascalientes',
#   'parentid': 23424900,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/111579',
#   'woeid': 111579},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Chihuahua',
#   'parentid': 23424900,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/115958',
#   'woeid': 115958},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Mexico City',
#   'parentid': 23424900,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/116545',
#   'woeid': 116545},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Ciudad Juarez',
#   'parentid': 23424900,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/116556',
#   'woeid': 116556},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Nezahualcóyotl',
#   'parentid': 23424900,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/116564',
#   

#   'parentid': 23424977,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2503863',
#   'woeid': 2503863},
#  {'country': 'United States',
#   'countryCode': 'US',
#   'name': 'Tucson',
#   'parentid': 23424977,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2508428',
#   'woeid': 2508428},
#  {'country': 'United States',
#   'countryCode': 'US',
#   'name': 'Virginia Beach',
#   'parentid': 23424977,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2512636',
#   'woeid': 2512636},
#  {'country': 'United States',
#   'countryCode': 'US',
#   'name': 'Washington',
#   'parentid': 23424977,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2514815',
#   'woeid': 2514815},
#  {'country': 'Japan',
#   'countryCode': 'JP',
#   'name': 'Osaka',
#   'parentid': 23424856,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/15015370',
#   'woeid': 15015370},
#  {'country': 'Japan',
#   'countryCode': 'JP',
#   'name': 'Kyoto',
#   'parentid': 23424856,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/15015372',
#   'woeid': 15015372},
#  {'country': 'India',
#   'countryCode': 'IN',
#   'name': 'Delhi',
#   'parentid': 23424848,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/20070458',
#   'woeid': 20070458},
#  {'country': 'United Arab Emirates',
#   'countryCode': 'AE',
#   'name': 'United Arab Emirates',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424738',
#   'woeid': 23424738},
#  {'country': 'Algeria',
#   'countryCode': 'DZ',
#   'name': 'Algeria',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424740',
#   'woeid': 23424740},
#  {'country': 'Argentina',
#   'countryCode': 'AR',
#   'name': 'Argentina',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424747',
#   'woeid': 23424747},
#  {'country': 'Australia',
#   'countryCode': 'AU',
#   'name': 'Australia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424748',
#   'woeid': 23424748},
#  {'country': 'Austria',
#   'countryCode': 'AT',
#   'name': 'Austria',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424750',
#   'woeid': 23424750},
#  {'country': 'Bahrain',
#   'countryCode': 'BH',
#   'name': 'Bahrain',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424753',
#   'woeid': 23424753},
#  {'country': 'Belgium',
#   'countryCode': 'BE',
#   'name': 'Belgium',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424757',
#   'woeid': 23424757},
#  {'country': 'Belarus',
#   'countryCode': 'BY',
#   'name': 'Belarus',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424765',
#   'woeid': 23424765},
#  {'country': 'Brazil',
#   'countryCode': 'BR',
#   'name': 'Brazil',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424768',
#   'woeid': 23424768},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Canada',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424775',
#   'woeid': 23424775},
#  {'country': 'Chile',
#   'countryCode': 'CL',
#   'name': 'Chile',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424782',
#   'woeid': 23424782},
#  {'country': 'Colombia',
#   'countryCode': 'CO',
#   'name': 'Colombia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424787',
#   'woeid': 23424787},
#  {'country': 'Denmark',
#   'countryCode': 'DK',
#   'name': 'Denmark',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424796',
#   'woeid': 23424796},
#  {'country': 'Dominican Republic',
#   'countryCode': 'DO',
#   'name': 'Dominican Republic',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424800',
#   'woeid': 23424800},
#  {'country': 'Ecuador',
#   'countryCode': 'EC',
#   'name': 'Ecuador',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424801',
#   'woeid': 23424801},
#  {'country': 'Egypt',
#   'countryCode': 'EG',
#   'name': 'Egypt',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424802',
#   'woeid': 23424802},
#  {'country': 'Ireland',
#   'countryCode': 'IE',
#   'name': 'Ireland',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424803',
#   'woeid': 23424803},
#  {'country': 'France',
#   'countryCode': 'FR',
#   'name': 'France',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424819',
#   'woeid': 23424819},
#  {'country': 'Ghana',
#   'countryCode': 'GH',
#   'name': 'Ghana',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424824',
#   'woeid': 23424824},
#  {'country': 'Germany',
#   'countryCode': 'DE',
#   'name': 'Germany',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424829',
#   'woeid': 23424829},
#  {'country': 'Greece',
#   'countryCode': 'GR',
#   'name': 'Greece',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424833',
#   'woeid': 23424833},
#  {'country': 'Guatemala',
#   'countryCode': 'GT',
#   'name': 'Guatemala',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424834',
#   'woeid': 23424834},
#  {'country': 'Indonesia',
#   'countryCode': 'ID',
#   'name': 'Indonesia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424846',
#   'woeid': 23424846},
#  {'country': 'India',
#   'countryCode': 'IN',
#   'name': 'India',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424848',
#   'woeid': 23424848},
#  {'country': 'Israel',
#   'countryCode': 'IL',
#   'name': 'Israel',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424852',
#   'woeid': 23424852},
#  {'country': 'Italy',
#   'countryCode': 'IT',
#   'name': 'Italy',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424853',
#   'woeid': 23424853},
#  {'country': 'Japan',
#   'countryCode': 'JP',
#   'name': 'Japan',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424856',
#   'woeid': 23424856},
#  {'country': 'Jordan',
#   'countryCode': 'JO',
#   'name': 'Jordan',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424860',
#   'woeid': 23424860},
#  {'country': 'Kenya',
#   'countryCode': 'KE',
#   'name': 'Kenya',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424863',
#   'woeid': 23424863},
#  {'country': 'Korea',
#   'countryCode': 'KR',
#   'name': 'Korea',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424868',
#   'woeid': 23424868},
#  {'country': 'Kuwait',
#   'countryCode': 'KW',
#   'name': 'Kuwait',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424870',
#   'woeid': 23424870},
#  {'country': 'Lebanon',
#   'countryCode': 'LB',
#   'name': 'Lebanon',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424873',
#   'woeid': 23424873},
#  {'country': 'Latvia',
#   'countryCode': 'LV',
#   'name': 'Latvia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424874',
#   'woeid': 23424874},
#  {'country': 'Oman',
#   'countryCode': 'OM',
#   'name': 'Oman',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424898',
#   'woeid': 23424898},
#  {'country': 'Mexico',
#   'countryCode': 'MX',
#   'name': 'Mexico',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424900',
#   'woeid': 23424900},
#  {'country': 'Malaysia',
#   'countryCode': 'MY',
#   'name': 'Malaysia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424901',
#   'woeid': 23424901},
#  {'country': 'Nigeria',
#   'countryCode': 'NG',
#   'name': 'Nigeria',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424908',
#   'woeid': 23424908},
#  {'country': 'Netherlands',
#   'countryCode': 'NL',
#   'name': 'Netherlands',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424909',
#   'woeid': 23424909},
#  {'country': 'Norway',
#   'countryCode': 'NO',
#   'name': 'Norway',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424910',
#   'woeid': 23424910},
#  {'country': 'New Zealand',
#   'countryCode': 'NZ',
#   'name': 'New Zealand',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424916',
#   'woeid': 23424916},
#  {'country': 'Peru',
#   'countryCode': 'PE',
#   'name': 'Peru',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424919',
#   'woeid': 23424919},
#  {'country': 'Pakistan',
#   'countryCode': 'PK',
#   'name': 'Pakistan',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424922',
#   'woeid': 23424922},
#  {'country': 'Poland',
#   'countryCode': 'PL',
#   'name': 'Poland',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424923',
#   'woeid': 23424923},
#  {'country': 'Panama',
#   'countryCode': 'PA',
#   'name': 'Panama',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424924',
#   'woeid': 23424924},
#  {'country': 'Portugal',
#   'countryCode': 'PT',
#   'name': 'Portugal',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424925',
#   'woeid': 23424925},
#  {'country': 'Qatar',
#   'countryCode': 'QA',
#   'name': 'Qatar',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424930',
#   'woeid': 23424930},
#  {'country': 'Philippines',
#   'countryCode': 'PH',
#   'name': 'Philippines',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424934',
#   'woeid': 23424934},
#  {'country': 'Puerto Rico',
#   'countryCode': 'PR',
#   'name': 'Puerto Rico',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424935',
#   'woeid': 23424935},
#  {'country': 'Russia',
#   'countryCode': 'RU',
#   'name': 'Russia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424936',
#   'woeid': 23424936},
#  {'country': 'Saudi Arabia',
#   'countryCode': 'SA',
#   'name': 'Saudi Arabia',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424938',
#   'woeid': 23424938},
#  {'country': 'South Africa',
#   'countryCode': 'ZA',
#   'name': 'South Africa',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424942',
#   'woeid': 23424942},
#  {'country': 'Singapore',
#   'countryCode': 'SG',
#   'name': 'Singapore',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424948',
#   'woeid': 23424948},
#  {'country': 'Spain',
#   'countryCode': 'ES',
#   'name': 'Spain',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424950',
#   'woeid': 23424950},
#  {'country': 'Sweden',
#   'countryCode': 'SE',
#   'name': 'Sweden',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424954',
#   'woeid': 23424954},
#  {'country': 'Switzerland',
#   'countryCode': 'CH',
#   'name': 'Switzerland',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424957',
#   'woeid': 23424957},
#  {'country': 'Thailand',
#   'countryCode': 'TH',
#   'name': 'Thailand',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424960',
#   'woeid': 23424960},
#  {'country': 'Turkey',
#   'countryCode': 'TR',
#   'name': 'Turkey',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424969',
#   'woeid': 23424969},
#  {'country': 'United Kingdom',
#   'countryCode': 'GB',
#   'name': 'United Kingdom',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424975',
#   'woeid': 23424975},
#  {'country': 'Ukraine',
#   'countryCode': 'UA',
#   'name': 'Ukraine',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424976',
#   'woeid': 23424976},
#  {'country': 'United States',
#   'countryCode': 'US',
#   'name': 'United States',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424977',
#   'woeid': 23424977},
#  {'country': 'Venezuela',
#   'countryCode': 'VE',
#   'name': 'Venezuela',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424982',
#   'woeid': 23424982},
#  {'country': 'Vietnam',
#   'countryCode': 'VN',
#   'name': 'Vietnam',
#   'parentid': 1,
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424984',
#   'woeid': 23424984},
#  {'country': 'Malaysia',
#   'countryCode': 'MY',
#   'name': 'Petaling',
#   'parentid': 23424901,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/56013632',
#   'woeid': 56013632},
#  {'country': 'Malaysia',
#   'countryCode': 'MY',
#   'name': 'Hulu Langat',
#   'parentid': 23424901,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/56013645',
#   'woeid': 56013645},
#  {'country': 'Saudi Arabia',
#   'countryCode': 'SA',
#   'name': 'Ahsa',
#   'parentid': 23424938,
#   'placeType': {'code': 9, 'name': 'Unknown'},
#   'url': 'http://where.yahooapis.com/v1/place/56120136',
#   'woeid': 56120136},
#  {'country': 'Japan',
#   'countryCode': 'JP',
#   'name': 'Okayama',
#   'parentid': 23424856,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/90036018',
#   'woeid': 90036018}]

# %%
trendtopics = api.trends_place(455824)
#trendtopics = api.trends_place(455821)
trendtopics
# Out:
# [{'as_of': '2017-08-29T16:59:36Z',
#   'created_at': '2017-08-29T16:53:52Z',
#   'locations': [{'name': 'Recife', 'woeid': 455824}],
#   'trends': [{'name': 'III Guerra Mundial',
#     'promoted_content': None,
#     'query': '%22III+Guerra+Mundial%22',
#     'tweet_volume': 92235,
#     'url': 'http://twitter.com/search?q=%22III+Guerra+Mundial%22'},
#    {'name': '#OProblemaDaMinhaVidaÉ',
#     'promoted_content': None,
#     'query': '%23OProblemaDaMinhaVida%C3%89',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23OProblemaDaMinhaVida%C3%89'},
#    {'name': '#TercaDetremuraSDV',
#     'promoted_content': None,
#     'query': '%23TercaDetremuraSDV',
#     'tweet_volume': 16989,
#     'url': 'http://twitter.com/search?q=%23TercaDetremuraSDV'},
#    {'name': 'PARABÉNS LUCERO',
#     'promoted_content': None,
#     'query': '%22PARAB%C3%89NS+LUCERO%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22PARAB%C3%89NS+LUCERO%22'},
#    {'name': '#VisibilidadeLésbica',
#     'promoted_content': None,
#     'query': '%23VisibilidadeL%C3%A9sbica',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23VisibilidadeL%C3%A9sbica'},
#    {'name': '#MelhorCoisaEh',
#     'promoted_content': None,
#     'query': '%23MelhorCoisaEh',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MelhorCoisaEh'},
#    {'name': '#FlickerSessionsDublin',
#     'promoted_content': None,
#     'query': '%23FlickerSessionsDublin',
#     'tweet_volume': 10695,
#     'url': 'http://twitter.com/search?q=%23FlickerSessionsDublin'},
#    {'name': 'Fufuca',
#     'promoted_content': None,
#     'query': 'Fufuca',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Fufuca'},
#    {'name': 'Kenarik Boujikian',
#     'promoted_content': None,
#     'query': '%22Kenarik+Boujikian%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Kenarik+Boujikian%22'},
#    {'name': 'Pasadena',
#     'promoted_content': None,
#     'query': 'Pasadena',
#     'tweet_volume': 10697,
#     'url': 'http://twitter.com/search?q=Pasadena'},
#    {'name': 'Sonic Mania',
#     'promoted_content': None,
#     'query': '%22Sonic+Mania%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Sonic+Mania%22'},
#    {'name': 'Kim Jong-un',
#     'promoted_content': None,
#     'query': '%22Kim+Jong-un%22',
#     'tweet_volume': 16925,
#     'url': 'http://twitter.com/search?q=%22Kim+Jong-un%22'},
#    {'name': 'Bear',
#     'promoted_content': None,
#     'query': 'Bear',
#     'tweet_volume': 99228,
#     'url': 'http://twitter.com/search?q=Bear'},
#    {'name': 'Vadão',
#     'promoted_content': None,
#     'query': 'Vad%C3%A3o',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Vad%C3%A3o'},
#    {'name': 'Lea Michele',
#     'promoted_content': None,
#     'query': '%22Lea+Michele%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Lea+Michele%22'},
#    {'name': 'Quixeré',
#     'promoted_content': None,
#     'query': 'Quixer%C3%A9',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Quixer%C3%A9'},
#    {'name': 'Erika Miranda',
#     'promoted_content': None,
#     'query': '%22Erika+Miranda%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Erika+Miranda%22'},
#    {'name': 'Emre Mor',
#     'promoted_content': None,
#     'query': '%22Emre+Mor%22',
#     'tweet_volume': 24936,
#     'url': 'http://twitter.com/search?q=%22Emre+Mor%22'},
#    {'name': 'Moro e Bretas',
#     'promoted_content': None,
#     'query': '%22Moro+e+Bretas%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Moro+e+Bretas%22'},
#    {'name': 'Mamadou Sakho',
#     'promoted_content': None,
#     'query': '%22Mamadou+Sakho%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Mamadou+Sakho%22'},
#    {'name': "'Chiclete'",
#     'promoted_content': None,
#     'query': '%27Chiclete%27',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%27Chiclete%27'},
#    {'name': 'What Lovers Do',
#     'promoted_content': None,
#     'query': '%22What+Lovers+Do%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22What+Lovers+Do%22'},
#    {'name': 'Giovanni Augusto',
#     'promoted_content': None,
#     'query': '%22Giovanni+Augusto%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Giovanni+Augusto%22'},
#    {'name': 'ISAC',
#     'promoted_content': None,
#     'query': 'ISAC',
#     'tweet_volume': 28669,
#     'url': 'http://twitter.com/search?q=ISAC'},
#    {'name': 'Arena Grêmio',
#     'promoted_content': None,
#     'query': '%22Arena+Gr%C3%AAmio%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Arena+Gr%C3%AAmio%22'},
#    {'name': 'Contorno Leste',
#     'promoted_content': None,
#     'query': '%22Contorno+Leste%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Contorno+Leste%22'},
#    {'name': 'Presidente da Câmara',
#     'promoted_content': None,
#     'query': '%22Presidente+da+C%C3%A2mara%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Presidente+da+C%C3%A2mara%22'},
#    {'name': 'Lollapalooza 2018',
#     'promoted_content': None,
#     'query': '%22Lollapalooza+2018%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Lollapalooza+2018%22'},
#    {'name': 'Van Dijk',
#     'promoted_content': None,
#     'query': '%22Van+Dijk%22',
#     'tweet_volume': 52376,
#     'url': 'http://twitter.com/search?q=%22Van+Dijk%22'},
#    {'name': 'Pato Fu',
#     'promoted_content': None,
#     'query': '%22Pato+Fu%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Pato+Fu%22'},
#    {'name': 'São João Batista',
#     'promoted_content': None,
#     'query': '%22S%C3%A3o+Jo%C3%A3o+Batista%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22S%C3%A3o+Jo%C3%A3o+Batista%22'},
#    {'name': 'Rever',
#     'promoted_content': None,
#     'query': 'Rever',
#     'tweet_volume': 10952,
#     'url': 'http://twitter.com/search?q=Rever'},
#    {'name': 'Ucker',
#     'promoted_content': None,
#     'query': 'Ucker',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Ucker'},
#    {'name': 'Robinho e Fred',
#     'promoted_content': None,
#     'query': '%22Robinho+e+Fred%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Robinho+e+Fred%22'},
#    {'name': '#5HonGMA',
#     'promoted_content': None,
#     'query': '%235HonGMA',
#     'tweet_volume': 41421,
#     'url': 'http://twitter.com/search?q=%235HonGMA'},
#    {'name': '#VELHAPRA',
#     'promoted_content': None,
#     'query': '%23VELHAPRA',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23VELHAPRA'},
#    {'name': '#HappyDLDay',
#     'promoted_content': None,
#     'query': '%23HappyDLDay',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HappyDLDay'},
#    {'name': '#Encontro',
#     'promoted_content': None,
#     'query': '%23Encontro',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Encontro'},
#    {'name': '#bbdebate',
#     'promoted_content': None,
#     'query': '%23bbdebate',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23bbdebate'},
#    {'name': '#SeOTwitterFosseBanidoEu',
#     'promoted_content': None,
#     'query': '%23SeOTwitterFosseBanidoEu',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SeOTwitterFosseBanidoEu'},
#    {'name': '#fsradiobrasil',
#     'promoted_content': None,
#     'query': '%23fsradiobrasil',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23fsradiobrasil'},
#    {'name': '#MichaelJacksonDay',
#     'promoted_content': None,
#     'query': '%23MichaelJacksonDay',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MichaelJacksonDay'},
#    {'name': '#MalhaçãoNoVIVA',
#     'promoted_content': None,
#     'query': '%23Malha%C3%A7%C3%A3oNoVIVA',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Malha%C3%A7%C3%A3oNoVIVA'},
#    {'name': '#JornalAssombrado',
#     'promoted_content': None,
#     'query': '%23JornalAssombrado',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23JornalAssombrado'},
#    {'name': '#economiaG1',
#     'promoted_content': None,
#     'query': '%23economiaG1',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23economiaG1'},
#    {'name': '#ConexãoEI',
#     'promoted_content': None,
#     'query': '%23Conex%C3%A3oEI',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Conex%C3%A3oEI'},
#    {'name': '#BemEstar',
#     'promoted_content': None,
#     'query': '%23BemEstar',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23BemEstar'},
#    {'name': '#VMAs',
#     'promoted_content': None,
#     'query': '%23VMAs',
#     'tweet_volume': 392329,
#     'url': 'http://twitter.com/search?q=%23VMAs'}]}]

# %% [markdown]
# Como pode ser visto, o resultado é uma lista de objetos no formato JSON (um dicionário). Podemos usar Pandas para criar um data frame com os dados obtidos. Repare que a requisição retorna um único objeto com quatro chaves: data da apuração, data da requisição, local, e os tópicos. Nossa intenção é criar um data frame com os dados dos tópicos. As outras informações são complementares e podem ser replicadas no data frame se necessário após a criação.

# %%
dfTrendTopics = pd.DataFrame(trendtopics[0]['trends'])

# %%
dfTrendTopics.head(10)
# Out:
#                      name promoted_content                          query  \
# 0      III Guerra Mundial             None       %22III+Guerra+Mundial%22
# 1  #OProblemaDaMinhaVidaÉ             None  %23OProblemaDaMinhaVida%C3%89
# 2      #TercaDetremuraSDV             None           %23TercaDetremuraSDV
# 3         PARABÉNS LUCERO             None     %22PARAB%C3%89NS+LUCERO%22
# 4    #VisibilidadeLésbica             None    %23VisibilidadeL%C3%A9sbica
# 5          #MelhorCoisaEh             None               %23MelhorCoisaEh
# 6  #FlickerSessionsDublin             None       %23FlickerSessionsDublin
# 7                  Fufuca             None                         Fufuca
# 8       Kenarik Boujikian             None        %22Kenarik+Boujikian%22
# 9                Pasadena             None                       Pasadena
#
#    tweet_volume                                                url
# 0       92235.0  http://twitter.com/search?q=%22III+Guerra+Mund...
# 1           NaN  http://twitter.com/search?q=%23OProblemaDaMinh...
# 2       16989.0   http://twitter.com/search?q=%23TercaDetremuraSDV
# 3           NaN  http://twitter.com/search?q=%22PARAB%C3%89NS+L...
# 4           NaN  http://twitter.com/search?q=%23VisibilidadeL%C...
# 5           NaN       http://twitter.com/search?q=%23MelhorCoisaEh
# 6       10695.0  http://twitter.com/search?q=%23FlickerSessions...
# 7           NaN                 http://twitter.com/search?q=Fufuca
# 8           NaN  http://twitter.com/search?q=%22Kenarik+Boujiki...
# 9       10697.0               http://twitter.com/search?q=Pasadena

# %%
dfTrendTopics.sort_values(by='tweet_volume',ascending=False).\
                head(10)[['name','tweet_volume']]
# Out:
#                   name  tweet_volume
# 47               #VMAs      392329.0
# 12                Bear       99228.0
# 0   III Guerra Mundial       92235.0
# 28            Van Dijk       52376.0
# 34            #5HonGMA       41421.0
# 23                ISAC       28669.0
# 17            Emre Mor       24936.0
# 2   #TercaDetremuraSDV       16989.0
# 11         Kim Jong-un       16925.0
# 31               Rever       10952.0

# %% [markdown]
# Podemos também obter a lista de tweets de um usuário

# %%
trumpsTweets = api.user_timeline(screen_name='realdonaldtrump')
trumpsTweets[0]
# Out:
# Status(geo=None, retweet_count=7392, truncated=False, coordinates=None, place=None, contributors=None, retweeted=False, author=User(profile_use_background_image=True, follow_request_sent=False, followers_count=36995477, profile_image_url_https='https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg', created_at=datetime.datetime(2009, 3, 18, 13, 46, 38), profile_sidebar_fill_color='C5CEC0', protected=False, url=None, entities={'description': {'urls': []}}, screen_name='realDonaldTrump', verified=True, profile_banner_url='https://pbs.twimg.com/profile_banners/25073877/1503378994', description='45th President of the United States of America🇺🇸', id_str='25073877', following=False, profile_background_image_url='http://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg', default_profile_image=False, profile_link_color='1B95E0', favourites_count=13, statuses_count=35663, friends_count=45, profile_sidebar_border_color='BDDCAD', name='Donald J. Trump', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=True, lang='en', contributors_enabled=False, profile_background_color='6D5C18', profile_image_url='http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg', location='Washington, DC', profile_background_tile=True, _json={'contributors_enabled': False, 'profile_use_background_image': True, 'profile_background_color': '6D5C18', 'followers_count': 36995477, 'id': 25073877, 'default_profile': False, 'listed_count': 74877, 'profile_background_tile': True, 'notifications': False, 'created_at': 'Wed Mar 18 13:46:38 +0000 2009', 'location': 'Washington, DC', 'profile_text_color': '333333', 'protected': False, 'url': None, 'entities': {'description': {'urls': []}}, 'follow_request_sent': False, 'favourites_count': 13, 'verified': True, 'translator_type': 'regular', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1503378994', 'description': '45th President of the United States of America🇺🇸', 'geo_enabled': True, 'id_str': '25073877', 'following': False, 'utc_offset': -14400, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg', 'default_profile_image': False, 'profile_sidebar_border_color': 'BDDCAD', 'profile_link_color': '1B95E0', 'screen_name': 'realDonaldTrump', 'statuses_count': 35663, 'friends_count': 45, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg', 'name': 'Donald J. Trump', 'is_translation_enabled': True, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg', 'profile_sidebar_fill_color': 'C5CEC0', 'has_extended_profile': False, 'time_zone': 'Eastern Time (US & Canada)', 'lang': 'en', 'is_translator': False}, id=25073877, translator_type='regular', listed_count=74877, geo_enabled=True, utc_offset=-14400, has_extended_profile=False, profile_text_color='333333', default_profile=False, notifications=False, profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg', time_zone='Eastern Time (US & Canada)', is_translator=False), in_reply_to_user_id=None, source_url='http://twitter.com/download/iphone', entities={'urls': [], 'symbols': [], 'user_mentions': [{'id': 174752321, 'indices': [3, 18], 'id_str': '174752321', 'name': 'Brazoria County', 'screen_name': 'BrazoriaCounty'}], 'media': [{'expanded_url': 'https://twitter.com/BrazoriaCounty/status/902539081841827842/photo/1', 'source_status_id_str': '902539081841827842', 'source_user_id_str': '174752321', 'id_str': '902539076540047360', 'source_user_id': 174752321, 'sizes': {'small': {'resize': 'fit', 'h': 609, 'w': 680}, 'medium': {'resize': 'fit', 'h': 845, 'w': 944}, 'large': {'resize': 'fit', 'h': 845, 'w': 944}, 'thum ...

# %% [markdown]
# O resultado da chamada é uma lista de objetos da classe `Status`. Inspecionando esse objeto, vemos que ele possui um atributo `_json` que armazena o tweet como um dicionário (JSON).

# %%
print(type(trumpsTweets[0]._json))
trumpsTweets[0]._json
# Out:
# <class 'dict'>
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Aug 29 16:06:57 +0000 2017',
#  'entities': {'hashtags': [],
#   'media': [{'display_url': 'pic.twitter.com/sUTyXBzer9',
#     'expanded_url': 'https://twitter.com/BrazoriaCounty/status/902539081841827842/photo/1',
#     'id': 902539076540047360,
#     'id_str': '902539076540047360',
#     'indices': [20, 43],
#     'media_url': 'http://pbs.twimg.com/media/DIZ2gh0UIAA8jCO.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DIZ2gh0UIAA8jCO.jpg',
#     'sizes': {'large': {'h': 845, 'resize': 'fit', 'w': 944},
#      'medium': {'h': 845, 'resize': 'fit', 'w': 944},
#      'small': {'h': 609, 'resize': 'fit', 'w': 680},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 902539081841827842,
#     'source_status_id_str': '902539081841827842',
#     'source_user_id': 174752321,
#     'source_user_id_str': '174752321',
#     'type': 'photo',
#     'url': 'https://t.co/sUTyXBzer9'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 174752321,
#     'id_str': '174752321',
#     'indices': [3, 18],
#     'name': 'Brazoria County',
#     'screen_name': 'BrazoriaCounty'}]},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/sUTyXBzer9',
#     'expanded_url': 'https://twitter.com/BrazoriaCounty/status/902539081841827842/photo/1',
#     'id': 902539076540047360,
#     'id_str': '902539076540047360',
#     'indices': [20, 43],
#     'media_url': 'http://pbs.twimg.com/media/DIZ2gh0UIAA8jCO.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DIZ2gh0UIAA8jCO.jpg',
#     'sizes': {'large': {'h': 845, 'resize': 'fit', 'w': 944},
#      'medium': {'h': 845, 'resize': 'fit', 'w': 944},
#      'small': {'h': 609, 'resize': 'fit', 'w': 680},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 902539081841827842,
#     'source_status_id_str': '902539081841827842',
#     'source_user_id': 174752321,
#     'source_user_id_str': '174752321',
#     'type': 'photo',
#     'url': 'https://t.co/sUTyXBzer9'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 902563229968228353,
#  'id_str': '902563229968228353',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'und',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 7392,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Aug 29 14:31:00 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/sUTyXBzer9',
#      'expanded_url': 'https://twitter.com/BrazoriaCounty/status/902539081841827842/photo/1',
#      'id': 902539076540047360,
#      'id_str': '902539076540047360',
#      'indices': [0, 23],
#      'media_url': 'http://pbs.twimg.com/media/DIZ2gh0UIAA8jCO.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DIZ2gh0UIAA8jCO.jpg',
#      'sizes': {'large': {'h': 845, 'resize': 'fit', 'w': 944},
#       'medium': {'h': 845, 'resize': 'fit', 'w': 944},
#       'small': {'h': 609, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/sUTyXBzer9'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/sUTyXBzer9',
#      'expanded_url': 'https://twitter.com/BrazoriaCounty/status/902539081841827842/photo/1',
#      'id': 902539076540047360,
#      'id_str': '902539076540047360',
#      'indices': [0, 23],
#      'media_url': 'http://pbs.twimg.com/media/DIZ2gh0UIAA8jCO.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DIZ2gh0UIAA8jCO.jpg',
#      'sizes': {'large': {'h': 845, 'resize': 'fit', 'w': 944},
#       'medium': {'h': 845, 'resize': 'fit', 'w': 944},
#       'small': {'h': 609, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/sUTyXBzer9'}]},
#   'favorite_count': 6491,
#   'favorited': False,
#   'geo': None,
#   'id': 902539081841827842,
#   'id_str': '902539081841827842',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'und',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 7392,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'https://t.co/sUTyXBzer9',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Aug 04 18:52:04 +0000 2010',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Official Brazoria County Twitter Page',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'brazoria-county.com',
#        'expanded_url': 'http://www.brazoria-county.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/lqQUH5d5Wj'}]}},
#    'favourites_count': 212,
#    'follow_request_sent': False,
#    'followers_count': 4358,
#    'following': False,
#    'friends_count': 163,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 174752321,
#    'id_str': '174752321',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 123,
#    'location': 'Texas',
#    'name': 'Brazoria County',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/174752321/1502123137',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/899670568940707841/psmAothO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/899670568940707841/psmAothO_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'BrazoriaCounty',
#    'statuses_count': 1490,
#    'time_zone': 'Central Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/lqQUH5d5Wj',
#    'utc_offset': -18000,
#    'verified': False}},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': 'RT @BrazoriaCounty: https://t.co/sUTyXBzer9',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': '45th President of the United States of America🇺🇸',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 13,
#   'follow_request_sent': False,
#   'followers_count': 36995477,
#   'following': False,
#   'friends_count': 45,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 25073877,
#   'id_str': '25073877',
#   'is_translation_enabled': True,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 74877,
#   'location': 'Washington, DC',
#   'name': 'Donald J. Trump',
#   'notifications': False,
#   'profile_background_color': '6D5C18',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1503378994',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': 'BDDCAD',
#   'profile_sidebar_fill_color': 'C5CEC0',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'realDonaldTrump',
#   'statuses_count': 35663,
#   'time_zone': 'Eastern Time (US & Canada)',
#   'translator_type': 'regular',
#   'url': None,
#   'utc_offset': -14400,
#   'verified': True}}

# %% [markdown]
# Essa representação reflete o modelo de objetos estabelecido pela API do Twitter. Um tweet possui vários campos, como descrito em https://dev.twitter.com/overview/api/tweets. Nem todos os campos são interessantes para a análise de dados. Por exemplo, o tweet contém informações detalhadas sobre o usuário, como o link para a imagem de seu perfil, o link para a imagem que ele usa de fundo, entre outras coisas. Geralmente, esses dados não são úteis para análise. Assim, devemos ser cuidadosos para criar um data frame somente com os dados que julgarmos importantes.
#
# Por exemplo, podemos selecionar os seguintes campos:
#
# - id
# - created_at
# - entities (hashtags, urls, user_mentions)
# - favorite_count
# - in_reply_to_screen_name
# - in_reply_to_status_id
# - in_reply_to_user_id
# - lang
# - place (country, name)
# - retweet_count
# - source
# - text
# - truncated
# - user (screen_name, id)

# %%
def filtra_campos(tweet):    
    dic = {a[0] : a[1] for a in tweet.items() if a[0] in ['id',
                                    'created_at',
                                    'favorite_count',
                                    'in_reply_to_screen_name',
                                    'in_reply_to_status_id',
                                    'in_reply_to_user_id',
                                    'lang',
                                    'retweet_count',
                                    'source',
                                    'text',
                                    'truncated']}
    dic.update(tweet['entities'])
    if tweet['place']:
        dic.update({'place_'+a[0] : a[1] for a in tweet['place'].items() \
                    if a[0] in ['country', 'name']})
    dic.update({'user_'+a[0] : a[1] for a in tweet['user'].items() \
                if a[0] in ['screen_name', 'id']})
    return dic

# %%
filtra_campos(trumpsTweets[0]._json)
# Out:
# {'created_at': 'Tue Aug 29 16:06:57 +0000 2017',
#  'favorite_count': 0,
#  'hashtags': [],
#  'id': 902563229968228353,
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_user_id': None,
#  'lang': 'und',
#  'media': [{'display_url': 'pic.twitter.com/sUTyXBzer9',
#    'expanded_url': 'https://twitter.com/BrazoriaCounty/status/902539081841827842/photo/1',
#    'id': 902539076540047360,
#    'id_str': '902539076540047360',
#    'indices': [20, 43],
#    'media_url': 'http://pbs.twimg.com/media/DIZ2gh0UIAA8jCO.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/DIZ2gh0UIAA8jCO.jpg',
#    'sizes': {'large': {'h': 845, 'resize': 'fit', 'w': 944},
#     'medium': {'h': 845, 'resize': 'fit', 'w': 944},
#     'small': {'h': 609, 'resize': 'fit', 'w': 680},
#     'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#    'source_status_id': 902539081841827842,
#    'source_status_id_str': '902539081841827842',
#    'source_user_id': 174752321,
#    'source_user_id_str': '174752321',
#    'type': 'photo',
#    'url': 'https://t.co/sUTyXBzer9'}],
#  'retweet_count': 7392,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'symbols': [],
#  'text': 'RT @BrazoriaCounty: https://t.co/sUTyXBzer9',
#  'truncated': False,
#  'urls': [],
#  'user_id': 25073877,
#  'user_mentions': [{'id': 174752321,
#    'id_str': '174752321',
#    'indices': [3, 18],
#    'name': 'Brazoria County',
#    'screen_name': 'BrazoriaCounty'}],
#  'user_screen_name': 'realDonaldTrump'}

# %% [markdown]
# Podemos aplicar a função `filtra_campos` aos tweets recuperados para extrair os campos desejados.

# %%
dfTrumpsTweets = pd.DataFrame(list(map(lambda x: filtra_campos(x._json),trumpsTweets)))
dfTrumpsTweets.head()
# Out:
#                        created_at  favorite_count  \
# 0  Tue Aug 29 16:06:57 +0000 2017               0
# 1  Tue Aug 29 12:26:55 +0000 2017           39442
# 2  Tue Aug 29 12:10:30 +0000 2017           84495
# 3  Tue Aug 29 11:31:46 +0000 2017               0
# 4  Tue Aug 29 11:22:57 +0000 2017               0
#
#                                             hashtags                  id  \
# 0                                                 []  902563229968228353
# 1                                                 []  902507855584092160
# 2                                                 []  902503724274331653
# 3       [{'indices': [100, 108], 'text': 'thefive'}]  902493977533968384
# 4  [{'indices': [16, 35], 'text': 'PhotosFromTheF...  902491758235406346
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_user_id lang  \
# 0                    None                    NaN                  NaN  und
# 1                    None                    NaN                  NaN   en
# 2                    None                    NaN                  NaN   en
# 3                    None                    NaN                  NaN   en
# 4                    None                    NaN                  NaN   en
#
#                                                media  retweet_count  \
# 0  [{'expanded_url': 'https://twitter.com/Brazori...           7392
# 1                                                NaN           9091
# 2                                                NaN          15518
# 3                                                NaN           4082
# 4                                                NaN           3965
#
#                                               source symbols  \
# 0  <a href="http://twitter.com/download/iphone" r...      []
# 1  <a href="http://twitter.com/download/iphone" r...      []
# 2  <a href="http://twitter.com/download/iphone" r...      []
# 3  <a href="http://twitter.com/download/iphone" r...      []
# 4  <a href="http://twitter.com/download/iphone" r...      []
#
#                                                 text truncated urls   user_id  \
# 0        RT @BrazoriaCounty: https://t.co/sUTyXBzer9     False   []  25073877
# 1  .@foxandfriends   We are not looking to fill a...     False   []  25073877
# 2                             Leaving now for Texas!     False   []  25073877
# 3  RT @TheFive: "Trump just won on law &amp; orde...     False   []  25073877
# 4  RT @TXMilitary: #PhotosFromTheField: Aerial ph...     False   []  25073877
#
#                                        user_mentions user_screen_name
# 0  [{'id': 174752321, 'indices': [3, 18], 'id_str...  realDonaldTrump
# 1  [{'id': 15513604, 'indices': [1, 15], 'id_str'...  realDonaldTrump
# 2                                                 []  realDonaldTrump
# 3  [{'id': 334053327, 'indices': [3, 11], 'id_str...  realDonaldTrump
# 4  [{'id': 111598798, 'indices': [3, 14], 'id_str...  realDonaldTrump

# %% [markdown]
# #### Pesquisando tweets
#
# A API do Twitter fornece ainda acesso à pesquisa de tweets usando termos ou *hashtags*.
# A descrição completa de como elaborar termos de busca pode ser encontrada em https://dev.twitter.com/rest/public/search. O acesso é fornecido em Tweepy pelo método [`search`](http://docs.tweepy.org/en/v3.5.0/api.html#API.search) da classe API.
#
# A documentação de Tweepy traz a seguinte descrição
#
# ```python
# API.search(q[, lang][, locale][, rpp][, page][, since_id][, geocode][, show_user])
# ```
#
# Contudo, os parâmetros descritos estão desatualizados. A documentação do código traz a lista atual de parâmetros, conforme descrição da API do Twitter. São eles:
#
# ```python
# 'q', 'lang', 'locale', 'since_id', 'geocode',
#              'max_id', 'since', 'until', 'result_type', 'count',
#               'include_entities', 'from', 'to', 'source'
# ```
#
# Verifique https://dev.twitter.com/rest/reference/get/search/tweets para ver a descrição de cada um dos parâmetros.

# %%
tweetsDataScience = api.search('#datascience',count=100,result_type="recent")
len(tweetsDataScience)
# Out:
# 100

# %%
tweetsDataScience
# Out:
# [Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'und'}, retweet_count=1, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=True, follow_request_sent=False, followers_count=1222, profile_image_url_https='https://pbs.twimg.com/profile_images/885191163170312192/-3gkTpKz_normal.jpg', created_at=datetime.datetime(2009, 9, 18, 13, 35, 13), profile_sidebar_fill_color='DDEEF6', protected=False, url='https://t.co/ON9JG0QKLf', entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://www.linkedin.com/in/kjsbedi/', 'url': 'https://t.co/ON9JG0QKLf', 'display_url': 'linkedin.com/in/kjsbedi/', 'indices': [0, 23]}]}}, screen_name='KJSBEDI', verified=False, description='#DigitalTransformation #BlockChain #DataScience #R #DevOps #Cloud #EnterpriseArchitecture #IOT #MobileArchitect #RPA', id_str='75281169', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='1DA1F2', favourites_count=224, statuses_count=2721, friends_count=1395, profile_sidebar_border_color='C0DEED', name='Kamaljeet Singh Bedi', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='C0DEED', profile_image_url='http://pbs.twimg.com/profile_images/885191163170312192/-3gkTpKz_normal.jpg', location='New Delhi, India', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': True, 'profile_background_color': 'C0DEED', 'followers_count': 1222, 'id': 75281169, 'default_profile': True, 'listed_count': 36, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Fri Sep 18 13:35:13 +0000 2009', 'location': 'New Delhi, India', 'profile_text_color': '333333', 'protected': False, 'url': 'https://t.co/ON9JG0QKLf', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://www.linkedin.com/in/kjsbedi/', 'url': 'https://t.co/ON9JG0QKLf', 'display_url': 'linkedin.com/in/kjsbedi/', 'indices': [0, 23]}]}}, 'follow_request_sent': False, 'favourites_count': 224, 'verified': False, 'translator_type': 'none', 'description': '#DigitalTransformation #BlockChain #DataScience #R #DevOps #Cloud #EnterpriseArchitecture #IOT #MobileArchitect #RPA', 'geo_enabled': False, 'id_str': '75281169', 'following': False, 'utc_offset': None, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'default_profile_image': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_link_color': '1DA1F2', 'screen_name': 'KJSBEDI', 'statuses_count': 2721, 'friends_count': 1395, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/885191163170312192/-3gkTpKz_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/885191163170312192/-3gkTpKz_normal.jpg', 'name': 'Kamaljeet Singh Bedi', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'has_extended_profile': True, 'time_zone': None, 'lang': 'en', 'is_translator': False}, id=75281169, translator_type='none', listed_count=36, geo_enabled=False, utc_offset=None, has_extended_profile=True, profile_text_color='333333', default_profile=True, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', time_zone=None, is_translator=False), in_reply_to_user_id=None, source_url='http://sp1n3.com/', entities={'urls': [{'expanded_url': 'http://www.amazon.com/dp/1107149894/?tag=andrewshamlet-20', 'url': 'https://t.co/KJpeop39WA', 'display_url': 'amazon.com/dp/1107149894/…', 'indices': [19, 42]}], 'symbols': [], 'user_mentions': [{'id': 2442313279, 'indices': [3, 17], 'id_str': '2442313279', 'name': 'Andrew Hamlet', 'screen_name': 'andrewshamlet'}], 'hashtags': [{'indices': [43, 48], ' ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=10, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=True, follow_request_sent=False, followers_count=350, profile_image_url_https='https://pbs.twimg.com/profile_images/870098088551206912/b1GliIek_normal.jpg', created_at=datetime.datetime(2009, 6, 4, 4, 10, 48), profile_sidebar_fill_color='252429', protected=False, url=None, entities={'description': {'urls': []}}, screen_name='tweetingAsGreg', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/44542581/1355687151', description='', id_str='44542581', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme9/bg.gif', default_profile_image=False, profile_link_color='2FC2EF', favourites_count=7, statuses_count=552, friends_count=1514, profile_sidebar_border_color='181A1E', name='Greg Michaelson', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='1A1B1F', profile_image_url='http://pbs.twimg.com/profile_images/870098088551206912/b1GliIek_normal.jpg', location='Concord, NC', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': True, 'profile_background_color': '1A1B1F', 'followers_count': 350, 'id': 44542581, 'default_profile': False, 'listed_count': 10, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Thu Jun 04 04:10:48 +0000 2009', 'location': 'Concord, NC', 'profile_text_color': '666666', 'protected': False, 'url': None, 'entities': {'description': {'urls': []}}, 'follow_request_sent': False, 'favourites_count': 7, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44542581/1355687151', 'description': '', 'geo_enabled': False, 'id_str': '44542581', 'following': False, 'utc_offset': -18000, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'default_profile_image': False, 'profile_sidebar_border_color': '181A1E', 'profile_link_color': '2FC2EF', 'screen_name': 'tweetingAsGreg', 'statuses_count': 552, 'friends_count': 1514, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/870098088551206912/b1GliIek_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/870098088551206912/b1GliIek_normal.jpg', 'name': 'Greg Michaelson', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_sidebar_fill_color': '252429', 'has_extended_profile': False, 'time_zone': 'Central Time (US & Canada)', 'lang': 'en', 'is_translator': False}, id=44542581, translator_type='none', listed_count=10, geo_enabled=False, utc_offset=-18000, has_extended_profile=False, profile_text_color='666666', default_profile=False, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme9/bg.gif', time_zone='Central Time (US & Canada)', is_translator=False), in_reply_to_user_id=None, source_url='http://gaggleamp.com/twit/', entities={'urls': [{'expanded_url': 'http://bit.ly/2xtn9jl', 'url': 'https://t.co/BQLPAq8ns9', 'display_url': 'bit.ly/2xtn9jl', 'indices': [115, 138]}], 'symbols': [], 'user_mentions': [{'id': 622519917, 'indices': [3, 13], 'id_str': '622519917', 'name': 'DataRobot', 'screen_name': 'DataRobot'}], 'hashtags': [{'indices': [32, 44], 'text': 'datascience'}]}, in_reply_to_status_id=None, retweeted_status=Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=10, truncated=True, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=True, follow_request_sent=False, followers_count=8431, profile_image_url_https='https://pbs.twimg.com/profile_images/803259137542987776/kE1KycaB_normal.jpg', created_at ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=0, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=False, follow_request_sent=False, followers_count=91, profile_image_url_https='https://pbs.twimg.com/profile_images/786754250089062404/NDkXviYH_normal.jpg', created_at=datetime.datetime(2010, 4, 2, 2, 9, 38), profile_sidebar_fill_color='000000', protected=False, url='https://t.co/Dal7l52grt', entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'http://www.xtendly.com', 'url': 'https://t.co/Dal7l52grt', 'display_url': 'xtendly.com', 'indices': [0, 23]}]}}, screen_name='abiconti', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/128739276/1453362795', description='SEO Specialist', id_str='128739276', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='4A913C', favourites_count=11, statuses_count=3036, friends_count=158, profile_sidebar_border_color='000000', name='Michelle', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='000000', profile_image_url='http://pbs.twimg.com/profile_images/786754250089062404/NDkXviYH_normal.jpg', location='', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': False, 'profile_background_color': '000000', 'followers_count': 91, 'id': 128739276, 'default_profile': False, 'listed_count': 31, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Fri Apr 02 02:09:38 +0000 2010', 'location': '', 'profile_text_color': '000000', 'protected': False, 'url': 'https://t.co/Dal7l52grt', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'http://www.xtendly.com', 'url': 'https://t.co/Dal7l52grt', 'display_url': 'xtendly.com', 'indices': [0, 23]}]}}, 'follow_request_sent': False, 'favourites_count': 11, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/128739276/1453362795', 'description': 'SEO Specialist', 'geo_enabled': False, 'id_str': '128739276', 'following': False, 'utc_offset': None, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'default_profile_image': False, 'profile_sidebar_border_color': '000000', 'profile_link_color': '4A913C', 'screen_name': 'abiconti', 'statuses_count': 3036, 'friends_count': 158, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/786754250089062404/NDkXviYH_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/786754250089062404/NDkXviYH_normal.jpg', 'name': 'Michelle', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': '000000', 'has_extended_profile': False, 'time_zone': None, 'lang': 'en', 'is_translator': False}, id=128739276, translator_type='none', listed_count=31, geo_enabled=False, utc_offset=None, has_extended_profile=False, profile_text_color='000000', default_profile=False, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', time_zone=None, is_translator=False), in_reply_to_user_id=None, source_url='https://ifttt.com', entities={'urls': [{'expanded_url': 'https://buff.ly/2vFqk6p', 'url': 'https://t.co/JuH7i7hqpb', 'display_url': 'buff.ly/2vFqk6p', 'indices': [78, 101]}], 'symbols': [], 'user_mentions': [], 'hashtags': [{'indices': [52, 64], 'text': 'DataScience'}, {'indices': [115, 123], 'text': 'bigdata'}]}, in_reply_to_status_id=None, contributors=None, id=902578515194859521, in_reply_to_status_id_str=None, id_str='902578515194859521', text="xtendly: 'How I Analysed 1.6 Million Articles for a #DataScience Competition' https://t.co/JuH7i7hqpb via  ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'und'}, retweet_count=1, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=True, follow_request_sent=False, followers_count=2860, profile_image_url_https='https://pbs.twimg.com/profile_images/788026161284648962/Cw2UrZRR_normal.jpg', created_at=datetime.datetime(2014, 4, 13, 19, 8, 6), profile_sidebar_fill_color='DDEEF6', protected=False, url='https://t.co/C3BhwWVuF1', entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'http://www.andrewshamlet.net', 'url': 'https://t.co/C3BhwWVuF1', 'display_url': 'andrewshamlet.net', 'indices': [0, 23]}]}}, screen_name='andrewshamlet', verified=False, description='Data Science. Python. Musings. @nyustern @unc 🐬🐬🐬', id_str='2442313279', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='1DA1F2', favourites_count=28866, statuses_count=14418, friends_count=17, profile_sidebar_border_color='C0DEED', name='Andrew Hamlet', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='C0DEED', profile_image_url='http://pbs.twimg.com/profile_images/788026161284648962/Cw2UrZRR_normal.jpg', location='Brooklyn, NY', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': True, 'profile_background_color': 'C0DEED', 'followers_count': 2860, 'id': 2442313279, 'default_profile': True, 'listed_count': 200, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Sun Apr 13 19:08:06 +0000 2014', 'location': 'Brooklyn, NY', 'profile_text_color': '333333', 'protected': False, 'url': 'https://t.co/C3BhwWVuF1', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'http://www.andrewshamlet.net', 'url': 'https://t.co/C3BhwWVuF1', 'display_url': 'andrewshamlet.net', 'indices': [0, 23]}]}}, 'follow_request_sent': False, 'favourites_count': 28866, 'verified': False, 'translator_type': 'none', 'description': 'Data Science. Python. Musings. @nyustern @unc 🐬🐬🐬', 'geo_enabled': False, 'id_str': '2442313279', 'following': False, 'utc_offset': -14400, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'default_profile_image': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_link_color': '1DA1F2', 'screen_name': 'andrewshamlet', 'statuses_count': 14418, 'friends_count': 17, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/788026161284648962/Cw2UrZRR_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/788026161284648962/Cw2UrZRR_normal.jpg', 'name': 'Andrew Hamlet', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'has_extended_profile': False, 'time_zone': 'Eastern Time (US & Canada)', 'lang': 'en', 'is_translator': False}, id=2442313279, translator_type='none', listed_count=200, geo_enabled=False, utc_offset=-14400, has_extended_profile=False, profile_text_color='333333', default_profile=True, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', time_zone='Eastern Time (US & Canada)', is_translator=False), in_reply_to_user_id=None, source_url='http://www.andrewshamlet.net', entities={'urls': [{'expanded_url': 'http://www.amazon.com/dp/1107149894/?tag=andrewshamlet-20', 'url': 'https://t.co/KJpeop39WA', 'display_url': 'amazon.com/dp/1107149894/…', 'indices': [0, 23]}], 'symbols': [], 'user_mentions': [], 'hashtags': [{'indices': [24, 29], 'text': 'code'}, {'indices': [30, 36], 'text': 'learn'}, {'indices': [37, 42], 'text': 'data'}, {'indices': [43, 55], 'text': 'datascience'}, {'indices': [56, 63], 'text': 'python'}, {'indices': [64, 67], 'text': 'AI'},  ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=0, truncated=True, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=False, follow_request_sent=False, followers_count=414, profile_image_url_https='https://pbs.twimg.com/profile_images/454977439488172032/rvPtPbJH_normal.png', created_at=datetime.datetime(2013, 12, 19, 14, 3, 35), profile_sidebar_fill_color='DDEEF6', protected=False, url='https://t.co/HSWCblAvFP', entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://www.blendo.co/', 'url': 'https://t.co/HSWCblAvFP', 'display_url': 'blendo.co', 'indices': [0, 23]}]}}, screen_name='APIrise', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/2253579049/1399531910', description='We are building @blendoapp the simplest #ETL #ELT tool to load all your data into your #datawarehouse in minutes.', id_str='2253579049', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='000000', favourites_count=179, statuses_count=2598, friends_count=675, profile_sidebar_border_color='FFFFFF', name='Apirise', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='FFF8E3', profile_image_url='http://pbs.twimg.com/profile_images/454977439488172032/rvPtPbJH_normal.png', location='Athens - Greece', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': False, 'profile_background_color': 'FFF8E3', 'followers_count': 414, 'id': 2253579049, 'default_profile': False, 'listed_count': 202, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Thu Dec 19 14:03:35 +0000 2013', 'location': 'Athens - Greece', 'profile_text_color': '333333', 'protected': False, 'url': 'https://t.co/HSWCblAvFP', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://www.blendo.co/', 'url': 'https://t.co/HSWCblAvFP', 'display_url': 'blendo.co', 'indices': [0, 23]}]}}, 'follow_request_sent': False, 'favourites_count': 179, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2253579049/1399531910', 'description': 'We are building @blendoapp the simplest #ETL #ELT tool to load all your data into your #datawarehouse in minutes.', 'geo_enabled': False, 'id_str': '2253579049', 'following': False, 'utc_offset': 10800, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'default_profile_image': False, 'profile_sidebar_border_color': 'FFFFFF', 'profile_link_color': '000000', 'screen_name': 'APIrise', 'statuses_count': 2598, 'friends_count': 675, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/454977439488172032/rvPtPbJH_normal.png', 'profile_image_url': 'http://pbs.twimg.com/profile_images/454977439488172032/rvPtPbJH_normal.png', 'name': 'Apirise', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'has_extended_profile': False, 'time_zone': 'Athens', 'lang': 'en', 'is_translator': False}, id=2253579049, translator_type='none', listed_count=202, geo_enabled=False, utc_offset=10800, has_extended_profile=False, profile_text_color='333333', default_profile=False, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', time_zone='Athens', is_translator=False), in_reply_to_user_id=None, source_url='http://meetedgar.com', entities={'urls': [{'expanded_url': 'https://www.blendo.co/blog/predicting-churn-email-unsubscribe/', 'url': 'https://t.co/syETVG8cSf', 'display_url': 'blendo.co/blog/predictin…', 'indices': [60, 83]}, {'expanded_url': 'https://twitter.com/i/web/status/902578389906804737', 'url': 'https://t. ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=0, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=True, follow_request_sent=False, followers_count=524, profile_image_url_https='https://pbs.twimg.com/profile_images/3551645164/43da6af8f588b87bf67710b041f85f24_normal.jpeg', created_at=datetime.datetime(2011, 10, 6, 15, 16, 49), profile_sidebar_fill_color='DDEEF6', protected=False, url=None, entities={'description': {'urls': []}}, screen_name='dv_cloud', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/386033228/1415758191', description="Technopreneur that's crazy passionate about helping Small-to-Medium Businesses accelerate and grow by leveraging the cloud!!!", id_str='386033228', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='1DA1F2', favourites_count=9, statuses_count=750, friends_count=1036, profile_sidebar_border_color='C0DEED', name='Dennis Velasco', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='C0DEED', profile_image_url='http://pbs.twimg.com/profile_images/3551645164/43da6af8f588b87bf67710b041f85f24_normal.jpeg', location='San Francisco, CA', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': True, 'profile_background_color': 'C0DEED', 'followers_count': 524, 'id': 386033228, 'default_profile': True, 'listed_count': 39, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Thu Oct 06 15:16:49 +0000 2011', 'location': 'San Francisco, CA', 'profile_text_color': '333333', 'protected': False, 'url': None, 'entities': {'description': {'urls': []}}, 'follow_request_sent': False, 'favourites_count': 9, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/386033228/1415758191', 'description': "Technopreneur that's crazy passionate about helping Small-to-Medium Businesses accelerate and grow by leveraging the cloud!!!", 'geo_enabled': False, 'id_str': '386033228', 'following': False, 'utc_offset': -25200, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'default_profile_image': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_link_color': '1DA1F2', 'screen_name': 'dv_cloud', 'statuses_count': 750, 'friends_count': 1036, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3551645164/43da6af8f588b87bf67710b041f85f24_normal.jpeg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/3551645164/43da6af8f588b87bf67710b041f85f24_normal.jpeg', 'name': 'Dennis Velasco', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'has_extended_profile': False, 'time_zone': 'Pacific Time (US & Canada)', 'lang': 'en', 'is_translator': False}, id=386033228, translator_type='none', listed_count=39, geo_enabled=False, utc_offset=-25200, has_extended_profile=False, profile_text_color='333333', default_profile=True, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', time_zone='Pacific Time (US & Canada)', is_translator=False), in_reply_to_user_id=None, source_url='http://bufferapp.com', entities={'urls': [{'expanded_url': 'https://buff.ly/2vAf7oj', 'url': 'https://t.co/0x6QOO6ZXB', 'display_url': 'buff.ly/2vAf7oj', 'indices': [69, 92]}], 'symbols': [], 'user_mentions': [{'id': 89481823, 'indices': [97, 106], 'id_str': '89481823', 'name': 'RedPixie', 'screen_name': 'RedPixie'}], 'media': [{'type': 'photo', 'expanded_url': 'https://twitter.com/dv_cloud/status/902578350929190913/photo/1', 'media_url_https': 'https://pbs.twimg.com/media/DIaaOdsUwAAw9V3.jpg', 'id_str' ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=0, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=False, follow_request_sent=False, followers_count=192, profile_image_url_https='https://pbs.twimg.com/profile_images/767540361589878789/3R0UOXU2_normal.jpg', created_at=datetime.datetime(2015, 10, 30, 5, 53, 19), profile_sidebar_fill_color='000000', protected=False, url=None, entities={'description': {'urls': []}}, screen_name='shinnperdigosa', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/4065523814/1471831311', description='#digitalmarketing #SEO #searchenhineoptimization #SMM #socialmediamanagement #PPC', id_str='4065523814', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='1B95E0', favourites_count=2, statuses_count=2440, friends_count=404, profile_sidebar_border_color='000000', name='Shinn Perdigosa', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='000000', profile_image_url='http://pbs.twimg.com/profile_images/767540361589878789/3R0UOXU2_normal.jpg', location='Cavite, PH', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': False, 'profile_background_color': '000000', 'followers_count': 192, 'id': 4065523814, 'default_profile': False, 'listed_count': 22, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Fri Oct 30 05:53:19 +0000 2015', 'location': 'Cavite, PH', 'profile_text_color': '000000', 'protected': False, 'url': None, 'entities': {'description': {'urls': []}}, 'follow_request_sent': False, 'favourites_count': 2, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4065523814/1471831311', 'description': '#digitalmarketing #SEO #searchenhineoptimization #SMM #socialmediamanagement #PPC', 'geo_enabled': False, 'id_str': '4065523814', 'following': False, 'utc_offset': -25200, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'default_profile_image': False, 'profile_sidebar_border_color': '000000', 'profile_link_color': '1B95E0', 'screen_name': 'shinnperdigosa', 'statuses_count': 2440, 'friends_count': 404, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/767540361589878789/3R0UOXU2_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/767540361589878789/3R0UOXU2_normal.jpg', 'name': 'Shinn Perdigosa', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': '000000', 'has_extended_profile': True, 'time_zone': 'Pacific Time (US & Canada)', 'lang': 'en', 'is_translator': False}, id=4065523814, translator_type='none', listed_count=22, geo_enabled=False, utc_offset=-25200, has_extended_profile=True, profile_text_color='000000', default_profile=False, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', time_zone='Pacific Time (US & Canada)', is_translator=False), in_reply_to_user_id=None, source_url='https://ifttt.com', entities={'urls': [{'expanded_url': 'https://buff.ly/2vFqk6p', 'url': 'https://t.co/w5tPXCg2wK', 'display_url': 'buff.ly/2vFqk6p', 'indices': [78, 101]}], 'symbols': [], 'user_mentions': [], 'hashtags': [{'indices': [52, 64], 'text': 'DataScience'}, {'indices': [115, 123], 'text': 'bigdata'}]}, in_reply_to_status_id=None, contributors=None, id=902578336500723712, in_reply_to_status_id_str=None, id_str='902578336500723712', text="xtendly: 'How I Analysed 1.6 Million Articles for a #DataScience Competition' https://t.co/w5tPXCg2wK via RedPixie #bigdata …", user=User(profile_use_background_image=False, follow_request_sent=False, fo ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=82, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=False, follow_request_sent=False, followers_count=76, profile_image_url_https='https://pbs.twimg.com/profile_images/637331013132226560/wNFCs_Vx_normal.jpg', created_at=datetime.datetime(2010, 11, 15, 14, 0, 22), profile_sidebar_fill_color='000000', protected=False, url=None, entities={'description': {'urls': []}}, screen_name='jjmareca', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/215988823/1492537436', description='', id_str='215988823', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme14/bg.gif', default_profile_image=False, profile_link_color='19CF86', favourites_count=401, statuses_count=804, friends_count=521, profile_sidebar_border_color='000000', name='Xavier Mareca', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='000000', profile_image_url='http://pbs.twimg.com/profile_images/637331013132226560/wNFCs_Vx_normal.jpg', location='World citizen ', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': False, 'profile_background_color': '000000', 'followers_count': 76, 'id': 215988823, 'default_profile': False, 'listed_count': 3, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Mon Nov 15 14:00:22 +0000 2010', 'location': 'World citizen ', 'profile_text_color': '000000', 'protected': False, 'url': None, 'entities': {'description': {'urls': []}}, 'follow_request_sent': False, 'favourites_count': 401, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/215988823/1492537436', 'description': '', 'geo_enabled': True, 'id_str': '215988823', 'following': False, 'utc_offset': 7200, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'default_profile_image': False, 'profile_sidebar_border_color': '000000', 'profile_link_color': '19CF86', 'screen_name': 'jjmareca', 'statuses_count': 804, 'friends_count': 521, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/637331013132226560/wNFCs_Vx_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/637331013132226560/wNFCs_Vx_normal.jpg', 'name': 'Xavier Mareca', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_sidebar_fill_color': '000000', 'has_extended_profile': False, 'time_zone': 'Bern', 'lang': 'en', 'is_translator': False}, id=215988823, translator_type='none', listed_count=3, geo_enabled=True, utc_offset=7200, has_extended_profile=False, profile_text_color='000000', default_profile=False, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme14/bg.gif', time_zone='Bern', is_translator=False), in_reply_to_user_id=None, source_url='http://twitter.com/download/android', entities={'urls': [{'expanded_url': 'https://buff.ly/2wDoZBx', 'url': 'https://t.co/YW8AofGKxg', 'display_url': 'buff.ly/2wDoZBx', 'indices': [107, 130]}], 'symbols': [], 'user_mentions': [{'id': 20167623, 'indices': [3, 13], 'id_str': '20167623', 'name': 'KDnuggets', 'screen_name': 'kdnuggets'}], 'hashtags': [{'indices': [15, 22], 'text': 'Python'}, {'indices': [35, 42], 'text': 'rstats'}, {'indices': [66, 78], 'text': 'DataScience'}, {'indices': [80, 96], 'text': 'MachineLearning'}]}, in_reply_to_status_id=None, retweeted_status=Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=82, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=True, follow_request_sent=False, followers_count=92380, profile_image_url ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=19, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=True, follow_request_sent=False, followers_count=1340, profile_image_url_https='https://pbs.twimg.com/profile_images/798876005557538816/gpMAt2G__normal.jpg', created_at=datetime.datetime(2013, 10, 14, 19, 16), profile_sidebar_fill_color='511020', protected=False, url='https://t.co/nNgyZ4F6B6', entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://www.linkedin.com/in/ampercival', 'url': 'https://t.co/nNgyZ4F6B6', 'display_url': 'linkedin.com/in/ampercival', 'indices': [0, 23]}]}}, screen_name='am_percival', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/1961211860/1478654280', description='🍁 Public Servant | Former @drdc_rddc physicist 🚀 | @NRCan Free Agent 👾 | Developing and leading #UX program 🕵️ and playing with #blockchain 🔗 @CIPO_Canada', id_str='1961211860', following=False, profile_background_image_url='http://pbs.twimg.com/profile_background_images/378800000094735732/9bd298835170ab874dcdb87720ea7e0f.png', default_profile_image=False, profile_link_color='ABB8C2', favourites_count=1988, statuses_count=5512, friends_count=1668, profile_sidebar_border_color='910F0F', name='Aaron Percival 🇨🇦', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='514034', profile_image_url='http://pbs.twimg.com/profile_images/798876005557538816/gpMAt2G__normal.jpg', location='Ottawa, Ontario', profile_background_tile=True, _json={'contributors_enabled': False, 'profile_use_background_image': True, 'profile_background_color': '514034', 'followers_count': 1340, 'id': 1961211860, 'default_profile': False, 'listed_count': 98, 'profile_background_tile': True, 'notifications': False, 'created_at': 'Mon Oct 14 19:16:00 +0000 2013', 'location': 'Ottawa, Ontario', 'profile_text_color': 'A1B100', 'protected': False, 'url': 'https://t.co/nNgyZ4F6B6', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://www.linkedin.com/in/ampercival', 'url': 'https://t.co/nNgyZ4F6B6', 'display_url': 'linkedin.com/in/ampercival', 'indices': [0, 23]}]}}, 'follow_request_sent': False, 'favourites_count': 1988, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1961211860/1478654280', 'description': '🍁 Public Servant | Former @drdc_rddc physicist 🚀 | @NRCan Free Agent 👾 | Developing and leading #UX program 🕵️ and playing with #blockchain 🔗 @CIPO_Canada', 'geo_enabled': True, 'id_str': '1961211860', 'following': False, 'utc_offset': -10800, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000094735732/9bd298835170ab874dcdb87720ea7e0f.png', 'default_profile_image': False, 'profile_sidebar_border_color': '910F0F', 'profile_link_color': 'ABB8C2', 'screen_name': 'am_percival', 'statuses_count': 5512, 'friends_count': 1668, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/798876005557538816/gpMAt2G__normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/798876005557538816/gpMAt2G__normal.jpg', 'name': 'Aaron Percival 🇨🇦', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000094735732/9bd298835170ab874dcdb87720ea7e0f.png', 'profile_sidebar_fill_color': '511020', 'has_extended_profile': True, 'time_zone': 'Atlantic Time (Canada)', 'lang': 'en', 'is_translator': False}, id=1961211860, translator_type='none', listed_count=98, geo_enabled=True, utc_offset=-10800, has_extended_profile=True, profile_text_color='A1B100', default_profile=False, notifications=False, profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/378800000094735732/9bd298835170ab874dcdb87720ea7 ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=16, truncated=False, coordinates=None, place=None, contributors=None, retweeted=False, author=User(profile_use_background_image=False, follow_request_sent=False, followers_count=6993, profile_image_url_https='https://pbs.twimg.com/profile_images/885882430984527873/Mb0G02Rm_normal.jpg', created_at=datetime.datetime(2016, 6, 6, 9, 35, 55), profile_sidebar_fill_color='000000', protected=False, url='https://t.co/7OtOj82t1v', entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://www.linkedin.com/in/cabadi/', 'url': 'https://t.co/7OtOj82t1v', 'display_url': 'linkedin.com/in/cabadi/', 'indices': [0, 23]}]}}, screen_name='Damien_CABADI', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/739752670752346112/1499194315', description="#Fintech enthusiast #CFO #Banking #Insurtech #Payments #blockchain #regtech Chief Financial Officer @INSEAD @HECParis @MITFintech Let's connect on Linkedin", id_str='739752670752346112', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='1B95E0', favourites_count=3786, statuses_count=877, friends_count=6971, profile_sidebar_border_color='000000', name='Damien CABADI', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='fr', contributors_enabled=False, profile_background_color='000000', profile_image_url='http://pbs.twimg.com/profile_images/885882430984527873/Mb0G02Rm_normal.jpg', location='', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': False, 'profile_background_color': '000000', 'followers_count': 6993, 'id': 739752670752346112, 'default_profile': False, 'listed_count': 199, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Mon Jun 06 09:35:55 +0000 2016', 'location': '', 'profile_text_color': '000000', 'protected': False, 'url': 'https://t.co/7OtOj82t1v', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://www.linkedin.com/in/cabadi/', 'url': 'https://t.co/7OtOj82t1v', 'display_url': 'linkedin.com/in/cabadi/', 'indices': [0, 23]}]}}, 'follow_request_sent': False, 'favourites_count': 3786, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/739752670752346112/1499194315', 'description': "#Fintech enthusiast #CFO #Banking #Insurtech #Payments #blockchain #regtech Chief Financial Officer @INSEAD @HECParis @MITFintech Let's connect on Linkedin", 'geo_enabled': True, 'id_str': '739752670752346112', 'following': False, 'utc_offset': 7200, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'default_profile_image': False, 'profile_sidebar_border_color': '000000', 'profile_link_color': '1B95E0', 'screen_name': 'Damien_CABADI', 'statuses_count': 877, 'friends_count': 6971, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/885882430984527873/Mb0G02Rm_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/885882430984527873/Mb0G02Rm_normal.jpg', 'name': 'Damien CABADI', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': '000000', 'has_extended_profile': True, 'time_zone': 'Paris', 'lang': 'fr', 'is_translator': False}, id=739752670752346112, translator_type='none', listed_count=199, geo_enabled=True, utc_offset=7200, has_extended_profile=True, profile_text_color='000000', default_profile=False, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', time_zone='Paris', is_translator=False), in_reply_to_user_id=None, source_url='http://bufferapp.com', entities={'urls': [], 'symbols': [], 'user_mentions': [{'id': 822120163067789314, 'indices': [3, 11], 'id_str': '8221201630 ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=2, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=False, follow_request_sent=False, followers_count=9910, profile_image_url_https='https://pbs.twimg.com/profile_images/477167045772312577/3q1ssMVN_normal.jpeg', created_at=datetime.datetime(2010, 1, 13, 15, 46, 14), profile_sidebar_fill_color='000000', protected=False, url='https://t.co/7WtxS2cHYx', entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'http://cl.linkedin.com/in/alevergara', 'url': 'https://t.co/7WtxS2cHYx', 'display_url': 'cl.linkedin.com/in/alevergara', 'indices': [0, 23]}]}}, screen_name='alevergara78', verified=False, description='Any fool can write code that a computer can understand. Good programmers write code that humans can understand. Martin Fowler.\n#BigData  #machinelearning', id_str='104520454', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='02243B', favourites_count=1366, statuses_count=538612, friends_count=721, profile_sidebar_border_color='000000', name='alejandro vergara', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='000000', profile_image_url='http://pbs.twimg.com/profile_images/477167045772312577/3q1ssMVN_normal.jpeg', location='Santiago, Chile', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': False, 'profile_background_color': '000000', 'followers_count': 9910, 'id': 104520454, 'default_profile': False, 'listed_count': 3929, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Wed Jan 13 15:46:14 +0000 2010', 'location': 'Santiago, Chile', 'profile_text_color': '000000', 'protected': False, 'url': 'https://t.co/7WtxS2cHYx', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'http://cl.linkedin.com/in/alevergara', 'url': 'https://t.co/7WtxS2cHYx', 'display_url': 'cl.linkedin.com/in/alevergara', 'indices': [0, 23]}]}}, 'follow_request_sent': False, 'favourites_count': 1366, 'verified': False, 'translator_type': 'none', 'description': 'Any fool can write code that a computer can understand. Good programmers write code that humans can understand. Martin Fowler.\n#BigData  #machinelearning', 'geo_enabled': True, 'id_str': '104520454', 'following': False, 'utc_offset': -10800, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'default_profile_image': False, 'profile_sidebar_border_color': '000000', 'profile_link_color': '02243B', 'screen_name': 'alevergara78', 'statuses_count': 538612, 'friends_count': 721, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/477167045772312577/3q1ssMVN_normal.jpeg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/477167045772312577/3q1ssMVN_normal.jpeg', 'name': 'alejandro vergara', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': '000000', 'has_extended_profile': False, 'time_zone': 'Santiago', 'lang': 'en', 'is_translator': False}, id=104520454, translator_type='none', listed_count=3929, geo_enabled=True, utc_offset=-10800, has_extended_profile=False, profile_text_color='000000', default_profile=False, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', time_zone='Santiago', is_translator=False), in_reply_to_user_id=None, source_url='https://twitter.com/alevergara78', entities={'urls': [{'expanded_url': 'https://buff.ly/2vnIgm4', 'url': 'https://t.co/KYqbgrF6j3', 'display_url': 'buff.ly/2vnIgm4', 'indices': [54, 77]}], 'symbols': [], 'user_mentions': [{'id': 4361928854, 'indices': [3, 15], 'id_str': '4361928854', 'n ...
# ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=4, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=True, follow_request_sent=False, followers_count=274, profile_image_url_https='https://pbs.twimg.com/profile_images/761357076526403584/beTzpWDb_normal.jpg', created_at=datetime.datetime(2013, 4, 3, 21, 7, 55), profile_sidebar_fill_color='DDEEF6', protected=False, url=None, entities={'description': {'urls': []}}, screen_name='adrianfz10', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/1325421246/1454253055', description='Data geek, Big data, MSAnalytics, Database, Data science, IoT, Azure, AWS', id_str='1325421246', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='1DA1F2', favourites_count=414, statuses_count=1956, friends_count=1197, profile_sidebar_border_color='C0DEED', name='Adrian Fernandez', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='C0DEED', profile_image_url='http://pbs.twimg.com/profile_images/761357076526403584/beTzpWDb_normal.jpg', location='Capital Federal, Argentina', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': True, 'profile_background_color': 'C0DEED', 'followers_count': 274, 'id': 1325421246, 'default_profile': True, 'listed_count': 222, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Wed Apr 03 21:07:55 +0000 2013', 'location': 'Capital Federal, Argentina', 'profile_text_color': '333333', 'protected': False, 'url': None, 'entities': {'description': {'urls': []}}, 'follow_request_sent': False, 'favourites_count': 414, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1325421246/1454253055', 'description': 'Data geek, Big data, MSAnalytics, Database, Data science, IoT, Azure, AWS', 'geo_enabled': False, 'id_str': '1325421246', 'following': False, 'utc_offset': -10800, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'default_profile_image': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_link_color': '1DA1F2', 'screen_name': 'adrianfz10', 'statuses_count': 1956, 'friends_count': 1197, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/761357076526403584/beTzpWDb_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/761357076526403584/beTzpWDb_normal.jpg', 'name': 'Adrian Fernandez', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'has_extended_profile': False, 'time_zone': 'Buenos Aires', 'lang': 'en', 'is_translator': False}, id=1325421246, translator_type='none', listed_count=222, geo_enabled=False, utc_offset=-10800, has_extended_profile=False, profile_text_color='333333', default_profile=True, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', time_zone='Buenos Aires', is_translator=False), in_reply_to_user_id=None, source_url='http://twitter.com/download/iphone', entities={'urls': [{'expanded_url': 'http://bit.ly/2vTOa09', 'url': 'https://t.co/ffTSDAGD5u', 'display_url': 'bit.ly/2vTOa09', 'indices': [89, 112]}], 'symbols': [], 'user_mentions': [{'id': 129315638, 'indices': [3, 14], 'id_str': '129315638', 'name': 'Mark Tabladillo', 'screen_name': 'MarkTabNet'}], 'hashtags': [{'indices': [113, 125], 'text': 'DataScience'}]}, in_reply_to_status_id=None, retweeted_status=Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=4, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=103, truncated=False, coordinates=None, place=None, contributors=None, retweeted=False, author=User(profile_use_background_image=False, follow_request_sent=False, followers_count=0, profile_image_url_https='https://pbs.twimg.com/profile_images/902566557565329413/aasXuBum_normal.jpg', created_at=datetime.datetime(2017, 8, 25, 16, 10, 21), profile_sidebar_fill_color='000000', protected=False, url='https://t.co/LPCS9egT9T', entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'http://www.luvdigital.com', 'url': 'https://t.co/LPCS9egT9T', 'display_url': 'luvdigital.com', 'indices': [0, 23]}]}}, screen_name='LuvDigitaldtcom', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/901114533695172610/1504022601', description='', id_str='901114533695172610', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='D4119A', favourites_count=3, statuses_count=4, friends_count=12, profile_sidebar_border_color='000000', name='LuvDigital', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='000000', profile_image_url='http://pbs.twimg.com/profile_images/902566557565329413/aasXuBum_normal.jpg', location='Evesham, England', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': False, 'profile_background_color': '000000', 'followers_count': 0, 'id': 901114533695172610, 'default_profile': False, 'listed_count': 0, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Fri Aug 25 16:10:21 +0000 2017', 'location': 'Evesham, England', 'profile_text_color': '000000', 'protected': False, 'url': 'https://t.co/LPCS9egT9T', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'http://www.luvdigital.com', 'url': 'https://t.co/LPCS9egT9T', 'display_url': 'luvdigital.com', 'indices': [0, 23]}]}}, 'follow_request_sent': False, 'favourites_count': 3, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/901114533695172610/1504022601', 'description': '', 'geo_enabled': False, 'id_str': '901114533695172610', 'following': False, 'utc_offset': None, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'default_profile_image': False, 'profile_sidebar_border_color': '000000', 'profile_link_color': 'D4119A', 'screen_name': 'LuvDigitaldtcom', 'statuses_count': 4, 'friends_count': 12, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/902566557565329413/aasXuBum_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/902566557565329413/aasXuBum_normal.jpg', 'name': 'LuvDigital', 'is_translation_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': '000000', 'has_extended_profile': False, 'time_zone': None, 'lang': 'en', 'is_translator': False}, id=901114533695172610, translator_type='none', listed_count=0, geo_enabled=False, utc_offset=None, has_extended_profile=False, profile_text_color='000000', default_profile=False, notifications=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', time_zone=None, is_translator=False), in_reply_to_user_id=None, source_url='http://twitter.com', entities={'urls': [], 'symbols': [], 'user_mentions': [{'id': 4374719908, 'indices': [3, 15], 'id_str': '4374719908', 'name': 'J-Baptiste Lefevre', 'screen_name': 'jblefevre60'}], 'hashtags': [{'indices': [49, 65], 'text': 'machinelearning'}, {'indices': [67, 70], 'text': 'AI'}, {'indices': [71, 79], 'text': 'BigData'}, {'indices': [80, 90], 'text': 'Analytics'}, {'indices': [91, 103], 'text': 'DataScience'}, {'indices': [104, 113], 'text': 'Robotics'}, {'indice ...
#  Status(geo=None, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, retweet_count=0, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, author=User(profile_use_background_image=True, follow_request_sent=False, followers_count=6, profile_image_url_https='https://pbs.twimg.com/profile_images/902314027778527232/r4WtXdRx_normal.jpg', created_at=datetime.datetime(2017, 7, 5, 19, 18, 55), profile_sidebar_fill_color='DDEEF6', protected=False, url='https://t.co/HFDGShzsZl', entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://rocketprep.co/', 'url': 'https://t.co/HFDGShzsZl', 'display_url': 'rocketprep.co', 'indices': [0, 23]}]}}, screen_name='realrocketprep', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/882680206833700864/1503962945', description='Learn about high growth tech careers in cybersecurity, robotics, machine learning and data science', id_str='882680206833700864', following=False, profile_background_image_url=None, default_profile_image=False, profile_link_color='1DA1F2', favourites_count=0, statuses_count=34, friends_count=0, profile_sidebar_border_color='C0DEED', name='RocketPrep', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='F5F8FA', profile_image_url='http://pbs.twimg.com/profile_images/902314027778527232/r4WtXdRx_normal.jpg', location='Manhattan, NY', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': True, 'profile_background_color': 'F5F8FA', 'followers_count': 6, 'id': 882680206833700864, 'default_profile': True, 'listed_count': 0, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Wed Jul 05 19:18:55 +0000 2017', 'location': 'Manhattan, NY', 'profile_text_color': '333333', 'protected': False, 'url': 'https://t.co/HFDGShzsZl', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://rocketprep.co/', 'url': 'https://t.co/HFDGShzsZl', 'display_url': 'rocketprep.co', 'indices': [0, 23]}]}}, 'follow_request_sent': False, 'favourites_count': 0, 'verified': False, 'translator_type': 'none', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/882680206833700864/1503962945', 'description': 'Learn about high growth tech careers in cybersecurity, robotics, machine learning and data science', 'geo_enabled': False, 'id_str': '882680206833700864', 'following': False, 'utc_offset': -25200, 'profile_background_image_url': None, 'default_profile_image': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_link_color': '1DA1F2', 'screen_name': 'realrocketprep', 'statuses_count': 34, 'friends_count': 0, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/902314027778527232/r4WtXdRx_normal.jpg', 'profile_image_url': 'http://pbs.twimg.com/profile_images/902314027778527232/r4WtXdRx_normal.jpg', 'name': 'RocketPrep', 'is_translation_enabled': False, 'profile_background_image_url_https': None, 'profile_sidebar_fill_color': 'DDEEF6', 'has_extended_profile': False, 'time_zone': 'Pacific Time (US & Canada)', 'lang': 'en', 'is_translator': False}, id=882680206833700864, translator_type='none', listed_count=0, geo_enabled=False, utc_offset=-25200, has_extended_profile=False, profile_text_color='333333', default_profile=True, notifications=False, profile_background_image_url_https=None, time_zone='Pacific Time (US & Canada)', is_translator=False), in_reply_to_user_id=None, source_url='http://twitter.com', entities={'urls': [{'expanded_url': 'http://www.engineering.com/DesignerEdge/DesignerEdgeArticles/ArticleID/15550/Using-Machine-Learning-and-Selfies-to-Screen-for-Pancreatic-Cancer.aspx', 'url': 'https://t.co/LMZ37CI7hx', 'display_url': 'engineering.com/DesignerEdge/D…', 'indices': [55, 78]}], 'symbols': [], 'user_mentions': [], 'hashtags': [{'indices': [22, 29], 'text': 'cancer'}, {'indices': [38, 54], 'text': 'mach ...

# %% [markdown]
# O resultado novamente é uma lista de objetos do tipo `Status`, a qual podemos processar da mesma forma como fizemos com os tweets do Trump.

# %%
dfTweetsDataScience = pd.DataFrame(list(map(lambda x: filtra_campos(x._json),
                                            tweetsDataScience)))
dfTweetsDataScience.head()
# Out:
#                        created_at  favorite_count  \
# 0  Tue Aug 29 17:08:19 +0000 2017               0
# 1  Tue Aug 29 17:08:13 +0000 2017               0
# 2  Tue Aug 29 17:07:41 +0000 2017               0
# 3  Tue Aug 29 17:07:21 +0000 2017               0
# 4  Tue Aug 29 17:07:11 +0000 2017               0
#
#                                             hashtags                  id  \
# 0  [{'indices': [43, 48], 'text': 'code'}, {'indi...  902578671323680769
# 1     [{'indices': [32, 44], 'text': 'datascience'}]  902578646866681861
# 2  [{'indices': [52, 64], 'text': 'DataScience'},...  902578515194859521
# 3  [{'indices': [24, 29], 'text': 'code'}, {'indi...  902578428951629824
# 4    [{'indices': [99, 111], 'text': 'datascience'}]  902578389906804737
#
#   in_reply_to_screen_name in_reply_to_status_id in_reply_to_user_id lang  \
# 0                    None                  None                None  und
# 1                    None                  None                None   en
# 2                    None                  None                None   en
# 3                    None                  None                None  und
# 4                    None                  None                None   en
#
#   media  retweet_count                                             source  \
# 0   NaN              1  <a href="http://sp1n3.com/" rel="nofollow">KJS...
# 1   NaN             10  <a href="http://gaggleamp.com/twit/" rel="nofo...
# 2   NaN              0  <a href="https://ifttt.com" rel="nofollow">IFT...
# 3   NaN              1  <a href="http://www.andrewshamlet.net" rel="no...
# 4   NaN              0  <a href="http://meetedgar.com" rel="nofollow">...
#
#   symbols                                               text truncated  \
# 0      []  RT @andrewshamlet: https://t.co/KJpeop39WA #co...     False
# 1      []  RT @DataRobot: You can become a #datascience s...     False
# 2      []  xtendly: 'How I Analysed 1.6 Million Articles ...     False
# 3      []  https://t.co/KJpeop39WA #code #learn #data #da...     False
# 4      []  How to predict Churn: When Do Email Recipients...      True
#
#                                                 urls     user_id  \
# 0  [{'expanded_url': 'http://www.amazon.com/dp/11...    75281169
# 1  [{'expanded_url': 'http://bit.ly/2xtn9jl', 'ur...    44542581
# 2  [{'expanded_url': 'https://buff.ly/2vFqk6p', '...   128739276
# 3  [{'expanded_url': 'http://www.amazon.com/dp/11...  2442313279
# 4  [{'expanded_url': 'https://www.blendo.co/blog/...  2253579049
#
#                                        user_mentions user_screen_name
# 0  [{'id': 2442313279, 'indices': [3, 17], 'id_st...          KJSBEDI
# 1  [{'id': 622519917, 'indices': [3, 13], 'id_str...   tweetingAsGreg
# 2                                                 []         abiconti
# 3                                                 []    andrewshamlet
# 4  [{'id': 2988710754, 'indices': [88, 98], 'id_s...          APIrise

# %% [markdown]
# Agora podemos iniciar nosso processamento. Podemos, por exemplo, identificar as mensagens mais interessantes, considerando o número de retweets.

# %%
dfTweetsDataScience.retweet_count.describe()
# Out:
# count    100.000000
# mean      19.870000
# std       38.072938
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%       18.250000
# max      201.000000
# Name: retweet_count, dtype: float64

# %%
[a for a in dfTweetsDataScience[\
    dfTweetsDataScience.retweet_count >= 16].sort_values(by='retweet_count')['text']]
# Out:
# ['RT @dbi_srl: RT evankirstel by  (evankirstel) 4 barriers to #DigitalTransformation\n#StartUps #SMM #IoT #BigData #Fintech #DataScience #DX\n#…',
#  'RT @Rbloggers: July 2017 New Package Picks https://t.co/PsNg0BxSjc #rstats #DataScience',
#  'RT @Rbloggers: July 2017 New Package Picks https://t.co/PsNg0BxSjc #rstats #DataScience',
#  'RT @MikeQuindazzi: #AI + #CRM? By 2021, @IDC estimates a $1.1 trillion boost global business revenues. #UI #BigData #DataScience https://t.…',
#  'RT @MikeTamir: A new #AI algorithm summarizes text amazingly well https://t.co/0Oz9uyVt89 #DeepLearning #MachineLearning #DataScience https…',
#  'RT @ExperianDataLab: Why We Need More Women Working in #DataScience [LIVE VIDEO]\nhttps://t.co/Y8kiK8cuMQ\n #AI #IoT #BigData #Analytics #Tec…',
#  'RT @gotosell: How big is #BigData at big companies?\n#DataScience #Cloud #Data #Tech #IoT #Mpgvip #Defstar5 #DigitalTransformation #SocialMe…',
#  'RT @gotosell: How big is #BigData at big companies?\n#DataScience #Cloud #Data #Tech #IoT #Mpgvip #Defstar5 #DigitalTransformation #SocialMe…',
#  'RT @gp_pulipaka: IDC FutureScape: Worldwide IoT - 2017 Predictions. #BigData #DataScience #IoT #Analytics #BlockChain #FinTech\nhttps://t.co…',
#  'RT @gotosell: How big is #BigData at big companies?\n#DataScience #Cloud #Data #Tech #IoT #Mpgvip #Defstar5 #DigitalTransformation #SocialMe…',
#  'RT @gotosell: How big is #BigData at big companies?\n#DataScience #Cloud #Data #Tech #IoT #Mpgvip #Defstar5 #DigitalTransformation #SocialMe…',
#  'RT @randal_olson: A Genetic Algorithm tutorial in #Python. #MachineLearning #DataScience\n\nhttps://t.co/DKTl08Rhs8 https://t.co/GfAr17vSeK',
#  'RT @KirkDBorne: A Brief Survey of Deep Reinforcement Learning: https://t.co/CaRoFjbNg4 #BigData #DataScience #MachineLearning #DeepLearning…',
#  'RT @paulalbright: #MachineLearning Defined\n{Infographic}\n\n#MakeYourOwnLane #AI #BigData #DigitalMarketing #DataScience #CX #defstar5 #Tech…',
#  'RT @Ronald_vanLoon: Why Artificial Intelligence Needs Neuroscience for Inspiration | #DataScience #Artificialintelligence #RT https://t.co/…',
#  'RT @TamaraMcCleary: The Evolution of #IoT via @topij @CalliauF #BigData #DataScience #Chatbot #Fintech #AI #VR #AR RT @viddyad @ipfconline1…',
#  'RT @KirkDBorne: Best #DeepLearning tutorials, videos &amp; books in 2017: https://t.co/XzcTZhjsSH #BigData #DataScience #MachineLearning #AI #P…',
#  'RT @kdnuggets: #Python overtakes R #rstats, becomes the leader in #DataScience, #MachineLearning platforms https://t.co/YW8AofGKxg https://…',
#  'RT @kdnuggets: #Python overtakes R #rstats, becomes the leader in #DataScience, #MachineLearning platforms https://t.co/YW8AofGKxg https://…',
#  'RT @jblefevre60: What are the different types of #machinelearning?\n#AI #BigData #Analytics #DataScience #Robotics #visualization #Marketing…',
#  'RT @jblefevre60: What are the different types of #machinelearning?\n#AI #BigData #Analytics #DataScience #Robotics #visualization #Marketing…',
#  'RT @jblefevre60: What are the different types of #machinelearning?\n#AI #BigData #Analytics #DataScience #Robotics #visualization #Marketing…',
#  'RT @ipfconline1: Brief #DataScience History\n#AI #MachineLearning #ML #BigData #Analytics #Dataviz\nv/ @Capgemini\nHT @DeepLearn007 @jblefevre…',
#  'RT @KirkDBorne: The Unreasonable Effectiveness of Recurrent Neural Networks: https://t.co/JloAAAUunY #abdsc #BigData #DataScience #ML #Deep…',
#  'RT @Fisher85M: What to consider in #DigitalTransformation #Strategy?\n\n#startups #SMM #IoT #BigData #blockchain #Fintech #DataScience #CIO @…',
#  'RT @Fisher85M: 9 types of Intelligence {Infographic}\n[@chboursin] MT\n\n#ArtificialIntelligence #VirtualReality #DataScience #CX #UX #Analyti…',
#  'RT @Ronald_vanLoon: Difference between Machine Learning, Data Science, AI, Deep Learning, and Statistics | #DataScience #MachineLearni … ht…',
#  'RT @Ronald_vanLoon: Big Data Science: Expectations vs. Reality | #DataScience #BigData #RT https://t.co/v1ESagKjNI https://t.co/z8xB10g9xa',
#  'RT @Ronald_vanLoon: R and Python cheatsheets | #DataScience #Python #RT https://t.co/dSSq7sjj9F https://t.co/bKeU7CCH7s']

# %% [markdown]
# Observamos que muitas mensagens se tratam de retweets extra-oficiais (não executadas pelo botão de retweet). Essas mensagens citam diversas usuários. Dessa forma, podemos os tweets para encontrar quais são os usuários mais influentes em data science.
#
# Se verificarmos a descrição do objeto Tweet, veremos que ele possui um atributo user_mentions no campo ***entities***. Esse atributo é preenchido pelo Twitter que entrega uma lista de todos os usuários (objetos do tipo User) contidos no texto. Para o nosso exemplo, podemos nos restringir somente ao login do usuário no perfil (screen_name). Depois, podemos usar o screen_name dos usuários mais influentes para recuperar as informações de seus perfis diretamente da API.

# %%
usuariosInfluentes = dfTweetsDataScience.user_mentions.apply(lambda x: 
                                        [y['screen_name'] for y in x])
usuariosInfluentes
# Out:
# 0                                       [andrewshamlet]
# 1                                           [DataRobot]
# 2                                                    []
# 3                                                    []
# 4                                           [blendoapp]
# 5                                            [RedPixie]
# 6                                                    []
# 7                                           [kdnuggets]
# 8                                           [MikeTamir]
# 9                                             [dbi_srl]
# 10                                        [YarmolukDan]
# 11                                        [YarmolukDan]
# 12                                 [MikeQuindazzi, IDC]
# 13                                           [AndySugs]
# 14                                        [jblefevre60]
# 15                                                   []
# 16                                                   []
# 17                                                   []
# 18                                                   []
# 19                                     [Ronald_vanLoon]
# 20                                       [BigCloudTeam]
# 21                                                [IBM]
# 22                                         [KirkDBorne]
# 23                                         [MediaHutUK]
# 24                                     [Ronald_vanLoon]
# 25                                                   []
# 26                                            [tableau]
# 27                                                   []
# 28                                                   []
# 29                                           [RedPixie]
#                             ...
# 70    [abhinavpoonia, topij, CalliauF, viddyad, ipfc...
# 71                                                   []
# 72                                        [jblefevre60]
# 73                                           [gotosell]
# 74                                    [bonzaiengineers]
# 75                                                   []
# 76                                       [paulalbright]
# 77                                          [GaryDower]
# 78                                          [alexeul17]
# 79                                                   []
# 80                                          [Fisher85M]
# 81                               [Fisher85M, chboursin]
# 82                                        [bigdataconf]
# 83                             [kdnuggets, Springboard]
# 84    [TamaraMcCleary, topij, CalliauF, viddyad, ipf...
# 85                                           [gotosell]
# 86                                           [gotosell]
# 87                                          [GaryDower]
# 88                                                   []
# 89                                           [gotosell]
# 90                                         [KirkDBorne]
# 91                                          [kdnuggets]
# 92                                                   []
# 93                                    [datasciencegame]
# 94                                          [kdnuggets]
# 95                                         [MediaHutUK]
# 96                                        [logtrustInc]
# 97                                         [MarkTabNet]
# 98                                        [jblefevre60]
# 99                                                   []
# Name: user_mentions, dtype: object

# %%
top10Influentes = Counter(reduce(lambda x, y: x+y,
                                 usuariosInfluentes.values)).most_common(10)
top10Influentes
# Out:
# [('kdnuggets', 5),
#  ('gotosell', 4),
#  ('BigCloudTeam', 4),
#  ('Ronald_vanLoon', 4),
#  ('jblefevre60', 3),
#  ('ipfconline1', 3),
#  ('AndySugs', 3),
#  ('KirkDBorne', 3),
#  ('GDPRdigest', 2),
#  ('MediaHutUK', 2)]

# %% [markdown]
# Agora que encontramos os dez usuários mais citados nas mensagens, podemos usar a API para recuperar seus dados de perfil. Essa consulta é feita pela interface `lookup_users`.

# %%
descTop10Influentes = api.lookup_users(screen_names=[a[0] for a in top10Influentes])
descTop10Influentes
# Out:
# [User(profile_use_background_image=True, follow_request_sent=False, followers_count=92383, status=Status(geo=None, retweet_count=3, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, in_reply_to_user_id=None, source_url='http
 'display_url': 'twitter.com/i/web/status/9…', 'indices': [113, 136]}], 'symbols': [], 'user_mentions': [{'id': 2325704833, 'indices': [66, 78], 'id_str': '2325704833', 'name': 'Pinna Pierre', 'screen_name': 'pierrepinna'}, {'id': 705539763349164032, 'indices': [82, 94], 'id_str': '705539763349164032', 'name': 'ipfconline', 'screen_name': 'ipfconline1'}], 'hashtags': [{'indices': [9, 17], 'text': 'BigData'}, {'indices': [95, 98], 'text': 'AI'}, {'indices': [99, 102], 'text': 'ML'}, {'indices': [103, 106], 'text': 'DL'}, {'indices': [107, 111], 'text': 'IoT'}]}, 'in_reply_to_status_id': None, 'possibly_sensitive': False, 'id': 902584264230883330, 'in_reply_to_status_id_str': None, 'id_str': '902584264230883330', 'in_reply_to_user_id_str': None, 'created_at': 'Tue Aug 29 17:30:32 +0000 2017', 'favorited': False, 'is_quote_status': False, 'in_reply_to_screen_name': None, 'favorite_count': 3, 'coordinates': None, 'lang': 'en'}, id=902584264230883330, favorited=False, is_quote_status=False, _api=<tweepy.api.API object at 0x10913f978>, in_reply_to_screen_name=None, favorite_count=3, source='Hootsuite', lang='en'), profile_image_url_https='https://pbs.twimg.com/profile_images/729065804004769793/St2_Pum9_normal.jpg', created_at=datetime.datetime(2016, 3, 3, 23, 46, 2), profile_sidebar_fill_color='DDEEF6', protected=False, url='https://t.co/GBIheG6pPy', entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'http://www.ipfconline.fr', 'url': 'https://t.co/GBIheG6pPy', 'display_url': 'ipfconline.fr', 'indices': [0, 23]}]}}, screen_name='ipfconline1', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/705539763349164032/1462657867', description='Création de Sites Internet Formation et Conseil Informatique #ecommerce #webmaster #seo #DigitalMarketing #foad #seriousgame #AI #BigData', id_str='705539763349164032', following=False, profile_background_image_ur ...
#  User(profile_use_background_image=True, follow_request_sent=False, followers_count=2744, status=Status(geo=None, retweet_count=0, truncated=False, coordinates=None, place=None, contributors=None, retweeted=False, in_reply_to_user_id=None, source_url='https://ifttt.com', entities={'urls': [], 'symbols': [], 'user_mentions': [], 'hashtags': [{'indices': [108, 114], 'text': 'quote'}]}, in_reply_to_status_id=None, id=902585929495453696, in_reply_to_status_id_str=None, id_str='902585929495453696', text="RT:digr_io: Life doesn't get easier or more forgiving; we get stronger and more resilient. - Steve Maraboli #quote", in_reply_to_user_id_str=None, _json={'geo': None, 'retweet_count': 0, 'truncated': False, 'place': None, 'contributors': None, 'retweeted': False, 'in_reply_to_user_id': None, 'text': "RT:digr_io: Life doesn't get easier or more forgiving; we get stronger and more resilient. - Steve Maraboli #quote", 'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>', 'entities': {'urls': [], 'symbols': [], 'user_mentions': [], 'hashtags': [{'indices': [108, 114], 'text': 'quote'}]}, 'in_reply_to_status_id': None, 'id': 902585929495453696, 'in_reply_to_status_id_str': None, 'id_str': '902585929495453696', 'in_reply_to_user_id_str': None, 'created_at': 'Tue Aug 29 17:37:09 +0000 2017', 'favorited': False, 'is_quote_status': False, 'in_reply_to_screen_name': None, 'favorite_count': 0, 'coordinates': None, 'lang': 'en'}, created_at=datetime.datetime(2017, 8, 29, 17, 37, 9), favorited=False, is_quote_status=False, _api=<tweepy.api.API object at 0x10913f978>, in_reply_to_screen_name=None, favorite_count=0, source='IFTTT', lang='en'), profile_image_url_https='https://pbs.twimg.com/profile_images/482534534768898048/-dVcutqH_normal.jpeg', created_at=datetime.datetime(2010, 12, 25, 10, 11, 58), profile_sidebar_fill_color='DDEEF6', protected=False, url=None, entities={'description': {'urls': []}}, screen_name='AndySugs', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/230403822/1493417607', description='Father ov 3 who supports LFC & likes 2 do odd T-SQL query. Buzz off SQL BI, House tunes, reading news & airing me views #SQLServer #PowerBI #DataScience #rstats', id_str='230403822', following=False, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', default_profile_image=False, profile_link_color='1DA1F2', favourites_count=1594, statuses_count=264380, friends_count=4432, profile_sidebar_border_color='C0DEED', name='Andy Sugden', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabled=False, lang='en', contributors_enabled=False, profile_background_color='C0DEED', profile_image_url='http://pbs.twimg.com/profile_images/482534534768898048/-dVcutqH_normal.jpeg', location='Lancs, NW England', profile_background_tile=False, _json={'contributors_enabled': False, 'profile_use_background_image': True, 'profile_background_color': 'C0DEED', 'followers_count': 2744, 'id': 230403822, 'default_profile': True, 'is_translator': False, 'status': {'geo': None, 'retweet_count': 0, 'truncated': False, 'place': None, 'contributors': None, 'retweeted': False, 'in_reply_to_user_id': None, 'text': "RT:digr_io: Life doesn't get easier or more forgiving; we get stronger and more resilient. - Steve Maraboli #quote", 'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>', 'entities': {'urls': [], 'symbols': [], 'user_mentions': [], 'hashtags': [{'indices': [108, 114], 'text': 'quote'}]}, 'in_reply_to_status_id': None, 'id': 902585929495453696, 'in_reply_to_status_id_str': None, 'id_str': '902585929495453696', 'in_reply_to_user_id_str': None, 'created_at': 'Tue Aug 29 17:37:09 +0000 2017', 'favorited': False, 'is_quote_status': False, 'in_reply_to_screen_name': None, 'favorite_count': 0, 'coordinates': None, 'lang': 'en'}, 'profile_background_tile': False, 'notifications': False, 'created_at': 'Sat Dec 25 10:11:58 +0000 2010', 'location': 'Lancs, NW England', 'profile_text_color':  ...
#  User(profile_use_background_image=True, follow_request_sent=False, followers_count=166638, status=Status(geo=None, retweet_count=8, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, in_reply_to_user_id=None, source_url='http://twitter.com', entities={'urls': [{'expanded_url': 'http://www.computerweekly.com/feature/How-AI-can-aid-not-replace-humans-in-recruitment', 'url': 'https://t.co/OnsVyV2SBy', 'display_url': 'computerweekly.com/feature/How-AI…', 'indices': [50, 73]}], 'symbols': [], 'user_mentions': [], 'hashtags': [{'indices': [0, 3], 'text': 'AI'}, {'indices': [74, 79], 'text': 'bots'}, {'indices': [80, 92], 'text': 'HRAnalytics'}, {'indices': [93, 109], 'text': 'TalentAnalytics'}, {'indices': [110, 122], 'text': 'DataScience'}, {'indices': [123, 139], 'text': 'MachineLearning'}]}, in_reply_to_status_id=None, contributors=None, created_at=datetime.datetime(2017, 8, 29, 16, 17, 28), in_reply_to_status_id_str=None, id_str='902565875538124800', text='#AI will aid, not replace, humans in recruitment: https://t.co/OnsVyV2SBy #bots #HRAnalytics #TalentAnalytics #DataScience #MachineLearning', in_reply_to_user_id_str=None, _json={'geo': None, 'retweet_count': 8, 'truncated': False, 'place': None, 'contributors': None, 'retweeted': False, 'in_reply_to_user_id': None, 'text': '#AI will aid, not replace, humans in recruitment: https://t.co/OnsVyV2SBy #bots #HRAnalytics #TalentAnalytics #DataScience #MachineLearning', 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'entities': {'urls': [{'expanded_url': 'http://www.computerweekly.com/feature/How-AI-can-aid-not-replace-humans-in-recruitment', 'url': 'https://t.co/OnsVyV2SBy', 'display_url': 'computerweekly.com/feature/How-AI…', 'indices': [50, 73]}], 'symbols': [], 'user_mentions': [], 'hashtags': [{'indices': [0, 3], 'text': 'AI'}, {'indices': [74, 79], 'text': 'bots'}, {'indices': [80, 92], 'text': 'HRAnalytics'}, {'indices': [93, 109], 'text': 'TalentAnalytics'}, {'indices': [110, 122], 'text': 'DataScience'}, {'indices': [123, 139], 'text': 'MachineLearning'}]}, 'in_reply_to_status_id': None, 'possibly_sensitive': False, 'id': 902565875538124800, 'in_reply_to_status_id_str': None, 'id_str': '902565875538124800', 'in_reply_to_user_id_str': None, 'created_at': 'Tue Aug 29 16:17:28 +0000 2017', 'favorited': False, 'is_quote_status': False, 'in_reply_to_screen_name': None, 'favorite_count': 10, 'coordinates': None, 'lang': 'en'}, id=902565875538124800, favorited=False, is_quote_status=False, _api=<tweepy.api.API object at 0x10913f978>, in_reply_to_screen_name=None, favorite_count=10, source='Twitter Web Client', lang='en'), profile_image_url_https='https://pbs.twimg.com/profile_images/869301637269139458/3wIcLiQC_normal.jpg', created_at=datetime.datetime(2012, 3, 23, 16, 35, 17), profile_sidebar_fill_color='DDEEF6', protected=False, url='https://t.co/tWlmeuTlR7', entities={'description': {'urls': [{'expanded_url': 'http://rocketdatascience.org/', 'url': 'https://t.co/f4gsbNc00C', 'display_url': 'rocketdatascience.org', 'indices': [119, 142]}]}, 'url': {'urls': [{'expanded_url': 'http://www.linkedin.com/in/kirkdborne', 'url': 'https://t.co/tWlmeuTlR7', 'display_url': 'linkedin.com/in/kirkdborne', 'indices': [0, 23]}]}}, screen_name='KirkDBorne', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/534563976/1450104430', description='The Principal Data Scientist at @BoozAllen, PhD Astrophysicist. Top Data Science and Big Data Influencer. Ex-Professor https://t.co/f4gsbNc00C 📊📈🔭', id_str='534563976', following=True, profile_background_image_url='http://pbs.twimg.com/profile_background_images/378800000110442114/094a0b4d38b70e3871a1bda7d7fe2341.jpeg', default_profile_image=False, profile_link_color='0084B4', favourites_count=120044, statuses_count=76006, friends_count=64492, profile_sidebar_border_color='FFFFFF', name='Kirk Borne', _api=<tweepy.api.API object at 0x10913f978>, is_translation_enabl ...
#  User(profile_use_background_image=True, follow_request_sent=False, followers_count=127, status=Status(geo=None, retweet_count=0, truncated=True, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, in_reply_to_user_id=None, source_url='https://about.twitter.com/products/tweetdeck', entities={'urls': [{'expanded_url': 'http://www.theonebrief.com/how-will-robots-change-the-world/?utm_source=twitter&utm_medium=sitesocialshare&utm_campaign=orgsocialshares#.WWkJvi12Zz8.twitter', 'url': 'https://t.co/iy5TzEymNh', 'display_url': 'theonebrief.com/how-will-robot…', 'indices': [35, 58]}, {'expanded_url': 'https://twitter.com/i/web/status/902580358864089089', 'url': 'https://t.co/VmQkblkDj0', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [109, 132]}], 'symbols': [], 'user_mentions': [{'id': 309256353, 'indices': [90, 104], 'id_str': '309256353', 'name': 'Phil Clement', 'screen_name': 'PhilClement84'}], 'hashtags': [{'indices': [9, 16], 'text': 'Robots'}, {'indices': [59, 68], 'text': 'robotics'}, {'indices': [69, 72], 'text': 'AI'}, {'indices': [73, 89], 'text': 'machinelearning'}]}, in_reply_to_status_id=None, contributors=None, created_at=datetime.datetime(2017, 8, 29, 17, 15, 1), in_reply_to_status_id_str=None, id_str='902580358864089089', text='How Will #Robots Change the World? https://t.co/iy5TzEymNh #robotics #AI #machinelearning @PhilClement84 TY… https://t.co/VmQkblkDj0', in_reply_to_user_id_str=None, _json={'geo': None, 'retweet_count': 0, 'truncated': True, 'place': None, 'contributors': None, 'retweeted': False, 'in_reply_to_user_id': None, 'text': 'How Will #Robots Change the World? https://t.co/iy5TzEymNh #robotics #AI #machinelearning @PhilClement84 TY… https://t.co/VmQkblkDj0', 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'entities': {'urls': [{'expanded_url': 'http://www.theonebrief.com/how-will-robots-change-the-world/?utm_source=twitter&utm_medium=sitesocialshare&utm_campaign=orgsocialshares#.WWkJvi12Zz8.twitter', 'url': 'https://t.co/iy5TzEymNh', 'display_url': 'theonebrief.com/how-will-robot…', 'indices': [35, 58]}, {'expanded_url': 'https://twitter.com/i/web/status/902580358864089089', 'url': 'https://t.co/VmQkblkDj0', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [109, 132]}], 'symbols': [], 'user_mentions': [{'id': 309256353, 'indices': [90, 104], 'id_str': '309256353', 'name': 'Phil Clement', 'screen_name': 'PhilClement84'}], 'hashtags': [{'indices': [9, 16], 'text': 'Robots'}, {'indices': [59, 68], 'text': 'robotics'}, {'indices': [69, 72], 'text': 'AI'}, {'indices': [73, 89], 'text': 'machinelearning'}]}, 'in_reply_to_status_id': None, 'possibly_sensitive': False, 'id': 902580358864089089, 'in_reply_to_status_id_str': None, 'id_str': '902580358864089089', 'in_reply_to_user_id_str': None, 'created_at': 'Tue Aug 29 17:15:01 +0000 2017', 'favorited': False, 'is_quote_status': False, 'in_reply_to_screen_name': None, 'favorite_count': 0, 'coordinates': None, 'lang': 'en'}, id=902580358864089089, favorited=False, is_quote_status=False, _api=<tweepy.api.API object at 0x10913f978>, in_reply_to_screen_name=None, favorite_count=0, source='TweetDeck', lang='en'), profile_image_url_https='https://pbs.twimg.com/profile_images/885123103713615872/KItuuLAv_normal.jpg', created_at=datetime.datetime(2017, 7, 12, 12, 56, 8), profile_sidebar_fill_color='DDEEF6', protected=False, url=None, entities={'description': {'urls': []}}, screen_name='GDPRdigest', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/885120592118198273/1499864588', description='The General Data Protection Regulation: (EU) 2016/679 (#GDPR). Die Europäische Datenschutz-Grundverordnung gilt ab 25 Mai 2018 in sämtlichen EU-Mitgliedsländern', id_str='885120592118198273', following=False, profile_background_image_url=None, default_profile_image=False, profile_link_color='1DA1F2', favourites_count=0, statuses_count=452, friends_count=3, profile_sidebar ...
#  User(profile_use_background_image=False, follow_request_sent=False, followers_count=589, status=Status(geo=None, retweet_count=6, truncated=False, coordinates=None, place=None, possibly_sensitive=False, retweeted=False, in_reply_to_user_id=None, source_url='http://bufferapp.com', entities={'urls': [{'expanded_url': 'https://buff.ly/2vzLrYt', 'url': 'https://t.co/qEpDC3O6K4', 'display_url': 'buff.ly/2vzLrYt', 'indices': [52, 75]}], 'symbols': [], 'user_mentions': [], 'media': [{'type': 'photo', 'expanded_url': 'https://twitter.com
# %% [markdown]
# Os objetos do tipo User possuem diversos campos que não são úteis para nossa análise nesse momento. Assim, antes de criar um data frame com os dados dos usuários, devemos filtrá-los, escolhendo somente aquilo que pode ser interessante. Nesse primeiro momento restringiremos nossa análise ao login, nome, descrição, localização, número de seguidores, o número de pessoas que o usuário segue, e o número de tweets que ele já tuitou.

# %%
dfTop10Influentes = pd.DataFrame([{'screen_name':a.screen_name,
                                  'name':a.name,
                                   'description':a.description,
                                   'location':a.location,
                                   'followers_count':a.followers_count,
                                   'friends_count':a.friends_count,
                                   'no_tweets':a.statuses_count
                                  } for a in descTop10Influentes],
                                columns = ['screen_name', 'name', 'description',
                                          'location', 'followers_count', 'friends_count', 
                                           'no_tweets'])
dfTop10Influentes
# Out:
#       screen_name                name  \
# 0       kdnuggets           KDnuggets
# 1        gotosell         GO TO SELL!
# 2    BigCloudTeam           Big Cloud
# 3  Ronald_vanLoon     Ronald van Loon
# 4     jblefevre60  J-Baptiste Lefevre
# 5     ipfconline1          ipfconline
# 6        AndySugs         Andy Sugden
# 7      KirkDBorne          Kirk Borne
# 8      GDPRdigest     The GDPR Digest
# 9      MediaHutUK           Media Hut
#
#                                          description  \
# 0  Covering #Analytics, #BigData, #DataMining, #D...
# 1  Real estate and Property portal\nListing inter...
# 2  Big thinking recruiters specialising in Big Da...
# 3  Helping data driven companies generating value...
# 4  #digital #innovation #banque #fintech #disrupt...
# 5  Création de Sites Internet Formation et Consei...
# 6  Father ov 3 who supports LFC & likes 2 do odd ...
# 7  The Principal Data Scientist at @BoozAllen, Ph...
# 8  The General Data Protection Regulation: (EU) 2...
# 9  #Promotionalproducts for your business to get ...
#
#                         location  followers_count  friends_count  no_tweets
# 0             Brookline, MA, USA            92383            394      40730
# 1               Istanbul, Turkey              338           1292         50
# 2                      Worldwide            30346          15552       6289
# 3  #NL. Also connect on LinkedIn           100181          96070      33067
# 4                  Paris, France            14637           2821      50882
# 5              Marseille, France            66935          64811      83171
# 6              Lancs, NW England             2744           4432     264380
# 7            Booz Allen Hamilton           166638          64492      76006
# 8            Zurich, Switzerland              127              3        452
# 9            Nottingham, England              589            678        524

# %% [markdown]
# #### Trabalhando com cursores
#
# A API do Twitter fornece mecanismos para que o usuário itere sobre o conjunto de resultados de uma requisição. Ao invés de retornar todos os resultados de uma única vez, a API utiliza o conceito de paginação através de cursores.
#
# Os resultados são divididos em páginas. Na primeira requisição, assume que a página solicitada é a primeira, usando para isso o parâmetro cursor com valor -1. Junto com os resultados, a API retorna o cursor (índice de página) anterior e o próximo. Na requisição subsequente, o usuário informa o próximo cursor e a API retorna a página seguinte com os outros resultados. O usuário pode, então, iterar sobre mais resultados que o limite imposto em cada requisição.
#
# A biblioteca Tweepy possui uma interface direta para a paginação usada pelo Twitter. O tutorial http://docs.tweepy.org/en/v3.5.0/cursor_tutorial.html detalha como utilizar os cursores. Veremos um exemplo a seguir onde recuperaremos os 1000 tweets mais recentes contendo #datascience.

# %%
tweetsDataScience = [tweet for tweet in tweepy.Cursor(api.search, q='#datascience',\
                                  count=100,result_type="recent").items(1000)]
len(tweetsDataScience)
# Out:
# 1000

# %% [markdown]
# O resultado da pesquisa continua sendo uma lista de objetos do tipo `Status`, os quais podemos processar da mesma forma que fizemos com a consulta direta.

# %%
dfTweetsDataScience = pd.DataFrame(list(map(lambda x: filtra_campos(x._json),
                                            tweetsDataScience)))
dfTweetsDataScience.head()
# Out:
#                        created_at  favorite_count  \
# 0  Tue Aug 29 17:44:07 +0000 2017               0
# 1  Tue Aug 29 17:43:56 +0000 2017               0
# 2  Tue Aug 29 17:43:38 +0000 2017               0
# 3  Tue Aug 29 17:43:36 +0000 2017               0
# 4  Tue Aug 29 17:43:28 +0000 2017               0
#
#                                             hashtags                  id  \
# 0  [{'indices': [24, 29], 'text': 'code'}, {'indi...  902587681527521281
# 1  [{'indices': [39, 51], 'text': 'DataScience'},...  902587635243372546
# 2  [{'indices': [21, 36], 'text': 'designthinking...  902587560811274240
# 3  [{'indices': [49, 65], 'text': 'machinelearnin...  902587551663476736
# 4  [{'indices': [23, 35], 'text': 'DataScience'},...  902587520520736769
#
#   in_reply_to_screen_name in_reply_to_status_id  in_reply_to_user_id lang  \
# 0                    None                  None                  NaN  und
# 1                    None                  None                  NaN   en
# 2                    None                  None                  NaN   en
# 3                    None                  None                  NaN   en
# 4                    None                  None                  NaN   en
#
#                                                media place_country place_name  \
# 0                                                NaN           NaN        NaN
# 1  [{'expanded_url': 'https://twitter.com/Analyti...           NaN        NaN
# 2                                                NaN           NaN        NaN
# 3                                                NaN           NaN        NaN
# 4                                                NaN           NaN        NaN
#
#    retweet_count                                             source symbols  \
# 0              0  <a href="http://www.andrewshamlet.net" rel="no...      []
# 1              2  <a href="http://twitter.com" rel="nofollow">Tw...      []
# 2             12  <a href="http://twitter.com/download/iphone" r...      []
# 3            105  <a href="http://twitter.com" rel="nofollow">Tw...      []
# 4            109  <a href="http://twitter.com" rel="nofollow">Tw...      []
#
#                                                 text truncated  \
# 0  https://t.co/0gGdCBBYsI #code #learn #data #da...     False
# 1  RT @AnalyticsVidhya: Taking up role of #DataSc...     False
# 2  RT @evankirstel: Can #designthinking unleash o...     False
# 3  RT @jblefevre60: What are the different types ...     False
# 4  RT @ipfconline1: Brief #DataScience History\n#...     False
#
#                                                 urls     user_id  \
# 0  [{'expanded_url': 'http://www.amazon.com/dp/15...  2442313279
# 1  [{'expanded_url': 'http://bit.ly/2vnmByX', 'ur...  3119786447
# 2                                                 []  2815408383
# 3                                                 []  3119786447
# 4                                                 []  3119786447
#
#                                        user_mentions user_screen_name
# 0                                                 []    andrewshamlet
# 1  [{'id': 2311645130, 'indices': [3, 19], 'id_st...    ChicagoAGroup
# 2  [{'id': 35203319, 'indices': [3, 15], 'id_str'...  martin_steinman
# 3  [{'id': 4374719908, 'indices': [3, 15], 'id_st...    ChicagoAGroup
# 4  [{'id': 705539763349164032, 'indices': [3, 15]...    ChicagoAGroup

# %%
dfTweetsDataScience[['favorite_count','retweet_count']].describe()
# Out:
#        favorite_count  retweet_count
# count     1000.000000    1000.000000
# mean         0.217000      27.481000
# std          1.389907      37.936062
# min          0.000000       0.000000
# 25%          0.000000       1.000000
# 50%          0.000000      10.000000
# 75%          0.000000      39.000000
# max         29.000000     237.000000

# %%
top10Influentes = Counter(reduce(lambda x, y: x+y,
                                 dfTweetsDataScience.user_mentions.apply(lambda x: 
                                        [y['screen_name'] for y in x]).values)).most_common(10)
top10Influentes
# Out:
# [('gp_pulipaka', 85),
#  ('KirkDBorne', 53),
#  ('kdnuggets', 49),
#  ('pinakinariwala', 48),
#  ('paulalbright', 30),
#  ('ipfconline1', 24),
#  ('evankirstel', 23),
#  ('cloudpreacher', 22),
#  ('Ronald_vanLoon', 21),
#  ('jblefevre60', 20)]

# %%
dfTop10Influentes = pd.DataFrame([{'screen_name':a.screen_name,
                                  'name':a.name,
                                   'description':a.description,
                                   'location':a.location,
                                   'followers_count':a.followers_count,
                                   'friends_count':a.friends_count,
                                   'no_tweets':a.statuses_count
                                  } \
                                  for a in api.lookup_users(screen_names=[a[0] \
                                                                          for a in top10Influentes])],
                                columns = ['screen_name', 'name', 'description',
                                          'location', 'followers_count', 'friends_count', 
                                           'no_tweets'])
dfTop10Influentes
# Out:
#       screen_name                name  \
# 0     gp_pulipaka     Dr. GP Pulipaka
# 1      KirkDBorne          Kirk Borne
# 2       kdnuggets           KDnuggets
# 3  pinakinariwala     Pinakin Ariwala
# 4    paulalbright       Paul Albright
# 5     ipfconline1          ipfconline
# 6     evankirstel        Evan Kirstel
# 7   cloudpreacher          David Holm
# 8  Ronald_vanLoon     Ronald van Loon
# 9     jblefevre60  J-Baptiste Lefevre
#
#                                          description  \
# 0  Ganapathi Pulipaka | Founder and CEO @deepsing...
# 1  The Principal Data Scientist at @BoozAllen, Ph...
# 2  Covering #Analytics, #BigData, #DataMining, #D...
# 3  Project Manager @marutitech, sharing data scie...
# 4  Leadership, growth, and getting things done at...
# 5  Création de Sites Internet Formation et Consei...
# 6  #Influencer #ThoughtLeader Helping #B2B client...
# 7  Futurist, CloudEvangelist, Influencer, Entrepr...
# 8  Helping data driven companies generating value...
# 9  #digital #innovation #banque #fintech #disrupt...
#
#                         location  followers_count  friends_count  no_tweets
# 0                Los Angeles, CA            29098          16322      33305
# 1            Booz Allen Hamilton           166632          64492      76006
# 2             Brookline, MA, USA            92384            394      40731
# 3                      Ahmedabad              453            140       8316
# 4             Silicon Valley, CA             7355           4271       5979
# 5              Marseille, France            66931          64797      83172
# 6                     Boston, MA           141111         137632     548280
# 7                   Oslo, Norway             8026           6338       3408
# 8  #NL. Also connect on LinkedIn           100173          96070      33068
# 9                  Paris, France            14634           2822      50882

# %% [markdown]
# ## Usando a API de Streaming
#
# Como foi dito anteriormente, a API REST não foi desenvolvida para a coleta de dados em tempo real. De acordo com a documentação da API (https://dev.twitter.com/rest/reference/get/search/tweets), o mecanismo de busca não foi desenvolvido para servir como base para coleta exaustiva de tweets. Veja o que diz a documentação
#
#     Please note that Twitter’s search service and, by extension, the Search API is not meant to be an exhaustive source of Tweets. Not all Tweets will be indexed or made available via the search interface.
#
# Caso seja importante coletar um grande volume de dados para processá-los depois, deve-se usar a [interface/API de streaming](https://dev.twitter.com/streaming/overview). Nesse caso, uma conexão é mantida com o servidor do Twitter por um tempo mais longo. Novos tweets serão enviados ao usuário à medida em que são postados.
#
# Mais uma vez, Tweepy fornece os mecanismos necessários para coletas da API de streaming. Em suma, o usuário deve criar um *listener* que executará as ações correspondentes quando um evento ocorrer. Esse listerner é passado para Tweepy que se encarrega de conectar com a API do Twitter.

# %%
from tweepy.streaming import StreamListener
from tweepy import Stream

# %% [markdown]
# A classe abaixo define um exemplo de um listener que exibe as mensagens na saída padrão sempre que um novo dado é enviado.

# %%
class StdOutListener(StreamListener):

    def on_data(self, data):
        print(data)
        return True

    def on_error(self, status):
        print(status)

# %% [markdown]
# O segundo passo para se coletar dados da API de streaming é instanciar um objeto `Stream` que será responsável pela conexão. Devemos passar para o construtor a sessão autenticada da mesma forma que na API REST, e um listener.

# %%
stream = Stream(auth, StdOutListener())

# %% [markdown]
# Na maior parte dos casos, nossa intenção é em coletar apenas tweets específicos de um assunto. Assim como na interface de busca, podemos informar os termos que estamos interessados no parâmetro **track**. Uma descrição mais completa dos parâmetros está disponível em https://dev.twitter.com/streaming/overview/request-parameters

# %%
stream.filter(track=['vamosport' ,'vamosanta', 
                     'classicodasmultidoes', 
                     'sportxsantacruz', 'sport recife'])
